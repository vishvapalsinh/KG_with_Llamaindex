# %%
import sys
import logging

# %%
# Install dependencies
# !pip install InstructorEmbedding torch transformers sentence-transformers
# !pip uninstall -y transformers sentence-transformers InstructorEmbedding
# !pip install transformers==4.31.0 sentence-transformers==2.2.2 InstructorEmbedding
# !pip install wikipedia
# %pip install ipython-ngql nebula3-python
# %pip install llama-index-graph-stores-neo4j
# %pip install neo4j

# %%
import requests
from typing import Any, List
from llama_index.core.embeddings import BaseEmbedding
from llama_index.core.bridge.pydantic import PrivateAttr
from llama_index.core import KnowledgeGraphIndex
from llama_index.graph_stores.nebula import NebulaGraphStore
from IPython.display import Markdown, display
from llama_index.core import Settings

# %%
# This is a custom embedding class for remote instructor embeddings
# It uses the requests library to make HTTP POST requests to a remote server
# to get the embeddings for the provided texts.
# The class is initialized with the base URL of the server, an API key for authentication,
# the model name, and an instruction string.


class RemoteInstructorEmbeddings(BaseEmbedding):
    _base_url: str = PrivateAttr()
    _api_key: str = PrivateAttr()
    _model_name: str = PrivateAttr()
    _instruction: str = PrivateAttr()

    def __init__(
        self,
        base_url: str,
        api_key: str,
        model_name: str = "snowflake-arctic-embed-s",  # Change as needed
        # model_name: str, 
        instruction: str = "Represent the text for semantic search:",
        **kwargs: Any,
    ):
        super().__init__(**kwargs)
        self._base_url = base_url.rstrip("/")
        self._api_key = api_key
        self._model_name = model_name
        self._instruction = instruction

    def _post_request(self, texts: List[str]) -> List[List[float]]:
        headers = {
            "Authorization": f"Bearer {self._api_key}",
            "Content-Type": "application/json"
        }

        # If you want to keep using instructions
        inputs = [f"{self._instruction} {text}" for text in texts]

        payload = {
            "model": self._model_name,
            "input": inputs if len(inputs) > 1 else inputs[0]  # API accepts string or list
        }

        response = requests.post(
            f"{self._base_url}/embeddings",
            headers=headers,
            json=payload
        )
        response.raise_for_status()
        return response.json()["data"]
    
    async def _aget_query_embedding(self, query: str) -> List[float]:
        return self._get_query_embedding(query)

    async def _aget_text_embedding(self, text: str) -> List[float]:
        return self._get_text_embedding(text)
    
    def _get_query_embedding(self, query: str) -> List[float]:
        return self._post_request([query])[0]

    def _get_text_embedding(self, text: str) -> List[float]:
        return self._post_request([text])[0]

    def _get_text_embeddings(self, texts: List[str]) -> List[List[float]]:
        return self._post_request(texts)

# %%
# Initialize the embedding models with the remote server details

embed_model_snow = RemoteInstructorEmbeddings(
    base_url="http://llms-inference.innkube.fim.uni-passau.de",
    api_key="enter the api key",  # Replace with your actual API key
    model_name="Snowflake/snowflake-arctic-embed-xs",  # or whatever model your server uses
)

embed_model_intfloat = RemoteInstructorEmbeddings(
    base_url="http://llms-inference.innkube.fim.uni-passau.de",
    api_key="enter the api key",
    model_name="intfloat/multilingual-e5-large",  # or whatever model your server uses
)

embed_model_jinaai = RemoteInstructorEmbeddings(
    base_url="http://llms-inference.innkube.fim.uni-passau.de",
    api_key="enter the api key",
    model_name="jinaai/jina-embeddings-v2-base-de",  # or whatever model your server uses
)


# Example usage
sentence = "What did the author do growing up?"

# %%
# Chekking if the embedding model is working
# This will return the embedding vector for the given sentence
embedding_snow = embed_model_snow._get_query_embedding(sentence)

print(f"Embedding vector:\n{embedding_snow}")
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): llms-inference.innkube.fim.uni-passau.de:80
# DEBUG:urllib3.connectionpool:http://llms-inference.innkube.fim.uni-passau.de:80 "POST /embeddings HTTP/1.1" 308 164
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): llms-inference.innkube.fim.uni-passau.de:443
# DEBUG:urllib3.connectionpool:https://llms-inference.innkube.fim.uni-passau.de:443 "POST /embeddings HTTP/1.1" 200 4883
# Embedding vector:
# {'object': 'embedding', 'index': 0, 'embedding': [0.03755944, 0.03179579, -0.0016535937, -0.006316622, -0.007491683, -0.0060295025, -0.088815525, -0.019279521, 0.062740855, 0.013409528, -0.0010979649, 0.09170799, -0.0106818965, -0.044152547, 0.015897894, 0.018162945, -0.045811456, 0.084051475, -0.10999854, -0.017663145, -0.014483566, 0.08315822, -0.0026611693, 0.029541371, -0.016801788, 0.02788246, -0.047512904, 0.0020483825, 0.013643477, -0.094855666, 0.043025337, 0.011601741, -0.012261052, -0.037495635, -0.027818657, -0.045428634, 0.030519703, -0.00079290086, -0.05478659, -0.052404564, -0.014143277, 0.019917563, 0.0052505587, -0.010852041, -0.026287355, -0.06495274, -0.011718716, -0.01967298, 0.020800188, 0.094090015, -0.10208681, -0.07345997, -0.01912001, 0.037176613, -0.022033738, 0.01672735, 0.0274571, -0.055849995, 0.036985204, -0.022969533, 0.054106012, 0.06656911, -0.26372427, -0.044577908, 0.0036873545, 0.026266087, -0.023586307, -0.042812657, -0.00080154097, 0.02611721, -0.03222115, 0.032816656, 0.044492837, 0.01838626, -0.0031981885, -0.065845996, 0.014345324, -0.008278603, 0.10455391, 0.0024896953, 0.051043406, 0.021640278, -0.021746619, 0.013813622, 0.011261452, 0.024394495, -0.03824002, -0.07911728, 0.04776812, -0.0022517587, -0.017865192, -0.051851593, 0.009007035, -0.0058008707, -0.051681448, 0.009692931, 0.007177979, 0.0274571, 0.025521703, 0.31731984, 0.037282955, 0.0020204682, -0.010357558, -0.040983602, -0.032922998, -0.042366028, -0.025585508, 0.030349558, 0.029179813, 0.054020938, -0.0049262205, -0.04776812, -0.0524471, -0.00093513116, -0.004564663, 0.056062676, -0.040047806, -0.026861593, 0.039494835, 0.020747017, -0.01433469, 0.026925396, -0.02543663, 0.03675125, -0.011474133, 0.0089964, 0.0065824725, 0.058955133, 0.0509158, -0.0049102693, 0.0007171333, 0.031264085, -0.0579768, 0.0050564874, -0.021629643, -0.04034556, 0.008438113, -0.08804987, 0.0224591, -0.014015669, -0.01438786, -0.10115102, 0.08830509, 0.01378172, 0.10302261, 0.065250486, 0.005101682, 0.004314763, -0.020821456, -0.09613175, 0.011165746, 0.047257688, 0.004434396, 0.0014741442, 0.011623009, -0.01008639, -0.05712608, -0.027924998, -0.01951347, 0.02656384, -0.07784119, -0.028967133, 0.0394523, 0.05602014, 0.04755544, -0.026585108, 0.014462299, 0.036836326, 0.09238856, -0.0067100814, 0.05346797, -0.013526503, 0.04364211, 0.07273685, -0.0062847193, -0.041153748, 0.04389733, 0.03668745, 0.008273286, -0.08132916, 0.027435832, 0.06848324, 0.010410728, -0.04164291, -0.023650112, -0.017971532, 0.044152547, 0.05248964, 0.028286554, 0.07316221, 0.0030732385, 0.093579575, 0.0077894367, -0.020523703, -0.016429596, -0.0073162215, -0.003434796, 0.020098342, 0.04179179, -0.036091942, 0.014653712, -0.0053436067, -0.09255871, -0.0008739854, 0.0002804729, -0.0059976005, -0.023713917, -0.0052080224, -0.031731986, -0.05912528, 0.0045620045, -0.032518905, 0.075629316, -0.023628844, 0.059040207, 0.0066090575, -0.00021085313, 0.003690013, 0.04968225, 0.058614846, 0.014972732, 0.0006430273, -0.03900567, -0.07307714, -0.03322075, -0.0017320197, -0.01656784, 0.017131444, 0.0035411364, -0.053723186, 0.022714317, 0.06363411, 0.06848324, 0.0873693, 0.00044363897, 0.046917398, -0.026500035, 0.0017599341, 0.051809058, -0.02177852, 0.01822675, -0.047427833, 0.018152311, 0.006635643, -0.02043863, -0.0014515469, -0.04602414, -0.04555624, 0.024607176, 0.11629389, 0.07826655, 0.01144223, -0.015142878, 0.031327892, 0.011452864, 0.0644423, -0.11152984, 0.030838724, -0.024032937, 0.03466698, 0.023862792, -0.0838388, 0.014962099, -0.0070397365, 0.0659736, -0.0279888, -0.06627136, -0.024841124, -0.013037337, -0.04810841, -0.065250486, 0.032625243, -0.015759652, -0.028137678, -0.02511761, 0.027393294, 0.0034374543, -0.0015525703, -0.051511306, -0.040707115, 0.038750455, 0.010517068, -0.00437325, 0.018152311, -0.075544246, 0.048065875, -0.09791827, -0.016918762, -0.037772123, 0.0033656745, -0.04525849, -0.06554824, 0.01194203, -0.015982967, 0.14292154, 0.012792754, 0.032965533,  ...

# %%
# Chekking if the embedding model is working
# This will return the embedding vector for the given sentence
embedding_intfloat = embed_model_intfloat._get_query_embedding(sentence)

print(f"Embedding vector:\n{embedding_intfloat}")
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): llms-inference.innkube.fim.uni-passau.de:80
# DEBUG:urllib3.connectionpool:http://llms-inference.innkube.fim.uni-passau.de:80 "POST /embeddings HTTP/1.1" 308 164
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): llms-inference.innkube.fim.uni-passau.de:443
# DEBUG:urllib3.connectionpool:https://llms-inference.innkube.fim.uni-passau.de:443 "POST /embeddings HTTP/1.1" 200 12859
# Embedding vector:
# {'object': 'embedding', 'index': 0, 'embedding': [-0.0053951642, -0.013991855, -0.02413849, -0.046007115, 0.026205083, -0.035877418, -0.00933355, 0.08340907, 0.02869516, -0.03106666, 0.026018752, 0.025730783, -0.049191702, -0.034064915, -0.0435001, -0.01627866, -0.02437564, 0.046040993, 0.005115666, -0.011518719, 0.026679384, -0.023511736, -0.02866128, -0.0329808, -0.007199199, -0.003658887, -0.027763499, -0.012416501, -0.012585893, -0.04949661, -0.016837656, -0.009934895, -0.037097048, -0.011459431, -0.047430016, 0.033184074, 0.033963278, 0.042009443, -0.026459174, 0.023054376, -0.023969097, 0.054171853, -0.02608651, -0.025104031, -0.025425877, 0.0116711715, 0.035098214, -0.0073685916, -0.010332968, 0.020598179, 0.024206247, 0.03851995, -0.00103065, -0.008461176, -0.044177674, 0.029762335, -0.02654387, 0.011789747, -0.04641366, -0.00752528, -0.0105362395, -0.029084764, 0.035030454, -0.0136869475, -0.040789813, 0.027627984, 0.03110054, 0.010739511, -0.04258538, 0.010129697, -0.033590615, 0.026154267, -0.044618092, -0.022309046, -0.023952158, -0.012382622, 0.025544452, -0.0011614002, 0.028102284, 0.0032354046, 0.04803983, -0.014008794, 0.030643178, -0.016219372, 0.03516597, 0.03757135, 0.025222605, 0.036622748, 0.02534118, 0.02584936, -0.024240127, 0.05329101, 0.02344398, -0.02989785, -0.02393522, -0.006525862, 0.05068236, 0.047938194, 0.0031845868, 0.018717917, 0.009248853, -0.027441652, 0.021140236, -0.052952226, -0.022681711, 0.0033645667, 0.011518719, 0.026425295, 0.031676475, 0.012501197, 0.032642014, 0.025019333, 0.016634384, -0.023630312, -0.023291526, -0.01029062, 0.018955067, -0.016295599, -0.035741907, 0.018345254, 0.04803983, 0.043838885, -0.0014948925, -0.044753607, 0.012323335, -0.013797053, 0.02464667, 0.02535812, 0.0020189518, 0.013365101, 0.023511736, 0.05119054, -0.042754773, -0.02556139, -0.03352286, -0.0416029, 7.404323e-05, -0.01985285, -0.013670009, -0.03990897, -0.0107903285, 0.033421222, 0.028136164, -0.033590615, -0.054917183, -0.04204332, -0.05400246, -0.0019511946, -0.022512319, -0.022918861, 0.022088837, -0.029271096, -0.010815738, 0.02845801, 0.041264113, -0.030795632, -0.015008212, 0.033793885, 0.03513209, -0.0013540846, -0.03162566, -0.03252344, 0.0017500406, -0.0136869475, -0.0114170825, -0.018768735, 0.026848776, 0.05213914, 0.011052888, -0.025917117, -0.01985285, -0.048209224, 0.03919752, -0.047904316, -0.0060642664, 0.02559527, 0.07006091, 0.026713263, 0.04902231, -0.018751796, 0.008952416, 0.0363856, 0.032642014, -0.017032458, -0.0030384853, 0.030253574, 0.057085413, 0.0016642854, 0.026103448, 0.032811407, 0.01123922, -0.052952226, -0.0025218371, 0.030439908, -0.031049721, 0.06213332, 0.044753607, 0.04224659, -0.015440164, -0.032387927, 0.01266212, 0.041704535, -0.0229358, 0.007931823, 0.007991111, -0.0177185, -0.029796213, -0.0435001, 0.05044521, -0.044550337, -0.03201526, -0.026001813, 0.023291526, -0.015236893, -0.04448258, -0.04068818, -0.019514063, -0.014627079, 0.007881005, 0.001770156, -0.0008268492, 0.041535143, 0.021462083, 0.0074194097, 0.025883237, 0.030050304, 0.029813154, 0.025256483, 0.055188213, -0.023833584, 0.012458849, 0.041264113, -0.04783656, -0.0238844, 0.0039764987, -0.025188727, -0.009062521, -0.035030454, 0.029796213, 0.02700123, -0.035945177, 0.011306977, 0.012755287, -0.011281569, -0.01863322, -0.010468482, 0.017167972, -0.034928817, 0.033133253, -0.016126206, 0.041467387, 0.016177023, -0.026374476, 0.0019363727, 0.051766474, 0.01934467, 0.032591198, -0.016066918, -0.01744747, -0.04739614, 0.017870953, 0.0049801515, -0.008240965, 0.02462973, 0.010248272, 0.010883495, -0.02820392, -0.031168297, -0.020394906, -0.02102166, -0.03753747, -0.029017007, -0.041433506, -0.040755935, -0.017515227, -0.012484258, -0.015922934, -0.015008212, -0.000841671, 0.023630312, 0.0033285709, -0.001726749, 0.03990897, -0.056001298, -0.0012715056, -0.022054957, 0.047633287, -0.0368599, 0.028271677, -0.02080145, 0.028051468, -0.024511155, 0.10319416, 0.020716753, -0.014516973, 0.03159178, -0.0 ...

# %%
# Chekking if the embedding model is working
# This will return the embedding vector for the given sentence
embedding_jinaai = embed_model_jinaai._get_query_embedding(sentence)

print(f"Embedding vector:\n{embedding_jinaai}")
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): llms-inference.innkube.fim.uni-passau.de:80
# DEBUG:urllib3.connectionpool:http://llms-inference.innkube.fim.uni-passau.de:80 "POST /embeddings HTTP/1.1" 308 164
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): llms-inference.innkube.fim.uni-passau.de:443
# DEBUG:urllib3.connectionpool:https://llms-inference.innkube.fim.uni-passau.de:443 "POST /embeddings HTTP/1.1" 200 9678
# Embedding vector:
# {'object': 'embedding', 'index': 0, 'embedding': [0.01325042, -0.074396856, -0.024057414, 0.046972133, 0.032117072, -0.039483823, -0.06496353, 0.036031418, 0.004974986, 0.02041051, -0.03136338, -0.023328034, 0.041890778, -0.050327286, 0.04631569, 0.0415504, 0.014222928, -0.004838227, 0.03702824, -0.010460538, -0.0030314894, -0.033624463, -0.03722274, 0.017371424, 0.014089208, 0.0014466055, -0.012715541, 0.011159528, -0.014830746, -0.033429958, 0.032433137, -0.08485132, 0.095500275, -0.044808302, 0.017492985, -0.0070871515, -0.058885355, 0.01541425, 0.011323639, -0.030512435, -0.007062839, 0.025406769, -0.034864407, -0.007998877, 0.013663736, -0.03984851, 0.0075126234, 0.052320927, -0.002669838, 0.05256405, -0.08878997, 0.012411633, 0.061413873, -0.029928932, -0.017492985, 0.034451094, 0.069096684, 0.020349728, 0.0549467, -0.0670058, -0.049986906, -0.019960726, 0.0478717, 0.0038140544, 0.026379278, -0.046729006, 0.060927622, 0.029175237, 0.07099308, -0.0139919575, 0.05640546, -0.030682625, 0.044200484, -0.008776884, -0.014235085, -0.115339436, 0.02866467, 0.037271366, 0.018599214, -0.011858518, 0.025285205, -0.053633813, 0.032919392, 0.0024419066, -0.0017945811, 0.05723209, 0.018234523, -0.047920328, 0.0007601517, 0.022647278, -0.0050236112, -0.019717598, 0.014563306, 0.04259585, -0.0004209136, 0.08353843, 0.013153169, -0.025358144, -0.023303721, -0.0047592106, 0.030342247, -0.0055858423, 0.047093697, -0.01015663, 0.05966336, 0.009646063, -0.016338132, -0.061267998, 0.027716476, -0.024653075, 0.043544043, 0.013578642, -0.025382457, 0.020094445, 0.026792593, 0.057280716, 0.040966894, -0.017444361, 0.05407144, 0.03902188, -0.028956423, -0.018659996, -0.019425845, -0.031217504, -0.04035908, 0.0702637, 0.019766223, 0.0013493547, 0.023729194, 0.0070263697, -0.031412005, 0.044735365, -0.0074700764, -0.016897324, 0.08582383, 0.004804797, -0.0024510238, -0.022622965, 0.025333831, -0.016216569, -0.02334019, 0.035472225, 0.00892276, 0.0103572095, -0.08533757, 0.013274733, -0.030561062, -0.066276416, -0.025479708, 0.078578636, 0.0018553628, -0.007840845, -0.0032244716, -0.021589676, 0.017833363, -0.02983168, 0.051786046, 0.034840096, 0.019839162, -0.025649896, 0.061754253, 0.08217692, -0.007384982, -0.005719562, 0.047725827, 0.015973443, -0.03685805, -0.046121188, 0.030974377, 0.025017766, -0.028810548, 0.025722835, -0.011639704, 0.0028415467, 0.048625395, -0.0030208528, -0.044929866, 0.03289508, 0.042304095, -0.036250234, -0.04913596, -0.0205807, 0.01301945, 0.02496914, -0.012727697, 0.019827005, -0.011244623, -0.037198428, 0.0035374975, -0.036201607, 0.012125958, 0.00075559306, -0.024081727, 0.06530391, -0.07541799, 0.051786046, -0.0036955301, 0.04522162, 0.03498597, -0.034913033, 0.011858518, -0.035010286, -0.04325229, 0.02064148, -0.025382457, 0.039799888, 0.026743967, -0.03452403, 0.029928932, 0.03975126, -0.009621751, 0.032311574, 0.032676265, 0.022161024, 0.020994015, -0.025309518, -0.0139919575, -0.03000187, 0.026209088, -0.0051694876, 0.0020225125, -0.0152319055, 0.045391805, -0.011834206, -0.018793715, -0.020763043, -0.06870768, 0.039240696, 0.0027822843, -0.03296802, 0.060684495, -0.05659996, -0.02456798, -0.0027929212, 0.00087677664, 0.0046224515, -0.056843087, -0.020167382, 0.062240507, 0.021091266, 0.026209088, 0.02693847, -0.02640359, 0.0325547, 0.0048990087, 0.011110903, -0.0012680591, 0.05596783, 0.03941088, 0.009810174, -0.0029980596, -0.024446419, -0.0023264212, 0.05387694, 0.040407702, 0.0032092761, -0.014636244, -0.026841218, 0.11378343, -0.04181784, -0.022914717, -0.004321582, 0.012350851, -0.04038339, 0.026987094, 0.020617168, -0.020434823, 0.01162147, 0.04198803, 0.023328034, 0.064234145, 0.0048230314, 0.022647278, 0.0354236, -0.03452403, 0.048357956, 0.033016644, -0.064282775, 0.018757246, 0.07546661, 0.07731438, -0.010727978, 0.039240696, -0.012861418, 0.028032541, -0.03999439, 0.01951094, 0.048090518, -0.02847017, 0.039872825, 0.006661679, -0.07872452, 0.081836544, -0.04913596, -0.01675145, 0.06885356, 0.0453918 ...

# %%
import os
from llama_index.core import download_loader

# %%
# Here we are using the WikipediaReader to fetch data from Wikipedia
# Make sure you have the necessary packages installed:  

# Load the WikipediaReader
WikipediaReader = download_loader("WikipediaReader")
loader = WikipediaReader()

# Define the page you want to fetch
page_title = 'Guardians of the Galaxy Vol. 3'

# Load data from Wikipedia
documents = loader.load_data(pages=[page_title], auto_suggest=False)

# Prepare folder and filename
folder_name = 'wiki_data'
os.makedirs(folder_name, exist_ok=True)

# Clean filename (remove special characters, keep it safe)
safe_filename = page_title.replace(" ", "_").replace("/", "_") + ".txt"
file_path = os.path.join(folder_name, safe_filename)

# Save the text content
with open(file_path, "w", encoding="utf-8") as f:
    for doc in documents:
        f.write(doc.text + "\n\n")

print(f"Saved to: {file_path}")
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_10280\332848010.py:2: DeprecationWarning: Call to deprecated function (or staticmethod) download_loader. (`download_loader()` is deprecated. Please install tool using pip install directly instead.)
#   WikipediaReader = download_loader("WikipediaReader")
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): en.wikipedia.org:80
# DEBUG:urllib3.connectionpool:http://en.wikipedia.org:80 "GET /w/api.php?prop=info%7Cpageprops&inprop=url&ppprop=disambiguation&redirects=&titles=Guardians+of+the+Galaxy+Vol.+3&format=json&action=query HTTP/1.1" 301 0
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): en.wikipedia.org:443
# DEBUG:urllib3.connectionpool:https://en.wikipedia.org:443 "GET /w/api.php?prop=info%7Cpageprops&inprop=url&ppprop=disambiguation&redirects=&titles=Guardians+of+the+Galaxy+Vol.+3&format=json&action=query HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): en.wikipedia.org:80
# DEBUG:urllib3.connectionpool:http://en.wikipedia.org:80 "GET /w/api.php?prop=extracts%7Crevisions&explaintext=&rvprop=ids&titles=Guardians+of+the+Galaxy+Vol.+3&format=json&action=query HTTP/1.1" 301 0
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): en.wikipedia.org:443
# DEBUG:urllib3.connectionpool:https://en.wikipedia.org:443 "GET /w/api.php?prop=extracts%7Crevisions&explaintext=&rvprop=ids&titles=Guardians+of+the+Galaxy+Vol.+3&format=json&action=query HTTP/1.1" 200 None
# Saved to: wiki_data\Guardians_of_the_Galaxy_Vol._3.txt

# %%
from llama_index.llms.openai_like import OpenAILike
from llama_index.core.llms import ChatMessage

# %%
llm_qwen = OpenAILike(
  api_base="https://llms-inference.innkube.fim.uni-passau.de",
  api_key="enter the api key",
  model="qwen2.5")

# %%
# %%time
messages = [
    ChatMessage(
        role="system", content="You are a assitant that helps to provide knowledge and information."
    ),
    ChatMessage(role="user", content="Tell me more about Rocket"),
]
resp = llm_qwen.chat(messages)
# Out:
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/completions', 'files': None, 'idempotency_key': 'stainless-python-retry-2f7b942e-ca40-432f-93ba-b2e0f741f597', 'json_data': {'model': 'qwen2.5', 'prompt': 'system: You are a assitant that helps to provide knowledge and information.\nuser: Tell me more about Rocket\nassistant: ', 'stream': False, 'temperature': 0.1}}
# DEBUG:openai._base_client:Sending HTTP Request: POST https://llms-inference.innkube.fim.uni-passau.de/completions
# DEBUG:httpcore.connection:connect_tcp.started host='llms-inference.innkube.fim.uni-passau.de' port=443 local_address=None timeout=60.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x000001D143C43190>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x000001D143A558C0> server_hostname='llms-inference.innkube.fim.uni-passau.de' timeout=60.0
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x000001D143C33B80>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Sun, 13 Jul 2025 09:26:53 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'2551'), (b'Connection', b'keep-alive'), (b'x-litellm-call-id', b'b74dd23f-50a2-40e2-bb69-125638616095'), (b'x-litellm-model-id', b'4fc98ad04997d06d243fa1037a8527856cb537a73abc970ce37122958bbea148'), (b'x-litellm-model-api-base', b'http://qwen2-5-ollama:11434'), (b'x-litellm-version', b'1.42.2'), (b'x-litellm-response-cost', b'0.274761'), (b'x-litellm-key-tpm-limit', b'None'), (b'x-litellm-key-rpm-limit', b'100'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains'), (b'Access-Control-Allow-Origin', b'*'), (b'Access-Control-Allow-Credentials', b'true'), (b'Access-Control-Allow-Methods', b'PUT, GET, POST'), (b'Access-Control-Allow-Headers', b'DNT,Keep-Alive,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range,Authorization'), (b'Access-Control-Max-Age', b'1728000')])
# INFO:httpx:HTTP Request: POST https://llms-inference.innkube.fim.uni-passau.de/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Response: POST https://llms-inference.innkube.fim.uni-passau.de/completions "200 OK" Headers({'date': 'Sun, 13 Jul 2025 09:26:53 GMT', 'content-type': 'application/json', 'content-length': '2551', 'connection': 'keep-alive', 'x-litellm-call-id': 'b74dd23f-50a2-40e2-bb69-125638616095', 'x-litellm-model-id': '4fc98ad04997d06d243fa1037a8527856cb537a73abc970ce37122958bbea148', 'x-litellm-model-api-base': 'http://qwen2-5-ollama:11434', 'x-litellm-version': '1.42.2', 'x-litellm-response-cost': '0.274761', 'x-litellm-key-tpm-limit': 'None', 'x-litellm-key-rpm-limit': '100', 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'access-control-allow-origin': '*', 'access-control-allow-credentials': 'true', 'access-control-allow-methods': 'PUT, GET, POST', 'access-control-allow-headers': 'DNT,Keep-Alive,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range,Authorization', 'access-control-max-age': '1728000'})
# DEBUG:openai._base_client:request_id: None
# CPU times: total: 62.5 ms
# Wall time: 20.4 s

# %%
# Display the response 
print(resp.message.blocks[0].text)
# Out:
# Certainly! "Rocket" can refer to several different things, but most commonly it refers to a vehicle or device designed to be propelled by the ejection of gases produced by combustion. Here are some key points about rockets:
#
# 1. **Basic Principle**:
#    - Rockets operate on the principle of action and reaction (Newton's Third Law of Motion). The expulsion of gas from the rocket engine produces an equal and opposite force, propelling the rocket forward.
#
# 2. **Types of Rockets**:
#    - **Solid-Fuel Rockets**: Use a solid propellant that is ignited to produce thrust.
#    - **Liquid-Fuel Rockets**: Use liquid propellants, which are fed into the combustion chamber where they mix and burn.
#    - **Hybrid Rockets**: Combine elements of both solid and liquid fuel rockets.
#
# 3. **Uses**:
#    - **Space Exploration**: Rockets are essential for launching satellites, space probes, and crewed missions into space.
#    - **Military Applications**: Missiles and other military hardware often use rocket technology.
#    - **Scientific Research**: High-altitude research and atmospheric studies can be conducted using sounding rockets.
#
# 4. **Historical Development**:
#    - **Early Rockets**: The concept of rockets dates back to ancient China, where gunpowder was used in fireworks and early war rockets.
#    - **Modern Rockets**: Significant advancements were made during the 20th century, particularly by pioneers like Robert Goddard, Konstantin Tsiolkovsky, and Wernher von Braun.
#
# 5. **Notable Rockets**:
#    - **Saturn V**: The most powerful rocket ever built, used by NASA for the Apollo missions to the Moon.
#    - **Space Shuttle**: A partially reusable spacecraft that was operational from 1981 to 2011.
#    - **Falcon 9 and Falcon Heavy**: Developed by SpaceX, these rockets are known for their reusability and cost-effectiveness.
#
# 6. **Future Developments**:
#    - **Reusability**: Companies like SpaceX and Blue Origin are focusing on making rockets reusable to reduce the cost of space travel.
#    - **Advanced Propulsion Systems**: Research is ongoing into more efficient and powerful propulsion systems, such as nuclear thermal propulsion and ion drives.
#
# If you have a specific aspect of rockets you're interested in, feel free to ask!

# %%
from llama_index.graph_stores.neo4j import Neo4jGraphStore
from llama_index.core.storage.storage_context import StorageContext

# %%
# Initialize the Neo4jGraphStore with your Neo4j database credentials
# Make sure to replace the username, password, and URL with your actual Neo4j database

graph_store = Neo4jGraphStore(
    username="neo4j",
    password="neo4j123",
    url="bolt://localhost:7687",
    database="neo4j"
)

storage_context = StorageContext.from_defaults(graph_store=graph_store)
# Out:
# DEBUG:neo4j.pool:[#0000]  _: <POOL> created, direct address IPv4Address(('localhost', 7687))
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> routing towards fixed database: None
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> pinning database: None
# DEBUG:neo4j.pool:[#0000]  _: <POOL> acquire direct connection, access_mode='READ', database=AcquisitionDatabase(name=None, guessed=False)
# DEBUG:neo4j.pool:[#0000]  _: <POOL> trying to hand out new connection
# DEBUG:neo4j.io:[#0000]  _: <RESOLVE> in: localhost:7687
# DEBUG:neo4j.io:[#0000]  _: <RESOLVE> dns resolver out: [::1]:7687
# DEBUG:neo4j.io:[#0000]  C: <OPEN> [::1]:7687
# DEBUG:neo4j.io:[#0000]  S: <ERROR> ConnectionRefusedError 10061 'Es konnte keine Verbindung hergestellt werden, da der Zielcomputer die Verbindung verweigerte' None 10061 None
# DEBUG:neo4j.io:[#0000]  C: <CLOSE> [::1]:7687
# DEBUG:neo4j.io:[#0000]  S: <CONNECTION FAILED> [::1]:7687 ServiceUnavailable: Failed to establish connection to ResolvedIPv6Address(('::1', 7687, 0, 0)) (reason [WinError 10061] Es konnte keine Verbindung hergestellt werden, da der Zielcomputer die Verbindung verweigerte)
# DEBUG:neo4j.io:[#0000]  _: <RESOLVE> dns resolver out: 127.0.0.1:7687
# DEBUG:neo4j.io:[#0000]  C: <OPEN> 127.0.0.1:7687
# DEBUG:neo4j.io:[#CA7C]  C: <MAGIC> 0x6060B017
# DEBUG:neo4j.io:[#CA7C]  C: <HANDSHAKE> 0x000001FF 0x00080805 0x00020404 0x00000003
# DEBUG:neo4j.io:[#CA7C]  S: <HANDSHAKE> 0x00000605
# DEBUG:neo4j.io:[#CA7C]  C: HELLO {'user_agent': 'neo4j-python/5.28.1 Python/3.9.21-final-0 (win32)', 'bolt_agent': {'product': 'neo4j-python/5.28.1', 'platform': 'Windows 10; AMD64', 'language': 'Python/3.9.21-final-0', 'language_details': 'CPython; 3.9.21-final-0 (main, Apr  9 2025 09:02:40) [MSC v.1929 64 bit (AMD64)]'}}
# DEBUG:neo4j.io:[#CA7C]  _: <CONNECTION> client state: CONNECTED > AUTHENTICATION
# DEBUG:neo4j.io:[#CA7C]  C: LOGON {'scheme': 'basic', 'principal': 'neo4j', 'credentials': '*******'}
# DEBUG:neo4j.io:[#CA7C]  _: <CONNECTION> client state: AUTHENTICATION > READY
# DEBUG:neo4j.io:[#CA7C]  S: SUCCESS {'server': 'Neo4j/5.24.0', 'connection_id': 'bolt-6', 'hints': {'connection.recv_timeout_seconds': 120}}
# DEBUG:neo4j.io:[#CA7C]  _: <CONNECTION> server state: CONNECTED > AUTHENTICATION
# DEBUG:neo4j.io:[#CA7C]  S: SUCCESS {}
# DEBUG:neo4j.io:[#CA7C]  _: <CONNECTION> server state: AUTHENTICATION > READY
# DEBUG:neo4j.pool:[#CA7C]  _: <POOL> released bolt-6
# DEBUG:neo4j.pool:[#0000]  _: <POOL> close
# DEBUG:neo4j.io:[#CA7C]  C: GOODBYE
# DEBUG:neo4j.io:[#CA7C]  C: <CLOSE>
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> routing towards fixed database: neo4j
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> pinning database: 'neo4j'
# DEBUG:neo4j.pool:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database=AcquisitionDatabase(name='neo4j', guessed=False)
# DEBUG:neo4j.pool:[#0000]  _: <POOL> trying to hand out new connection
# DEBUG:neo4j.io:[#0000]  _: <RESOLVE> in: localhost:7687
# DEBUG:neo4j.io:[#0000]  _: <RESOLVE> dns resolver out: [::1]:7687
# DEBUG:neo4j.io:[#0000]  C: <OPEN> [::1]:7687
# DEBUG:neo4j.io:[#0000]  S: <ERROR> ConnectionRefusedError 10061 'Es konnte keine Verbindung hergestellt werden, da der Zielcomputer die Verbindung verweigerte' None 10061 None
# DEBUG:neo4j.io:[#0000]  C: <CLOSE> [::1]:7687
# DEBUG:neo4j.io:[#0000]  S: <CONNECTION FAILED> [::1]:7687 ServiceUnavailable: Failed to establish connection to ResolvedIPv6Address(('::1', 7687, 0, 0)) (reason [WinError 10061] Es konnte keine Verbindung hergestellt werden, da der Zielcomputer die Verbindung verweigerte)
# DEBUG:neo4j.io:[#0000]  _: <RESOLVE> dns resolver out: 127.0.0.1:7687
# DEBUG:neo4j.io:[#0000]  C: <OPEN> 127.0.0.1:7687
# DEBUG:neo4j.io:[#CA7E]  C: <MAGIC> 0x6060B017
# DEBUG:neo4j.io:[#CA7E]  C: <HANDSHAKE> 0x000001FF 0x00080805 0x00020404 0x00000003
# DEBUG:neo4j.io:[#CA7E]  S: <HANDSHAKE> 0x00000605
# DEBUG:neo4j.io:[#CA7E]  C: HELLO {'user_agent': 'neo4j-python/5.28.1 Python/3.9.21-final-0 (win32)', 'bolt_agent': {'product': 'neo4j-python/5.28.1', 'platform': 'Windows 10; AMD64', 'language': 'Python/3.9.21-final-0', 'language_details': 'CPython; 3.9.21-final-0 (main, Apr  9 2025 09:02:40) [MSC v.1929 64 bit (AMD64)]'}}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> client state: CONNECTED > AUTHENTICATION
# DEBUG:neo4j.io:[#CA7E]  C: LOGON {'scheme': 'basic', 'principal': 'neo4j', 'credentials': '*******'}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> client state: AUTHENTICATION > READY
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'server': 'Neo4j/5.24.0', 'connection_id': 'bolt-7', 'hints': {'connection.recv_timeout_seconds': 120}}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> server state: CONNECTED > AUTHENTICATION
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> server state: AUTHENTICATION > READY
# DEBUG:neo4j.io:[#CA7E]  C: BEGIN {'db': 'neo4j'}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> client state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#CA7E]  C: RUN '\nCALL apoc.meta.data()\nYIELD label, other, elementType, type, property\nWHERE NOT type = "RELATIONSHIP" AND elementType = "node"\nWITH label AS nodeLabels, collect({property:property, type:type}) AS properties\nRETURN {labels: nodeLabels, properties: properties} AS output\n\n' {} {}
# DEBUG:neo4j.io:[#CA7E]  C: PULL {'n': 1000}
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> server state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'t_first': 274, 'fields': ['output'], 'qid': 0}
# DEBUG:neo4j.io:[#CA7E]  S: RECORD * 1
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'statuses': [{'gql_status': '00000', 'status_description': 'note: successful completion'}], 'type': 'r', 't_last': 144, 'db': 'neo4j'}
# DEBUG:neo4j.io:[#CA7E]  C: COMMIT
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> client state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'bookmark': 'FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAiJA='}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> server state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> released bolt-7
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> routing towards fixed database: neo4j
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> pinning database: 'neo4j'
# DEBUG:neo4j.pool:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database=AcquisitionDatabase(name='neo4j', guessed=False)
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> picked existing connection bolt-7
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> handing out existing connection
# DEBUG:neo4j.io:[#CA7E]  C: BEGIN {'db': 'neo4j', 'bookmarks': ['FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAiJA=']}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> client state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#CA7E]  C: RUN '\nCALL apoc.meta.data()\nYIELD label, other, elementType, type, property\nWHERE NOT type = "RELATIONSHIP" AND elementType = "relationship"\nWITH label AS nodeLabels, collect({property:property, type:type}) AS properties\nRETURN {type: nodeLabels, properties: properties} AS output\n' {} {}
# DEBUG:neo4j.io:[#CA7E]  C: PULL {'n': 1000}
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> server state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'t_first': 158, 'fields': ['output'], 'qid': 0}
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'statuses': [{'gql_status': '02000', 'status_description': 'note: no data'}], 'type': 'r', 't_last': 38, 'db': 'neo4j'}
# DEBUG:neo4j.io:[#CA7E]  C: COMMIT
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> client state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'bookmark': 'FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAiJA='}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> server state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> released bolt-7
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> routing towards fixed database: neo4j
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> pinning database: 'neo4j'
# DEBUG:neo4j.pool:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database=AcquisitionDatabase(name='neo4j', guessed=False)
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> picked existing connection bolt-7
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> handing out existing connection
# DEBUG:neo4j.io:[#CA7E]  C: BEGIN {'db': 'neo4j', 'bookmarks': ['FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAiJA=']}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> client state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#CA7E]  C: RUN '\nCALL apoc.meta.data()\nYIELD label, other, elementType, type, property\nWHERE type = "RELATIONSHIP" AND elementType = "node"\nUNWIND other AS other_node\nRETURN {start: label, type: property, end: toString(other_node)} AS output\n' {} {}
# DEBUG:neo4j.io:[#CA7E]  C: PULL {'n': 1000}
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> server state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'t_first': 176, 'fields': ['output'], 'qid': 0}
# DEBUG:neo4j.io:[#CA7E]  S: RECORD * 1
# DEBUG:neo4j.io:[#CA7E]  S: RECORD * 1
# DEBUG:neo4j.io:[#CA7E]  S: RECORD * 1
# DEBUG:neo4j.io:[#CA7E]  S: RECORD * 1
# DEBUG:neo4j.io:[#CA7E]  S: RECORD * 1
# DEBUG:neo4j.io:[#CA7E]  S: RECORD * 1
# DEBUG:neo4j.io:[#CA7E]  S: RECORD * 1
# DEBUG:neo4j.io:[#CA7E]  S: RECORD * 1
# DEBUG:neo4j.io:[#CA7E]  S: RECORD * 1
# DEBUG:neo4j.io:[#CA7E]  S: RECORD * 1
# DEBUG:neo4j.io:[#CA7E]  S: RECORD * 1
# DEBUG:neo4j.io:[#CA7E]  S: RECORD * 1
# DEBUG:neo4j.io:[#CA7E]  S: RECORD * 1
# DEBUG:neo4j.io:[#CA7E]  S: RECORD * 1
# DEBUG:neo4j.io:[#CA7E]  S: RECORD * 1
# DEBUG:neo4j.io:[#CA7E]  S: RECORD * 1
# DEBUG:neo4j.io:[#CA7E]  S: RECORD * 1
# DEBUG:neo4j.io:[#CA7E]  S: RECORD * 1
# DEBUG:neo4j.io:[#CA7E]  S: RECORD * 1
# DEBUG:neo4j.io:[#CA7E]  S: RECORD * 1
# DEBUG:neo4j.io:[#CA7E]  S: RECORD * 1
# DEBUG:neo4j.io:[#CA7E]  S: RECORD * 1
# DEBUG:neo4j.io:[#CA7E]  S: RECORD * 1
# DEBUG:neo4j.io:[#CA7E]  S: RECORD * 1
# DEBUG:neo4j.io:[#CA7E]  S: RECORD * 1
# DEBUG:neo4j.io:[#CA7E]  S: RECORD * 1
# DEBUG:neo4j.io:[#CA7E]  S: RECORD * 1
# DEBUG:neo4j.io:[#CA7E]  S: RECORD * 1
# DEBUG:neo4j.io:[#CA7E]  S: RECORD * 1
# DEBUG:neo4j.io:[#CA7E]  S: RECORD * 1
# DEBUG:neo4j.io:[#CA7E]  S: RECORD * 1
# DEBUG:neo4j.io:[#CA7E]  S: RECORD * 1
# DEBUG:neo4j.io:[#CA7E]  S: RECORD * 1
# DEBUG:neo4j.io:[#CA7E]  S: RECORD * 1
# DEBUG:neo4j.io:[#CA7E]  S: RECORD * 1
# DEBUG:neo4j.io:[#CA7E]  S: RECORD * 1
# DEBUG:neo4j.io:[#CA7E]  S: RECORD * 1
# DEBUG:neo4j.io:[#CA7E]  S: RECORD * 1
# DEBUG:neo4j.io:[#CA7E]  S: RECORD * 1
# DEBUG:neo4j.io:[#CA7E]  S: RECORD * 1
# DEBUG:neo4j.io:[#CA7E]  S: RECORD * 1
# DEBUG:neo4j.io:[#CA7E]  S: RECORD * 1
# DEBUG:neo4j.io:[#CA7E]  S: RECORD * 1
# DEBUG:neo4j.io:[#CA7E]  S: RECORD * 1
# DEBUG:neo4j.io:[#CA7E]  S: RECORD * 1
# DEBUG:neo4j.io:[#CA7E]  S: RECORD * 1
# DEBUG:neo4j.io:[#CA7E]  S: RECORD * 1
# DEBUG:neo4j.io:[#CA7E]  S: RECORD * 1
# DEBUG:neo4j.io:[#CA7E]  S: RECORD * 1
# DEBUG:neo4j.io:[#CA7E]  S: RECORD * 1
# DEBUG:neo4j.io:[#CA7E]  S: RECORD * 1
# DEBUG:neo4j.io:[#CA7E]  S: RECORD * 1
# DEBUG:neo4j.io:[#CA7E]  S: RECORD * 1
# DEBUG:neo4j.io:[#CA7E]  S: RECORD * 1
# DEBUG:neo4j.io:[#CA7E]  S: RECORD * 1
# DEBUG:neo4j.io:[#CA7E]  S: RECORD * 1
# DEBUG:neo4j.io:[#CA7E]  S: RECORD * 1
# DEBUG:neo4j.io:[#CA7E]  S: RECORD * 1
# DEBUG:neo4j.io:[#CA7E]  S: RECORD * 1
# DEBUG:neo4j.io:[#CA7E]  S: RECORD * 1
# DEBUG:neo4j.io:[#CA7E]  S: RECORD * 1
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'statuses': [{'gql_status': '00000', 'status_description': 'note: successful completion'}], 'type': 'r', 't_last': 37, 'db': 'neo4j'}
# DEBUG:neo4j.io:[#CA7E]  C: COMMIT
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> client state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'bookmark': 'FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAiJA='}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> server state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> released bolt-7
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> routing towards fixed database: neo4j
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> pinning database: 'neo4j'
# DEBUG:neo4j.pool:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database=AcquisitionDatabase(name='neo4j', guessed=False)
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> picked existing connection bolt-7
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> handing out existing connection
# DEBUG:neo4j.io:[#CA7E]  C: BEGIN {'db': 'neo4j', 'bookmarks': ['FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAiJA=']}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> client state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#CA7E]  C: RUN '\n                CREATE CONSTRAINT IF NOT EXISTS FOR (n:Entity) REQUIRE n.id IS UNIQUE;\n                ' {} {}
# DEBUG:neo4j.io:[#CA7E]  C: PULL {'n': 1000}
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> server state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'t_first': 99, 'fields': [], 'qid': 0}
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'statuses': [{'gql_status': '00NA0', 'neo4j_code': 'Neo.ClientNotification.Schema.IndexOrConstraintAlreadyExists', 'status_description': 'note: successful completion - index or constraint already exists. `CREATE CONSTRAINT IF NOT EXISTS FOR (e:Entity) REQUIRE (e.id) IS UNIQUE` has no effect. `CONSTRAINT constraint_1ed05907 FOR (e:Entity) REQUIRE (e.id) IS UNIQUE` already exists.', 'diagnostic_record': {'_classification': 'SCHEMA', '_status_parameters': {'cmd': 'CREATE CONSTRAINT IF NOT EXISTS FOR (e:Entity) REQUIRE (e.id) IS UNIQUE', 'indexConstrPat': 'CONSTRAINT constraint_1ed05907 FOR (e:Entity) REQUIRE (e.id) IS UNIQUE'}, '_severity': 'INFORMATION'}, 'description': '`CONSTRAINT constraint_1ed05907 FOR (e:Entity) REQUIRE (e.id) IS UNIQUE` already exists.', 'title': '`CREATE CONSTRAINT IF NOT EXISTS FOR (e:Entity) REQUIRE (e.id) IS UNIQUE` has no effect.'}, {'gql_status': '00001', 'status_description': 'note: successful completion - omitted result'}], 'type': 's', 't_last': 0, 'db': 'neo4j'}
# INFO:neo4j.notifications:Received notification from DBMS server: {severity: INFORMATION} {code: Neo.ClientNotification.Schema.IndexOrConstraintAlreadyExists} {category: SCHEMA} {title: `CREATE CONSTRAINT IF NOT EXISTS FOR (e:Entity) REQUIRE (e.id) IS UNIQUE` has no effect.} {description: `CONSTRAINT constraint_1ed05907 FOR (e:Entity) REQUIRE (e.id) IS UNIQUE` already exists.} {position: None} for query: '\n                CREATE CONSTRAINT IF NOT EXISTS FOR (n:Entity) REQUIRE n.id IS UNIQUE;\n                '
# DEBUG:neo4j.io:[#CA7E]  C: COMMIT
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> client state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'bookmark': 'FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAiJA='}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> server state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> released bolt-7

# %%
# checking the available methods and attributes of the Neo4jGraphStore and NebulaGraphStore
print(dir(Neo4jGraphStore))
print(dir(NebulaGraphStore))
# Out:
# ['__abstractmethods__', '__annotations__', '__class__', '__class_getitem__', '__del__', '__delattr__', '__dict__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__parameters__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_is_protocol', '_is_runtime_protocol', 'client', 'close', 'delete', 'get', 'get_rel_map', 'get_schema', 'persist', 'query', 'refresh_schema', 'schema', 'upsert_triplet']
# ['__abstractmethods__', '__annotations__', '__class__', '__class_getitem__', '__del__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__parameters__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_get_vid_type', '_is_protocol', '_is_runtime_protocol', 'client', 'config_dict', 'delete', 'execute', 'from_dict', 'get', 'get_flat_rel_map', 'get_rel_map', 'get_schema', 'init_session_pool', 'persist', 'query', 'refresh_schema', 'schema', 'upsert_triplet']

# %%
# Set global settings (optional, if not passed locally)
# We are using the embedding model and LLM defined above embed_model_snow
Settings.llm = llm_qwen
Settings.embed_model = embed_model_snow
Settings.chunk_size = 512

# %%
# %%time
# NOTE: can take a while!
# Create a KnowledgeGraphIndex from the documents
# This will create a knowledge graph index from the documents using the specified storage context
index = KnowledgeGraphIndex.from_documents(
    documents,
    storage_context=storage_context,
    max_triplets_per_chunk=2,
)
# Out:
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: Guardians of the Galaxy Vol. 3 (marketed as Gua...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: His return was publicly revealed in March 2019,...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: The Guardians travel to Orgocorp's headquarters...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: They are followed by Ayesha and Adam after the ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: The other Guardians orchestrate a rescue, which...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: The new Guardians—Rocket, Groot, Kraglin, Cosmo...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: Dave Bautista as Drax the Destroyer:A member of...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: Pom Klementieff as Mantis: A member of the Guar...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: Poulter believed there was "a lot of comedy" in...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: Gunn likened the High Evolutionary to "a space ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: Maria Bakalova reprises her voice and motion ca...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: Cameo appearances in the film include Lloyd Kau...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: In March 2017, Gunn said there would be a third...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 3 shortly after completing his work as executiv...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: In April, Chris Pratt was set to reprise his ro...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: My days saying something just because it's shoc...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: Despite this and the notable "vociferous suppor...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: for their rival superhero franchise, the DC Ext...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: At the end of the month, Cooper was asked if he...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: By the end of April, the franchise's five main ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: In June, Saldaña was asked about her role in th...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: In April, Gunn said the COVID-19 pandemic would...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 3, since he never planned to feature Thor in th...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: By late August, Gunn and Marvel Studios began m...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: Poulter was cast as Adam Warlock in October, an...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 3 set and crew to film Ezra Miller's cameo appe...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 3, given the tonal difference between the two w...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: == Music ==
#
# In April 2017, Gunn felt the music...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: == Marketing ==
#
# The film was discussed during ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: Hermanns also said the second trailer "goes a s...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: === Home media ===
# Guardians of the Galaxy Vol....
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: === Home media ===
# Guardians of the Galaxy Vol....
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: === Critical response ===
# The review aggregator...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: Matt Singer from ScreenCrush praised the film f...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: A negative review from NPR criticized the appro...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: == Notes ==
#
#
# == References ==
#
#
# == External li...
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/completions', 'files': None, 'idempotency_key': 'stainless-python-retry-ee677a4a-f68d-44ee-a85d-fc666da994dd', 'json_data': {'model': 'qwen2.5', 'prompt': "Some text is provided below. Given the text, extract up to 2 knowledge triplets in the form of (subject, predicate, object). Avoid stopwords.\n---------------------\nExample:Text: Alice is Bob's mother.Triplets:\n(Alice, is mother of, Bob)\nText: Philz is a coffee shop founded in Berkeley in 1982.\nTriplets:\n(Philz, is, coffee shop)\n(Philz, founded in, Berkeley)\n(Philz, founded in, 1982)\n---------------------\nText: Guardians of the Galaxy Vol. 3 (marketed as Guardians of the Galaxy Volume 3) is a 2023 American superhero film based on the Marvel Comics superhero team Guardians of the Galaxy, produced by Marvel Studios and distributed by Walt Disney Studios Motion Pictures. It is the sequel to Guardians of the Galaxy (2014) and Guardians of the Galaxy Vol. 2 (2017), and the 32nd film in the Marvel Cinematic Universe (MCU). Written and directed by James Gunn, it features an ensemble cast including Chris Pratt, Zoe Saldaña, Dave Bautista, Karen Gillan, Pom Klementieff, Vin Diesel, Bradley Cooper, Will Poulter, Sean Gunn, Chukwudi Iwuji, Linda Cardellini, Nathan Fillion, and Sylvester Stallone. In the film, the other Guardians race to save the life of Rocket (Cooper) from his creator, the High Evolutionary (Iwuji), who is an alien scientist trying to perfect the universe.\nGunn had initial ideas for a third and final Guardians of the Galaxy film by November 2014, and announced his return to write and direct in April 2017 ahead of Vol. 2's release. Vol. 3 explores the origin story of Rocket, with whom Gunn personally identifies. Disney fired Gunn from Vol. 3 in July 2018 after controversial jokes he made on Twitter resurfaced. Gunn received support from several cast members, and the studio reversed course by that October. His return was publicly revealed in March 2019, and he restarted work on the film after completing his film The Suicide Squad (2021) and the first season of its spin-off series Peacemaker (2022) for DC Films. New cast members, including Iwuji and Poulter, joined by the start of filming, which took place at Trilith Studios in Atlanta, Georgia, from November 2021 to May 2022.\nGuardians of the Galaxy Vol. 3 premiered at Disneyland Paris on April 22, 2023, and was released in the United States on May 5, as part of Phase Five of the MCU. Like its predecessors, it was a critical and commercial success, with many deeming it to be a satisfactory conclusion to the trilogy. It grossed over $845.6 million worldwide, becoming the fourth-highest-grossing film of 2023.\nTriplets:\n", 'stream': False, 'temperature': 0.1}}
# DEBUG:openai._base_client:Sending HTTP Request: POST https://llms-inference.innkube.fim.uni-passau.de/completions
# DEBUG:httpcore.connection:close.started
# DEBUG:httpcore.connection:close.complete
# DEBUG:httpcore.connection:connect_tcp.started host='llms-inference.innkube.fim.uni-passau.de' port=443 local_address=None timeout=60.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x000001D14B5C8CA0>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x000001D143A558C0> server_hostname='llms-inference.innkube.fim.uni-passau.de' timeout=60.0
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x000001D14B5C8C70>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Sun, 13 Jul 2025 09:30:35 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'405'), (b'Connection', b'keep-alive'), (b'x-litellm-call-id', b'45aa8746-458c-4950-8c3e-6f31b5c4ac79'), (b'x-litellm-model-id', b'4fc98ad04997d06d243fa1037a8527856cb537a73abc970ce37122958bbea148'), (b'x-litellm-model-api-base', b'http://qwen2-5-ollama:11434'), (b'x-litellm-version', b'1.42.2'), (b'x-litellm-response-cost', b'0.30311799999999994'), (b'x-litellm-key-tpm-limit', b'None'), (b'x-litellm-key-rpm-limit', b'100'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains'), (b'Access-Control-Allow-Origin', b'*'), (b'Access-Control-Allow-Credentials', b'true'), (b'Access-Control-Allow-Methods', b'PUT, GET, POST'), (b'Access-Control-Allow-Headers', b'DNT,Keep-Alive,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range,Authorization'), (b'Access-Control-Max-Age', b'1728000')])
# INFO:httpx:HTTP Request: POST https://llms-inference.innkube.fim.uni-passau.de/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Response: POST https://llms-inference.innkube.fim.uni-passau.de/completions "200 OK" Headers({'date': 'Sun, 13 Jul 2025 09:30:35 GMT', 'content-type': 'application/json', 'content-length': '405', 'connection': 'keep-alive', 'x-litellm-call-id': '45aa8746-458c-4950-8c3e-6f31b5c4ac79', 'x-litellm-model-id': '4fc98ad04997d06d243fa1037a8527856cb537a73abc970ce37122958bbea148', 'x-litellm-model-api-base': 'http://qwen2-5-ollama:11434', 'x-litellm-version': '1.42.2', 'x-litellm-response-cost': '0.30311799999999994', 'x-litellm-key-tpm-limit': 'None', 'x-litellm-key-rpm-limit': '100', 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'access-control-allow-origin': '*', 'access-control-allow-credentials': 'true', 'access-control-allow-methods': 'PUT, GET, POST', 'access-control-allow-headers': 'DNT,Keep-Alive,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range,Authorization', 'access-control-max-age': '1728000'})
# DEBUG:openai._base_client:request_id: None
# DEBUG:llama_index.core.indices.knowledge_graph.base:> Extracted triplets: [('Guardians of the galaxy vol. 3', 'Is', 'Superhero film'), ('Guardians of the galaxy vol. 3', 'Produced by', 'Marvel studios')]
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> routing towards fixed database: neo4j
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> pinning database: 'neo4j'
# DEBUG:neo4j.pool:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database=AcquisitionDatabase(name='neo4j', guessed=False)
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> picked existing connection bolt-7
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> handing out existing connection
# DEBUG:neo4j.io:[#CA7E]  C: RUN '\n            MERGE (n1:`Entity` {id:$subj})\n            MERGE (n2:`Entity` {id:$obj})\n            MERGE (n1)-[:`IS`]->(n2)\n        ' {'subj': 'Guardians of the galaxy vol. 3', 'obj': 'Superhero film'} {'db': 'neo4j'}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> client state: READY > STREAMING
# DEBUG:neo4j.io:[#CA7E]  C: PULL {'n': 1000}
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'t_first': 628, 'fields': []}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'bookmark': 'FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAiJA=', 'statuses': [{'gql_status': '00001', 'status_description': 'note: successful completion - omitted result'}], 'type': 'w', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> released bolt-7
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> routing towards fixed database: neo4j
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> pinning database: 'neo4j'
# DEBUG:neo4j.pool:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database=AcquisitionDatabase(name='neo4j', guessed=False)
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> picked existing connection bolt-7
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> handing out existing connection
# DEBUG:neo4j.io:[#CA7E]  C: RUN '\n            MERGE (n1:`Entity` {id:$subj})\n            MERGE (n2:`Entity` {id:$obj})\n            MERGE (n1)-[:`PRODUCED_BY`]->(n2)\n        ' {'subj': 'Guardians of the galaxy vol. 3', 'obj': 'Marvel studios'} {'db': 'neo4j'}
# DEBUG:neo4j.io:[#CA7E]  C: PULL {'n': 1000}
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'t_first': 169, 'fields': []}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'bookmark': 'FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAiJA=', 'statuses': [{'gql_status': '00001', 'status_description': 'note: successful completion - omitted result'}], 'type': 'w', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> released bolt-7
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/completions', 'files': None, 'idempotency_key': 'stainless-python-retry-88bac7fb-4aca-4c28-b0c4-480a15eaf5c1', 'json_data': {'model': 'qwen2.5', 'prompt': 'Some text is provided below. Given the text, extract up to 2 knowledge triplets in the form of (subject, predicate, object). Avoid stopwords.\n---------------------\nExample:Text: Alice is Bob\'s mother.Triplets:\n(Alice, is mother of, Bob)\nText: Philz is a coffee shop founded in Berkeley in 1982.\nTriplets:\n(Philz, is, coffee shop)\n(Philz, founded in, Berkeley)\n(Philz, founded in, 1982)\n---------------------\nText: His return was publicly revealed in March 2019, and he restarted work on the film after completing his film The Suicide Squad (2021) and the first season of its spin-off series Peacemaker (2022) for DC Films. New cast members, including Iwuji and Poulter, joined by the start of filming, which took place at Trilith Studios in Atlanta, Georgia, from November 2021 to May 2022.\nGuardians of the Galaxy Vol. 3 premiered at Disneyland Paris on April 22, 2023, and was released in the United States on May 5, as part of Phase Five of the MCU. Like its predecessors, it was a critical and commercial success, with many deeming it to be a satisfactory conclusion to the trilogy. It grossed over $845.6 million worldwide, becoming the fourth-highest-grossing film of 2023. At the 96th Academy Awards, the film was nominated for Best Visual Effects.\n\n\n== Plot ==\nAt their new headquarters on Knowhere, the Guardians of the Galaxy are attacked by Adam Warlock, a Sovereign warrior created by High Priestess Ayesha who seeks to destroy them for stealing from her. After critically wounding Rocket, Adam is stabbed by Nebula and flees. The Guardians\' med-packs are ineffective at healing Rocket\'s wounds due to a kill switch embedded in him by the organization Orgocorp. The Guardians travel to Orgocorp\'s headquarters to find the switch\'s override code and save Rocket\'s life.\nAs Rocket lies dying, he recalls his past. He was found and experimented on as a baby raccoon by the High Evolutionary, leader of Orgocorp, who aimed to enhance and anthropomorphize animal lifeforms into "Humanimals" for an ideal society, Counter-Earth. Rocket\'s fellow Batch 89 test subjects included the otter Lylla, walrus Teefs, and rabbit Floor. Impressed by Rocket\'s intelligence, the High Evolutionary used his insights to improve later batches of Humanimals. Angry that one of his creations could solve a problem that he could not, the High Evolutionary planned to harvest Rocket\'s brain and incinerate all of Batch 89. Rocket tried to rescue his friends, but the High Evolutionary killed Lylla and mocked Rocket\'s grief.\nTriplets:\n', 'stream': False, 'temperature': 0.1}}
# DEBUG:openai._base_client:Sending HTTP Request: POST https://llms-inference.innkube.fim.uni-passau.de/completions
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Sun, 13 Jul 2025 09:30:38 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'416'), (b'Connection', b'keep-alive'), (b'x-litellm-call-id', b'3c57f904-41cf-45d3-93b5-0f9db18181aa'), (b'x-litellm-model-id', b'4fc98ad04997d06d243fa1037a8527856cb537a73abc970ce37122958bbea148'), (b'x-litellm-model-api-base', b'http://qwen2-5-ollama:11434'), (b'x-litellm-version', b'1.42.2'), (b'x-litellm-response-cost', b'0.290166'), (b'x-litellm-key-tpm-limit', b'None'), (b'x-litellm-key-rpm-limit', b'100'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains'), (b'Access-Control-Allow-Origin', b'*'), (b'Access-Control-Allow-Credentials', b'true'), (b'Access-Control-Allow-Methods', b'PUT, GET, POST'), (b'Access-Control-Allow-Headers', b'DNT,Keep-Alive,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range,Authorization'), (b'Access-Control-Max-Age', b'1728000')])
# INFO:httpx:HTTP Request: POST https://llms-inference.innkube.fim.uni-passau.de/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Response: POST https://llms-inference.innkube.fim.uni-passau.de/completions "200 OK" Headers({'date': 'Sun, 13 Jul 2025 09:30:38 GMT', 'content-type': 'application/json', 'content-length': '416', 'connection': 'keep-alive', 'x-litellm-call-id': '3c57f904-41cf-45d3-93b5-0f9db18181aa', 'x-litellm-model-id': '4fc98ad04997d06d243fa1037a8527856cb537a73abc970ce37122958bbea148', 'x-litellm-model-api-base': 'http://qwen2-5-ollama:11434', 'x-litellm-version': '1.42.2', 'x-litellm-response-cost': '0.290166', 'x-litellm-key-tpm-limit': 'None', 'x-litellm-key-rpm-limit': '100', 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'access-control-allow-origin': '*', 'access-control-allow-credentials': 'true', 'access-control-allow-methods': 'PUT, GET, POST', 'access-control-allow-headers': 'DNT,Keep-Alive,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range,Authorization', 'access-control-max-age': '1728000'})
# DEBUG:openai._base_client:request_id: None
# DEBUG:llama_index.core.indices.knowledge_graph.base:> Extracted triplets: [('Guardians of the galaxy vol. 3', 'Premiered at', 'Disneyland paris'), ('Guardians of the galaxy vol. 3', 'Released in', 'United states')]
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> routing towards fixed database: neo4j
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> pinning database: 'neo4j'
# DEBUG:neo4j.pool:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database=AcquisitionDatabase(name='neo4j', guessed=False)
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> picked existing connection bolt-7
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> handing out existing connection
# DEBUG:neo4j.io:[#CA7E]  C: RUN '\n            MERGE (n1:`Entity` {id:$subj})\n            MERGE (n2:`Entity` {id:$obj})\n            MERGE (n1)-[:`PREMIERED_AT`]->(n2)\n        ' {'subj': 'Guardians of the galaxy vol. 3', 'obj': 'Disneyland paris'} {'db': 'neo4j'}
# DEBUG:neo4j.io:[#CA7E]  C: PULL {'n': 1000}
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'t_first': 176, 'fields': []}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'bookmark': 'FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAiJA=', 'statuses': [{'gql_status': '00001', 'status_description': 'note: successful completion - omitted result'}], 'type': 'w', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> released bolt-7
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> routing towards fixed database: neo4j
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> pinning database: 'neo4j'
# DEBUG:neo4j.pool:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database=AcquisitionDatabase(name='neo4j', guessed=False)
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> picked existing connection bolt-7
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> handing out existing connection
# DEBUG:neo4j.io:[#CA7E]  C: RUN '\n            MERGE (n1:`Entity` {id:$subj})\n            MERGE (n2:`Entity` {id:$obj})\n            MERGE (n1)-[:`RELEASED_IN`]->(n2)\n        ' {'subj': 'Guardians of the galaxy vol. 3', 'obj': 'United states'} {'db': 'neo4j'}
# DEBUG:neo4j.io:[#CA7E]  C: PULL {'n': 1000}
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'t_first': 167, 'fields': []}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'bookmark': 'FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAiJA=', 'statuses': [{'gql_status': '00001', 'status_description': 'note: successful completion - omitted result'}], 'type': 'w', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> released bolt-7
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/completions', 'files': None, 'idempotency_key': 'stainless-python-retry-a7d43bb4-b564-4abf-8534-b1b4fdd27559', 'json_data': {'model': 'qwen2.5', 'prompt': 'Some text is provided below. Given the text, extract up to 2 knowledge triplets in the form of (subject, predicate, object). Avoid stopwords.\n---------------------\nExample:Text: Alice is Bob\'s mother.Triplets:\n(Alice, is mother of, Bob)\nText: Philz is a coffee shop founded in Berkeley in 1982.\nTriplets:\n(Philz, is, coffee shop)\n(Philz, founded in, Berkeley)\n(Philz, founded in, 1982)\n---------------------\nText: The Guardians travel to Orgocorp\'s headquarters to find the switch\'s override code and save Rocket\'s life.\nAs Rocket lies dying, he recalls his past. He was found and experimented on as a baby raccoon by the High Evolutionary, leader of Orgocorp, who aimed to enhance and anthropomorphize animal lifeforms into "Humanimals" for an ideal society, Counter-Earth. Rocket\'s fellow Batch 89 test subjects included the otter Lylla, walrus Teefs, and rabbit Floor. Impressed by Rocket\'s intelligence, the High Evolutionary used his insights to improve later batches of Humanimals. Angry that one of his creations could solve a problem that he could not, the High Evolutionary planned to harvest Rocket\'s brain and incinerate all of Batch 89. Rocket tried to rescue his friends, but the High Evolutionary killed Lylla and mocked Rocket\'s grief. Enraged, Rocket attacked the High Evolutionary while henchmen killed Teefs and Floor during the chaos. Rocket kills the henchmen and then escapes in a spaceship.\nIn the present, an alternate version of Gamora, who has joined the Ravagers, helps the Guardians infiltrate Orgocorp. They retrieve Rocket\'s file but discover that Theel, one of the High Evolutionary\'s advisors, has removed the override code. The Guardians and Gamora travel to Counter-Earth to find him. They are followed by Ayesha and Adam after the High Evolutionary, their race\'s creator, threatened to wipe out the Sovereign if they failed to retrieve Rocket. At Counter-Earth, Drax and Mantis remain with Gamora and Rocket while Peter Quill, Groot, and Nebula go to the High Evolutionary\'s Arête Laboratories complex. Guards force Nebula to wait outside due to her cybernetic enhancements; Quill and Groot enter Arête. Drax tricks Mantis into pursuing Quill\'s group and Gamora saves Rocket from Adam and War Pig, one of the High Evolutionary\'s Hellspawn guards.\nThe High Evolutionary agrees with Quill that Counter-Earth is imperfect and begins bombarding the entire planet, killing the Humanimals and Ayesha. Arête, which is actually a spaceship, departs as Nebula, Drax, and Mantis board it to rescue Quill and Groot.\nTriplets:\n', 'stream': False, 'temperature': 0.1}}
# DEBUG:openai._base_client:Sending HTTP Request: POST https://llms-inference.innkube.fim.uni-passau.de/completions
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Sun, 13 Jul 2025 09:30:41 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'389'), (b'Connection', b'keep-alive'), (b'x-litellm-call-id', b'a1c45f76-89d1-4ec0-bc92-accf4a8b7873'), (b'x-litellm-model-id', b'4fc98ad04997d06d243fa1037a8527856cb537a73abc970ce37122958bbea148'), (b'x-litellm-model-api-base', b'http://qwen2-5-ollama:11434'), (b'x-litellm-version', b'1.42.2'), (b'x-litellm-response-cost', b'0.27874999999999994'), (b'x-litellm-key-tpm-limit', b'None'), (b'x-litellm-key-rpm-limit', b'100'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains'), (b'Access-Control-Allow-Origin', b'*'), (b'Access-Control-Allow-Credentials', b'true'), (b'Access-Control-Allow-Methods', b'PUT, GET, POST'), (b'Access-Control-Allow-Headers', b'DNT,Keep-Alive,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range,Authorization'), (b'Access-Control-Max-Age', b'1728000')])
# INFO:httpx:HTTP Request: POST https://llms-inference.innkube.fim.uni-passau.de/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Response: POST https://llms-inference.innkube.fim.uni-passau.de/completions "200 OK" Headers({'date': 'Sun, 13 Jul 2025 09:30:41 GMT', 'content-type': 'application/json', 'content-length': '389', 'connection': 'keep-alive', 'x-litellm-call-id': 'a1c45f76-89d1-4ec0-bc92-accf4a8b7873', 'x-litellm-model-id': '4fc98ad04997d06d243fa1037a8527856cb537a73abc970ce37122958bbea148', 'x-litellm-model-api-base': 'http://qwen2-5-ollama:11434', 'x-litellm-version': '1.42.2', 'x-litellm-response-cost': '0.27874999999999994', 'x-litellm-key-tpm-limit': 'None', 'x-litellm-key-rpm-limit': '100', 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'access-control-allow-origin': '*', 'access-control-allow-credentials': 'true', 'access-control-allow-methods': 'PUT, GET, POST', 'access-control-allow-headers': 'DNT,Keep-Alive,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range,Authorization', 'access-control-max-age': '1728000'})
# DEBUG:openai._base_client:request_id: None
# DEBUG:llama_index.core.indices.knowledge_graph.base:> Extracted triplets: [('Rocket', 'Found and experimented on by', 'High evolutionary'), ('High evolutionary', 'Leader of', 'Orgocorp')]
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> routing towards fixed database: neo4j
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> pinning database: 'neo4j'
# DEBUG:neo4j.pool:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database=AcquisitionDatabase(name='neo4j', guessed=False)
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> picked existing connection bolt-7
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> handing out existing connection
# DEBUG:neo4j.io:[#CA7E]  C: RUN '\n            MERGE (n1:`Entity` {id:$subj})\n            MERGE (n2:`Entity` {id:$obj})\n            MERGE (n1)-[:`FOUND_AND_EXPERIMENTED_ON_BY`]->(n2)\n        ' {'subj': 'Rocket', 'obj': 'High evolutionary'} {'db': 'neo4j'}
# DEBUG:neo4j.io:[#CA7E]  C: PULL {'n': 1000}
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'t_first': 169, 'fields': []}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'bookmark': 'FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAiJA=', 'statuses': [{'gql_status': '00001', 'status_description': 'note: successful completion - omitted result'}], 'type': 'w', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> released bolt-7
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> routing towards fixed database: neo4j
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> pinning database: 'neo4j'
# DEBUG:neo4j.pool:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database=AcquisitionDatabase(name='neo4j', guessed=False)
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> picked existing connection bolt-7
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> handing out existing connection
# DEBUG:neo4j.io:[#CA7E]  C: RUN '\n            MERGE (n1:`Entity` {id:$subj})\n            MERGE (n2:`Entity` {id:$obj})\n            MERGE (n1)-[:`LEADER_OF`]->(n2)\n        ' {'subj': 'High evolutionary', 'obj': 'Orgocorp'} {'db': 'neo4j'}
# DEBUG:neo4j.io:[#CA7E]  C: PULL {'n': 1000}
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'t_first': 450, 'fields': []}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'bookmark': 'FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAipA=', 'stats': {'contains-updates': True, 'labels-added': 1, 'relationships-created': 1, 'nodes-created': 1, 'properties-set': 1}, 'statuses': [{'gql_status': '00001', 'status_description': 'note: successful completion - omitted result'}], 'type': 'w', 't_last': 1, 'db': 'neo4j'}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> released bolt-7
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/completions', 'files': None, 'idempotency_key': 'stainless-python-retry-e90b808e-94c0-4491-b900-0eb0116a0aa8', 'json_data': {'model': 'qwen2.5', 'prompt': "Some text is provided below. Given the text, extract up to 2 knowledge triplets in the form of (subject, predicate, object). Avoid stopwords.\n---------------------\nExample:Text: Alice is Bob's mother.Triplets:\n(Alice, is mother of, Bob)\nText: Philz is a coffee shop founded in Berkeley in 1982.\nTriplets:\n(Philz, is, coffee shop)\n(Philz, founded in, Berkeley)\n(Philz, founded in, 1982)\n---------------------\nText: They are followed by Ayesha and Adam after the High Evolutionary, their race's creator, threatened to wipe out the Sovereign if they failed to retrieve Rocket. At Counter-Earth, Drax and Mantis remain with Gamora and Rocket while Peter Quill, Groot, and Nebula go to the High Evolutionary's Arête Laboratories complex. Guards force Nebula to wait outside due to her cybernetic enhancements; Quill and Groot enter Arête. Drax tricks Mantis into pursuing Quill's group and Gamora saves Rocket from Adam and War Pig, one of the High Evolutionary's Hellspawn guards.\nThe High Evolutionary agrees with Quill that Counter-Earth is imperfect and begins bombarding the entire planet, killing the Humanimals and Ayesha. Arête, which is actually a spaceship, departs as Nebula, Drax, and Mantis board it to rescue Quill and Groot. However, the latter pair jump off the spaceship with Theel, whom they kill before retrieving the override code from his corpse. They are rescued by Gamora on their ship. As they use the code, Rocket flatlines and has a near-death experience in which he reunites with Lylla, Teefs, and Floor. Lylla tells him his time has not yet come, and Quill succeeds in disabling the kill switch and restarting Rocket's heart.\nDrax, Nebula, and Mantis encounter the High Evolutionary's next batch of test subjects—genetically modified humanoid children—before they are captured. The other Guardians orchestrate a rescue, which leads to a battle against the High Evolutionary's forces. Kraglin opens fire on Arête with Knowhere and then helps to save Knowhere citizens from a counter-attack by the High Evolutionary's Hellspawn. Intent on retreat, the High Evolutionary's crew mutinies, but their leader kills them. Drax, Nebula, and Mantis befriend three monstrous Abilisks to escape and reunite with the rest of the Guardians. The Guardians delay leaving Arête, choosing to rescue the children, who escape to Knowhere via a tunnel constructed by Cosmo's telekinesis. Rocket discovers imprisoned animals on the ship and is confronted by the High Evolutionary, whom the other Guardians defeat. Rocket spares the High Evolutionary, and the Guardians help the animals escape to Knowhere.\nTriplets:\n", 'stream': False, 'temperature': 0.1}}
# DEBUG:openai._base_client:Sending HTTP Request: POST https://llms-inference.innkube.fim.uni-passau.de/completions
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Sun, 13 Jul 2025 09:30:44 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'358'), (b'Connection', b'keep-alive'), (b'x-litellm-call-id', b'7a4bdb6d-b4fc-45d1-ba5e-6184d759e50e'), (b'x-litellm-model-id', b'4fc98ad04997d06d243fa1037a8527856cb537a73abc970ce37122958bbea148'), (b'x-litellm-model-api-base', b'http://qwen2-5-ollama:11434'), (b'x-litellm-version', b'1.42.2'), (b'x-litellm-response-cost', b'0.278478'), (b'x-litellm-key-tpm-limit', b'None'), (b'x-litellm-key-rpm-limit', b'100'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains'), (b'Access-Control-Allow-Origin', b'*'), (b'Access-Control-Allow-Credentials', b'true'), (b'Access-Control-Allow-Methods', b'PUT, GET, POST'), (b'Access-Control-Allow-Headers', b'DNT,Keep-Alive,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range,Authorization'), (b'Access-Control-Max-Age', b'1728000')])
# INFO:httpx:HTTP Request: POST https://llms-inference.innkube.fim.uni-passau.de/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Response: POST https://llms-inference.innkube.fim.uni-passau.de/completions "200 OK" Headers({'date': 'Sun, 13 Jul 2025 09:30:44 GMT', 'content-type': 'application/json', 'content-length': '358', 'connection': 'keep-alive', 'x-litellm-call-id': '7a4bdb6d-b4fc-45d1-ba5e-6184d759e50e', 'x-litellm-model-id': '4fc98ad04997d06d243fa1037a8527856cb537a73abc970ce37122958bbea148', 'x-litellm-model-api-base': 'http://qwen2-5-ollama:11434', 'x-litellm-version': '1.42.2', 'x-litellm-response-cost': '0.278478', 'x-litellm-key-tpm-limit': 'None', 'x-litellm-key-rpm-limit': '100', 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'access-control-allow-origin': '*', 'access-control-allow-credentials': 'true', 'access-control-allow-methods': 'PUT, GET, POST', 'access-control-allow-headers': 'DNT,Keep-Alive,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range,Authorization', 'access-control-max-age': '1728000'})
# DEBUG:openai._base_client:request_id: None
# DEBUG:llama_index.core.indices.knowledge_graph.base:> Extracted triplets: [('Ayesha', 'Followed', 'Adam'), ('High evolutionary', 'Threatened', 'Sovereign')]
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> routing towards fixed database: neo4j
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> pinning database: 'neo4j'
# DEBUG:neo4j.pool:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database=AcquisitionDatabase(name='neo4j', guessed=False)
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> picked existing connection bolt-7
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> handing out existing connection
# DEBUG:neo4j.io:[#CA7E]  C: RUN '\n            MERGE (n1:`Entity` {id:$subj})\n            MERGE (n2:`Entity` {id:$obj})\n            MERGE (n1)-[:`FOLLOWED`]->(n2)\n        ' {'subj': 'Ayesha', 'obj': 'Adam'} {'db': 'neo4j'}
# DEBUG:neo4j.io:[#CA7E]  C: PULL {'n': 1000}
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'t_first': 146, 'fields': []}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'bookmark': 'FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAipA=', 'statuses': [{'gql_status': '00001', 'status_description': 'note: successful completion - omitted result'}], 'type': 'w', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> released bolt-7
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> routing towards fixed database: neo4j
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> pinning database: 'neo4j'
# DEBUG:neo4j.pool:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database=AcquisitionDatabase(name='neo4j', guessed=False)
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> picked existing connection bolt-7
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> handing out existing connection
# DEBUG:neo4j.io:[#CA7E]  C: RUN '\n            MERGE (n1:`Entity` {id:$subj})\n            MERGE (n2:`Entity` {id:$obj})\n            MERGE (n1)-[:`THREATENED`]->(n2)\n        ' {'subj': 'High evolutionary', 'obj': 'Sovereign'} {'db': 'neo4j'}
# DEBUG:neo4j.io:[#CA7E]  C: PULL {'n': 1000}
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'t_first': 156, 'fields': []}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'bookmark': 'FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAipA=', 'statuses': [{'gql_status': '00001', 'status_description': 'note: successful completion - omitted result'}], 'type': 'w', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> released bolt-7
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/completions', 'files': None, 'idempotency_key': 'stainless-python-retry-4ba47c4d-557b-474b-a8a0-8a3ef339f4e5', 'json_data': {'model': 'qwen2.5', 'prompt': 'Some text is provided below. Given the text, extract up to 2 knowledge triplets in the form of (subject, predicate, object). Avoid stopwords.\n---------------------\nExample:Text: Alice is Bob\'s mother.Triplets:\n(Alice, is mother of, Bob)\nText: Philz is a coffee shop founded in Berkeley in 1982.\nTriplets:\n(Philz, is, coffee shop)\n(Philz, founded in, Berkeley)\n(Philz, founded in, 1982)\n---------------------\nText: The other Guardians orchestrate a rescue, which leads to a battle against the High Evolutionary\'s forces. Kraglin opens fire on Arête with Knowhere and then helps to save Knowhere citizens from a counter-attack by the High Evolutionary\'s Hellspawn. Intent on retreat, the High Evolutionary\'s crew mutinies, but their leader kills them. Drax, Nebula, and Mantis befriend three monstrous Abilisks to escape and reunite with the rest of the Guardians. The Guardians delay leaving Arête, choosing to rescue the children, who escape to Knowhere via a tunnel constructed by Cosmo\'s telekinesis. Rocket discovers imprisoned animals on the ship and is confronted by the High Evolutionary, whom the other Guardians defeat. Rocket spares the High Evolutionary, and the Guardians help the animals escape to Knowhere. Quill nearly dies trying to reach Knowhere but is saved by Adam, whom Groot had earlier rescued from Arête\'s destruction.\nQuill decides to leave the Guardians, names Rocket as the new captain, and reunites with his grandfather Jason on Earth. Mantis embarks on a journey of self-discovery with the Abilisks, Gamora rejoins the Ravagers, and Nebula and Drax remain on Knowhere to raise the rescued children. The new Guardians—Rocket, Groot, Kraglin, Cosmo, Adam, Phyla (one of the rescued children), and Adam\'s pet Blurp—later take on a mission.\n\n\n== Cast ==\n\nChris Pratt as Peter Quill / Star-Lord:The half-human, half-Celestial leader of the Guardians of the Galaxy who was abducted from Earth as a child and raised by a group of alien thieves and smugglers, the Ravagers. In the film, Quill is in a "state of depression" following the appearance of a variant of his dead lover Gamora, who does not share the same affection for Quill as her older version had for him, which in turn affects his leadership of the Guardians.\nZoe Saldaña as Gamora:An orphan who seeks redemption for her past crimes, and was adopted and trained by Thanos to be his personal assassin.\nTriplets:\n', 'stream': False, 'temperature': 0.1}}
# DEBUG:openai._base_client:Sending HTTP Request: POST https://llms-inference.innkube.fim.uni-passau.de/completions
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Sun, 13 Jul 2025 09:30:46 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'365'), (b'Connection', b'keep-alive'), (b'x-litellm-call-id', b'43a49223-e373-4081-ac62-5b010644e401'), (b'x-litellm-model-id', b'4fc98ad04997d06d243fa1037a8527856cb537a73abc970ce37122958bbea148'), (b'x-litellm-model-api-base', b'http://qwen2-5-ollama:11434'), (b'x-litellm-version', b'1.42.2'), (b'x-litellm-response-cost', b'0.265897'), (b'x-litellm-key-tpm-limit', b'None'), (b'x-litellm-key-rpm-limit', b'100'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains'), (b'Access-Control-Allow-Origin', b'*'), (b'Access-Control-Allow-Credentials', b'true'), (b'Access-Control-Allow-Methods', b'PUT, GET, POST'), (b'Access-Control-Allow-Headers', b'DNT,Keep-Alive,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range,Authorization'), (b'Access-Control-Max-Age', b'1728000')])
# INFO:httpx:HTTP Request: POST https://llms-inference.innkube.fim.uni-passau.de/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Response: POST https://llms-inference.innkube.fim.uni-passau.de/completions "200 OK" Headers({'date': 'Sun, 13 Jul 2025 09:30:46 GMT', 'content-type': 'application/json', 'content-length': '365', 'connection': 'keep-alive', 'x-litellm-call-id': '43a49223-e373-4081-ac62-5b010644e401', 'x-litellm-model-id': '4fc98ad04997d06d243fa1037a8527856cb537a73abc970ce37122958bbea148', 'x-litellm-model-api-base': 'http://qwen2-5-ollama:11434', 'x-litellm-version': '1.42.2', 'x-litellm-response-cost': '0.265897', 'x-litellm-key-tpm-limit': 'None', 'x-litellm-key-rpm-limit': '100', 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'access-control-allow-origin': '*', 'access-control-allow-credentials': 'true', 'access-control-allow-methods': 'PUT, GET, POST', 'access-control-allow-headers': 'DNT,Keep-Alive,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range,Authorization', 'access-control-max-age': '1728000'})
# DEBUG:openai._base_client:request_id: None
# DEBUG:llama_index.core.indices.knowledge_graph.base:> Extracted triplets: [('Kraglin', 'Opens fire on', 'Arête')]
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> routing towards fixed database: neo4j
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> pinning database: 'neo4j'
# DEBUG:neo4j.pool:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database=AcquisitionDatabase(name='neo4j', guessed=False)
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> picked existing connection bolt-7
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> handing out existing connection
# DEBUG:neo4j.io:[#CA7E]  C: RUN '\n            MERGE (n1:`Entity` {id:$subj})\n            MERGE (n2:`Entity` {id:$obj})\n            MERGE (n1)-[:`OPENS_FIRE_ON`]->(n2)\n        ' {'subj': 'Kraglin', 'obj': 'Arête'} {'db': 'neo4j'}
# DEBUG:neo4j.io:[#CA7E]  C: PULL {'n': 1000}
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'t_first': 147, 'fields': []}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'bookmark': 'FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAipA=', 'statuses': [{'gql_status': '00001', 'status_description': 'note: successful completion - omitted result'}], 'type': 'w', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> released bolt-7
# ...
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> released bolt-7
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/completions', 'files': None, 'idempotency_key': 'stainless-python-retry-2e0e8a76-2242-4c03-94d5-a528403c0f7d', 'json_data': {'model': 'qwen2.5', 'prompt': 'Some text is provided below. Given the text, extract up to 2 knowledge triplets in the form of (subject, predicate, object). Avoid stopwords.\n---------------------\nExample:Text: Alice is Bob\'s mother.Triplets:\n(Alice, is mother of, Bob)\nText: Philz is a coffee shop founded in Berkeley in 1982.\nTriplets:\n(Philz, is, coffee shop)\n(Philz, founded in, Berkeley)\n(Philz, founded in, 1982)\n---------------------\nText: A negative review from NPR criticized the approach of cruelty to animals in the film, while The New York Times called it a "dour, visually off-putting two-and-a-half-hour A.S.P.C.A. nightmare of a film (that) may only be for completionist fans", and the Chicago Tribune, "the most empty, brutal MCU movie yet". Conversely, People for the Ethical Treatment of Animals (PETA) declared the film to be "the best animal rights film of the year", and gave Gunn a "Not a Number Award" for his depiction of animal testing.\n\n\n=== Accolades ===\n\n\n== Documentary special ==\n\nIn February 2021, the documentary series Marvel Studios: Assembled was announced. The special on this film, "The Making of Guardians of the Galaxy Vol. 3", was released on Disney+ on September 13, 2023.\n\n\n== Future ==\nGunn said in April 2017 that a fourth Guardians film could happen, although, it would likely center on a new group of characters since Gunn planned to conclude the story of the current team in Vol. 3. Later in September, Gunn said he was unlikely to return for another Guardians film but would continue to work with Marvel Studios on other projects that use the Guardians and cosmic characters. One such project from Gunn was a film centered on Drax and Mantis, which Bautista called "brilliant". However, in May 2021, Bautista stated that he had not heard any further updates regarding it, feeling Marvel Studios was not "very interested, or it doesn\'t fit into the way they have things mapped out". Gunn confirmed in September 2019 that he intended for Vol. 3 to be his last Guardians film, which he reaffirmed in May 2021. In July 2021, Gillan expressed her desire to continue playing Nebula after Vol. 3. In April 2023, Saldaña confirmed that Vol. 3 would be the last time she portrays Gamora, but hoped Marvel would recast the role with a younger actor because she wished for the character to continue.\nPratt indicated in May 2023 that he was willing to continue playing Peter Quill if the right script came along, and a note at the end of Vol. 3\'s post-credits scene states that the "Legendary Star-Lord" will return to the MCU. In December 2024, Gunn said he had given his blessing to Pratt to continue in the role without him, and he was excited for Marvel to use the Guardians again in future projects. He noted that there were planned spin-offs that did not eventuate but still could without his involvement, including a television series focused on the Ravagers and a project that he called "Legendary Star-Lord" which they "had a whole idea for".\nTriplets:\n', 'stream': False, 'temperature': 0.1}}
# DEBUG:openai._base_client:Sending HTTP Request: POST https://llms-inference.innkube.fim.uni-passau.de/completions
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Sun, 13 Jul 2025 09:32:12 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'420'), (b'Connection', b'keep-alive'), (b'x-litellm-call-id', b'fe962511-03b3-4a1e-9eff-e91a5cece3d8'), (b'x-litellm-model-id', b'4fc98ad04997d06d243fa1037a8527856cb537a73abc970ce37122958bbea148'), (b'x-litellm-model-api-base', b'http://qwen2-5-ollama:11434'), (b'x-litellm-version', b'1.42.2'), (b'x-litellm-response-cost', b'0.33238999999999996'), (b'x-litellm-key-tpm-limit', b'None'), (b'x-litellm-key-rpm-limit', b'100'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains'), (b'Access-Control-Allow-Origin', b'*'), (b'Access-Control-Allow-Credentials', b'true'), (b'Access-Control-Allow-Methods', b'PUT, GET, POST'), (b'Access-Control-Allow-Headers', b'DNT,Keep-Alive,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range,Authorization'), (b'Access-Control-Max-Age', b'1728000')])
# INFO:httpx:HTTP Request: POST https://llms-inference.innkube.fim.uni-passau.de/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Response: POST https://llms-inference.innkube.fim.uni-passau.de/completions "200 OK" Headers({'date': 'Sun, 13 Jul 2025 09:32:12 GMT', 'content-type': 'application/json', 'content-length': '420', 'connection': 'keep-alive', 'x-litellm-call-id': 'fe962511-03b3-4a1e-9eff-e91a5cece3d8', 'x-litellm-model-id': '4fc98ad04997d06d243fa1037a8527856cb537a73abc970ce37122958bbea148', 'x-litellm-model-api-base': 'http://qwen2-5-ollama:11434', 'x-litellm-version': '1.42.2', 'x-litellm-response-cost': '0.33238999999999996', 'x-litellm-key-tpm-limit': 'None', 'x-litellm-key-rpm-limit': '100', 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'access-control-allow-origin': '*', 'access-control-allow-credentials': 'true', 'access-control-allow-methods': 'PUT, GET, POST', 'access-control-allow-headers': 'DNT,Keep-Alive,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range,Authorization', 'access-control-max-age': '1728000'})
# DEBUG:openai._base_client:request_id: None
# DEBUG:llama_index.core.indices.knowledge_graph.base:> Extracted triplets: [('People for the ethical treatment of animals', 'Declared', 'Best animal rights film of the year'), ('Gunn', 'Received', 'Not a number award')]
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> routing towards fixed database: neo4j
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> pinning database: 'neo4j'
# DEBUG:neo4j.pool:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database=AcquisitionDatabase(name='neo4j', guessed=False)
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> picked existing connection bolt-7
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> handing out existing connection
# DEBUG:neo4j.io:[#CA7E]  C: RUN '\n            MERGE (n1:`Entity` {id:$subj})\n            MERGE (n2:`Entity` {id:$obj})\n            MERGE (n1)-[:`DECLARED`]->(n2)\n        ' {'subj': 'People for the ethical treatment of animals', 'obj': 'Best animal rights film of the year'} {'db': 'neo4j'}
# DEBUG:neo4j.io:[#CA7E]  C: PULL {'n': 1000}
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'t_first': 103, 'fields': []}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'bookmark': 'FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAoZA=', 'stats': {'contains-updates': True, 'labels-added': 1, 'relationships-created': 1, 'nodes-created': 1, 'properties-set': 1}, 'statuses': [{'gql_status': '00001', 'status_description': 'note: successful completion - omitted result'}], 'type': 'w', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> released bolt-7
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> routing towards fixed database: neo4j
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> pinning database: 'neo4j'
# DEBUG:neo4j.pool:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database=AcquisitionDatabase(name='neo4j', guessed=False)
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> picked existing connection bolt-7
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> handing out existing connection
# DEBUG:neo4j.io:[#CA7E]  C: RUN '\n            MERGE (n1:`Entity` {id:$subj})\n            MERGE (n2:`Entity` {id:$obj})\n            MERGE (n1)-[:`RECEIVED`]->(n2)\n        ' {'subj': 'Gunn', 'obj': 'Not a number award'} {'db': 'neo4j'}
# DEBUG:neo4j.io:[#CA7E]  C: PULL {'n': 1000}
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'t_first': 116, 'fields': []}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'bookmark': 'FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAoZA=', 'statuses': [{'gql_status': '00001', 'status_description': 'note: successful completion - omitted result'}], 'type': 'w', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> released bolt-7
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/completions', 'files': None, 'idempotency_key': 'stainless-python-retry-39360970-b3b7-4a74-881f-ad70e41682f1', 'json_data': {'model': 'qwen2.5', 'prompt': "Some text is provided below. Given the text, extract up to 2 knowledge triplets in the form of (subject, predicate, object). Avoid stopwords.\n---------------------\nExample:Text: Alice is Bob's mother.Triplets:\n(Alice, is mother of, Bob)\nText: Philz is a coffee shop founded in Berkeley in 1982.\nTriplets:\n(Philz, is, coffee shop)\n(Philz, founded in, Berkeley)\n(Philz, founded in, 1982)\n---------------------\nText: == Notes ==\n\n\n== References ==\n\n\n== External links ==\n\nOfficial website  at Marvel.com\nGuardians of the Galaxy Vol. 3 at IMDb \nGuardians of the Galaxy Vol. 3 at Disney A to Z \nGuardians of the Galaxy Vol. 3 at Disney.com\nTriplets:\n", 'stream': False, 'temperature': 0.1}}
# DEBUG:openai._base_client:Sending HTTP Request: POST https://llms-inference.innkube.fim.uni-passau.de/completions
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Sun, 13 Jul 2025 09:32:14 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'410'), (b'Connection', b'keep-alive'), (b'x-litellm-call-id', b'62fbff3c-edf6-40e7-a4e5-481598c7a470'), (b'x-litellm-model-id', b'4fc98ad04997d06d243fa1037a8527856cb537a73abc970ce37122958bbea148'), (b'x-litellm-model-api-base', b'http://qwen2-5-ollama:11434'), (b'x-litellm-version', b'1.42.2'), (b'x-litellm-response-cost', b'0.10713'), (b'x-litellm-key-tpm-limit', b'None'), (b'x-litellm-key-rpm-limit', b'100'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains'), (b'Access-Control-Allow-Origin', b'*'), (b'Access-Control-Allow-Credentials', b'true'), (b'Access-Control-Allow-Methods', b'PUT, GET, POST'), (b'Access-Control-Allow-Headers', b'DNT,Keep-Alive,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range,Authorization'), (b'Access-Control-Max-Age', b'1728000')])
# INFO:httpx:HTTP Request: POST https://llms-inference.innkube.fim.uni-passau.de/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Response: POST https://llms-inference.innkube.fim.uni-passau.de/completions "200 OK" Headers({'date': 'Sun, 13 Jul 2025 09:32:14 GMT', 'content-type': 'application/json', 'content-length': '410', 'connection': 'keep-alive', 'x-litellm-call-id': '62fbff3c-edf6-40e7-a4e5-481598c7a470', 'x-litellm-model-id': '4fc98ad04997d06d243fa1037a8527856cb537a73abc970ce37122958bbea148', 'x-litellm-model-api-base': 'http://qwen2-5-ollama:11434', 'x-litellm-version': '1.42.2', 'x-litellm-response-cost': '0.10713', 'x-litellm-key-tpm-limit': 'None', 'x-litellm-key-rpm-limit': '100', 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'access-control-allow-origin': '*', 'access-control-allow-credentials': 'true', 'access-control-allow-methods': 'PUT, GET, POST', 'access-control-allow-headers': 'DNT,Keep-Alive,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range,Authorization', 'access-control-max-age': '1728000'})
# DEBUG:openai._base_client:request_id: None
# DEBUG:llama_index.core.indices.knowledge_graph.base:> Extracted triplets: [('Guardians of the galaxy vol. 3', 'Has official website at', 'Marvel.com'), ('Guardians of the galaxy vol. 3', 'Listed at', 'Imdb')]
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> routing towards fixed database: neo4j
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> pinning database: 'neo4j'
# DEBUG:neo4j.pool:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database=AcquisitionDatabase(name='neo4j', guessed=False)
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> picked existing connection bolt-7
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> handing out existing connection
# DEBUG:neo4j.io:[#CA7E]  C: RUN '\n            MERGE (n1:`Entity` {id:$subj})\n            MERGE (n2:`Entity` {id:$obj})\n            MERGE (n1)-[:`HAS_OFFICIAL_WEBSITE_AT`]->(n2)\n        ' {'subj': 'Guardians of the galaxy vol. 3', 'obj': 'Marvel.com'} {'db': 'neo4j'}
# DEBUG:neo4j.io:[#CA7E]  C: PULL {'n': 1000}
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'t_first': 109, 'fields': []}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'bookmark': 'FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAoZA=', 'statuses': [{'gql_status': '00001', 'status_description': 'note: successful completion - omitted result'}], 'type': 'w', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> released bolt-7
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> routing towards fixed database: neo4j
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> pinning database: 'neo4j'
# DEBUG:neo4j.pool:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database=AcquisitionDatabase(name='neo4j', guessed=False)
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> picked existing connection bolt-7
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> handing out existing connection
# DEBUG:neo4j.io:[#CA7E]  C: RUN '\n            MERGE (n1:`Entity` {id:$subj})\n            MERGE (n2:`Entity` {id:$obj})\n            MERGE (n1)-[:`LISTED_AT`]->(n2)\n        ' {'subj': 'Guardians of the galaxy vol. 3', 'obj': 'Imdb'} {'db': 'neo4j'}
# DEBUG:neo4j.io:[#CA7E]  C: PULL {'n': 1000}
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'t_first': 113, 'fields': []}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'bookmark': 'FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAoZA=', 'statuses': [{'gql_status': '00001', 'status_description': 'note: successful completion - omitted result'}], 'type': 'w', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> released bolt-7
# CPU times: total: 2.14 s
# Wall time: 1min 43s

# %%
# Persist the index to the storage context
# This will save the index to the storage context, allowing it to be reused later
index.storage_context.persist()
# Out:
# DEBUG:fsspec.local:open file: c:/Research/PHD_Related_research/Experiments/KG_with_Llamaindex/storage/docstore.json
# DEBUG:fsspec.local:open file: c:/Research/PHD_Related_research/Experiments/KG_with_Llamaindex/storage/index_store.json
# DEBUG:fsspec.local:open file: c:/Research/PHD_Related_research/Experiments/KG_with_Llamaindex/storage/default__vector_store.json
# DEBUG:fsspec.local:open file: c:/Research/PHD_Related_research/Experiments/KG_with_Llamaindex/storage/image__vector_store.json

# %%
# Create a query engine from the index
# This will allow you to query the knowledge graph index
query_engine = index.as_query_engine(
    include_text=False, response_mode="tree_summarize"
)

# Query the knowledge graph index
# This will return a response based on the query and the knowledge graph index
response = query_engine.query("Tell me more about Rocket")
# Out:
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/completions', 'files': None, 'idempotency_key': 'stainless-python-retry-3bf14a44-ace7-4afb-98e6-f09d85696e35', 'json_data': {'model': 'qwen2.5', 'prompt': "A question is provided below. Given the question, extract up to 10 keywords from the text. Focus on extracting the keywords that we can use to best lookup answers to the question. Avoid stopwords.\n---------------------\nTell me more about Rocket\n---------------------\nProvide keywords in the following comma-separated format: 'KEYWORDS: <keywords>'\n", 'stream': False, 'temperature': 0.1}}
# DEBUG:openai._base_client:Sending HTTP Request: POST https://llms-inference.innkube.fim.uni-passau.de/completions
# DEBUG:httpcore.connection:close.started
# DEBUG:httpcore.connection:close.complete
# DEBUG:httpcore.connection:connect_tcp.started host='llms-inference.innkube.fim.uni-passau.de' port=443 local_address=None timeout=60.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x000001D14B5C8AC0>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x000001D143A558C0> server_hostname='llms-inference.innkube.fim.uni-passau.de' timeout=60.0
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x000001D143C43430>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Sun, 13 Jul 2025 09:33:23 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'402'), (b'Connection', b'keep-alive'), (b'x-litellm-call-id', b'a80a29f9-7b3d-4131-9b5f-3417da42832a'), (b'x-litellm-model-id', b'4fc98ad04997d06d243fa1037a8527856cb537a73abc970ce37122958bbea148'), (b'x-litellm-model-api-base', b'http://qwen2-5-ollama:11434'), (b'x-litellm-version', b'1.42.2'), (b'x-litellm-response-cost', b'0.055323'), (b'x-litellm-key-tpm-limit', b'None'), (b'x-litellm-key-rpm-limit', b'100'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains'), (b'Access-Control-Allow-Origin', b'*'), (b'Access-Control-Allow-Credentials', b'true'), (b'Access-Control-Allow-Methods', b'PUT, GET, POST'), (b'Access-Control-Allow-Headers', b'DNT,Keep-Alive,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range,Authorization'), (b'Access-Control-Max-Age', b'1728000')])
# INFO:httpx:HTTP Request: POST https://llms-inference.innkube.fim.uni-passau.de/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Response: POST https://llms-inference.innkube.fim.uni-passau.de/completions "200 OK" Headers({'date': 'Sun, 13 Jul 2025 09:33:23 GMT', 'content-type': 'application/json', 'content-length': '402', 'connection': 'keep-alive', 'x-litellm-call-id': 'a80a29f9-7b3d-4131-9b5f-3417da42832a', 'x-litellm-model-id': '4fc98ad04997d06d243fa1037a8527856cb537a73abc970ce37122958bbea148', 'x-litellm-model-api-base': 'http://qwen2-5-ollama:11434', 'x-litellm-version': '1.42.2', 'x-litellm-response-cost': '0.055323', 'x-litellm-key-tpm-limit': 'None', 'x-litellm-key-rpm-limit': '100', 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'access-control-allow-origin': '*', 'access-control-allow-credentials': 'true', 'access-control-allow-methods': 'PUT, GET, POST', 'access-control-allow-headers': 'DNT,Keep-Alive,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range,Authorization', 'access-control-max-age': '1728000'})
# DEBUG:openai._base_client:request_id: None
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> routing towards fixed database: neo4j
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> pinning database: 'neo4j'
# DEBUG:neo4j.pool:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database=AcquisitionDatabase(name='neo4j', guessed=False)
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> picked existing connection bolt-7
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> handing out existing connection
# DEBUG:neo4j.io:[#CA7E]  C: BEGIN {'db': 'neo4j', 'bookmarks': ['FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAiJA=']}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> client state: STREAMING > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#CA7E]  C: RUN "MATCH p=(n1:Entity)-[*1..2]->() WHERE toLower(n1.id) IN ['history']UNWIND relationships(p) AS rel WITH n1.id AS subj, p, apoc.coll.flatten(apoc.coll.toSet(collect([type(rel), endNode(rel).id]))) AS flattened_rels RETURN subj, collect(flattened_rels) AS flattened_rels LIMIT 30" {'subjs': ['history']} {}
# DEBUG:neo4j.io:[#CA7E]  C: PULL {'n': 1000}
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> server state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'t_first': 459, 'fields': ['subj', 'flattened_rels'], 'qid': 0}
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'statuses': [{'gql_status': '02000', 'status_description': 'note: no data'}], 'type': 'r', 't_last': 15, 'db': 'neo4j'}
# DEBUG:neo4j.io:[#CA7E]  C: COMMIT
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> client state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'bookmark': 'FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAoZA='}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> server state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> released bolt-7
# DEBUG:llama_index.core.indices.knowledge_graph.retrievers:rel_map: {}
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> routing towards fixed database: neo4j
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> pinning database: 'neo4j'
# DEBUG:neo4j.pool:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database=AcquisitionDatabase(name='neo4j', guessed=False)
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> picked existing connection bolt-7
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> handing out existing connection
# DEBUG:neo4j.io:[#CA7E]  C: BEGIN {'db': 'neo4j', 'bookmarks': ['FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAoZA=']}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> client state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#CA7E]  C: RUN "MATCH p=(n1:Entity)-[*1..2]->() WHERE toLower(n1.id) IN ['applications']UNWIND relationships(p) AS rel WITH n1.id AS subj, p, apoc.coll.flatten(apoc.coll.toSet(collect([type(rel), endNode(rel).id]))) AS flattened_rels RETURN subj, collect(flattened_rels) AS flattened_rels LIMIT 30" {'subjs': ['applications']} {}
# DEBUG:neo4j.io:[#CA7E]  C: PULL {'n': 1000}
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> server state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'t_first': 46, 'fields': ['subj', 'flattened_rels'], 'qid': 0}
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'statuses': [{'gql_status': '02000', 'status_description': 'note: no data'}], 'type': 'r', 't_last': 22, 'db': 'neo4j'}
# DEBUG:neo4j.io:[#CA7E]  C: COMMIT
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> client state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'bookmark': 'FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAoZA='}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> server state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> released bolt-7
# DEBUG:llama_index.core.indices.knowledge_graph.retrievers:rel_map: {}
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> routing towards fixed database: neo4j
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> pinning database: 'neo4j'
# DEBUG:neo4j.pool:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database=AcquisitionDatabase(name='neo4j', guessed=False)
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> picked existing connection bolt-7
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> handing out existing connection
# DEBUG:neo4j.io:[#CA7E]  C: BEGIN {'db': 'neo4j', 'bookmarks': ['FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAoZA=']}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> client state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#CA7E]  C: RUN "MATCH p=(n1:Entity)-[*1..2]->() WHERE toLower(n1.id) IN ['space']UNWIND relationships(p) AS rel WITH n1.id AS subj, p, apoc.coll.flatten(apoc.coll.toSet(collect([type(rel), endNode(rel).id]))) AS flattened_rels RETURN subj, collect(flattened_rels) AS flattened_rels LIMIT 30" {'subjs': ['space']} {}
# DEBUG:neo4j.io:[#CA7E]  C: PULL {'n': 1000}
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> server state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'t_first': 50, 'fields': ['subj', 'flattened_rels'], 'qid': 0}
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'statuses': [{'gql_status': '02000', 'status_description': 'note: no data'}], 'type': 'r', 't_last': 4, 'db': 'neo4j'}
# DEBUG:neo4j.io:[#CA7E]  C: COMMIT
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> client state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'bookmark': 'FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAoZA='}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> server state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> released bolt-7
# DEBUG:llama_index.core.indices.knowledge_graph.retrievers:rel_map: {}
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> routing towards fixed database: neo4j
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> pinning database: 'neo4j'
# DEBUG:neo4j.pool:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database=AcquisitionDatabase(name='neo4j', guessed=False)
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> picked existing connection bolt-7
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> handing out existing connection
# DEBUG:neo4j.io:[#CA7E]  C: BEGIN {'db': 'neo4j', 'bookmarks': ['FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAoZA=']}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> client state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#CA7E]  C: RUN "MATCH p=(n1:Entity)-[*1..2]->() WHERE toLower(n1.id) IN ['information']UNWIND relationships(p) AS rel WITH n1.id AS subj, p, apoc.coll.flatten(apoc.coll.toSet(collect([type(rel), endNode(rel).id]))) AS flattened_rels RETURN subj, collect(flattened_rels) AS flattened_rels LIMIT 30" {'subjs': ['information']} {}
# DEBUG:neo4j.io:[#CA7E]  C: PULL {'n': 1000}
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> server state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'t_first': 38, 'fields': ['subj', 'flattened_rels'], 'qid': 0}
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'statuses': [{'gql_status': '02000', 'status_description': 'note: no data'}], 'type': 'r', 't_last': 4, 'db': 'neo4j'}
# DEBUG:neo4j.io:[#CA7E]  C: COMMIT
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> client state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'bookmark': 'FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAoZA='}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> server state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> released bolt-7
# DEBUG:llama_index.core.indices.knowledge_graph.retrievers:rel_map: {}
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> routing towards fixed database: neo4j
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> pinning database: 'neo4j'
# DEBUG:neo4j.pool:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database=AcquisitionDatabase(name='neo4j', guessed=False)
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> picked existing connection bolt-7
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> handing out existing connection
# DEBUG:neo4j.io:[#CA7E]  C: BEGIN {'db': 'neo4j', 'bookmarks': ['FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAoZA=']}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> client state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#CA7E]  C: RUN "MATCH p=(n1:Entity)-[*1..2]->() WHERE toLower(n1.id) IN ['details']UNWIND relationships(p) AS rel WITH n1.id AS subj, p, apoc.coll.flatten(apoc.coll.toSet(collect([type(rel), endNode(rel).id]))) AS flattened_rels RETURN subj, collect(flattened_rels) AS flattened_rels LIMIT 30" {'subjs': ['details']} {}
# DEBUG:neo4j.io:[#CA7E]  C: PULL {'n': 1000}
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> server state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'t_first': 87, 'fields': ['subj', 'flattened_rels'], 'qid': 0}
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'statuses': [{'gql_status': '02000', 'status_description': 'note: no data'}], 'type': 'r', 't_last': 6, 'db': 'neo4j'}
# DEBUG:neo4j.io:[#CA7E]  C: COMMIT
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> client state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'bookmark': 'FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAoZA='}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> server state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> released bolt-7
# DEBUG:llama_index.core.indices.knowledge_graph.retrievers:rel_map: {}
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> routing towards fixed database: neo4j
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> pinning database: 'neo4j'
# DEBUG:neo4j.pool:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database=AcquisitionDatabase(name='neo4j', guessed=False)
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> picked existing connection bolt-7
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> handing out existing connection
# DEBUG:neo4j.io:[#CA7E]  C: BEGIN {'db': 'neo4j', 'bookmarks': ['FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAoZA=']}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> client state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#CA7E]  C: RUN "MATCH p=(n1:Entity)-[*1..2]->() WHERE toLower(n1.id) IN ['technology']UNWIND relationships(p) AS rel WITH n1.id AS subj, p, apoc.coll.flatten(apoc.coll.toSet(collect([type(rel), endNode(rel).id]))) AS flattened_rels RETURN subj, collect(flattened_rels) AS flattened_rels LIMIT 30" {'subjs': ['technology']} {}
# DEBUG:neo4j.io:[#CA7E]  C: PULL {'n': 1000}
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> server state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'t_first': 39, 'fields': ['subj', 'flattened_rels'], 'qid': 0}
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'statuses': [{'gql_status': '02000', 'status_description': 'note: no data'}], 'type': 'r', 't_last': 2, 'db': 'neo4j'}
# DEBUG:neo4j.io:[#CA7E]  C: COMMIT
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> client state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'bookmark': 'FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAoZA='}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> server state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> released bolt-7
# DEBUG:llama_index.core.indices.knowledge_graph.retrievers:rel_map: {}
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> routing towards fixed database: neo4j
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> pinning database: 'neo4j'
# DEBUG:neo4j.pool:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database=AcquisitionDatabase(name='neo4j', guessed=False)
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> picked existing connection bolt-7
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> handing out existing connection
# DEBUG:neo4j.io:[#CA7E]  C: BEGIN {'db': 'neo4j', 'bookmarks': ['FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAoZA=']}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> client state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#CA7E]  C: RUN "MATCH p=(n1:Entity)-[*1..2]->() WHERE toLower(n1.id) IN ['characteristics']UNWIND relationships(p) AS rel WITH n1.id AS subj, p, apoc.coll.flatten(apoc.coll.toSet(collect([type(rel), endNode(rel).id]))) AS flattened_rels RETURN subj, collect(flattened_rels) AS flattened_rels LIMIT 30" {'subjs': ['characteristics']} {}
# DEBUG:neo4j.io:[#CA7E]  C: PULL {'n': 1000}
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> server state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'t_first': 39, 'fields': ['subj', 'flattened_rels'], 'qid': 0}
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'statuses': [{'gql_status': '02000', 'status_description': 'note: no data'}], 'type': 'r', 't_last': 4, 'db': 'neo4j'}
# DEBUG:neo4j.io:[#CA7E]  C: COMMIT
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> client state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'bookmark': 'FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAoZA='}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> server state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> released bolt-7
# DEBUG:llama_index.core.indices.knowledge_graph.retrievers:rel_map: {}
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> routing towards fixed database: neo4j
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> pinning database: 'neo4j'
# DEBUG:neo4j.pool:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database=AcquisitionDatabase(name='neo4j', guessed=False)
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> picked existing connection bolt-7
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> handing out existing connection
# DEBUG:neo4j.io:[#CA7E]  C: BEGIN {'db': 'neo4j', 'bookmarks': ['FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAoZA=']}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> client state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#CA7E]  C: RUN "MATCH p=(n1:Entity)-[*1..2]->() WHERE toLower(n1.id) IN ['rocket']UNWIND relationships(p) AS rel WITH n1.id AS subj, p, apoc.coll.flatten(apoc.coll.toSet(collect([type(rel), endNode(rel).id]))) AS flattened_rels RETURN subj, collect(flattened_rels) AS flattened_rels LIMIT 30" {'subjs': ['Rocket']} {}
# DEBUG:neo4j.io:[#CA7E]  C: PULL {'n': 1000}
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> server state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'t_first': 45, 'fields': ['subj', 'flattened_rels'], 'qid': 0}
# DEBUG:neo4j.io:[#CA7E]  S: RECORD * 1
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'statuses': [{'gql_status': '00000', 'status_description': 'note: successful completion'}], 'type': 'r', 't_last': 34, 'db': 'neo4j'}
# DEBUG:neo4j.io:[#CA7E]  C: COMMIT
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> client state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'bookmark': 'FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAoZA='}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> server state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> released bolt-7
# DEBUG:llama_index.core.indices.knowledge_graph.retrievers:rel_map: {'Rocket': [['FOUND_AND_EXPERIMENTED_ON_BY', 'High evolutionary'], ['FOUND_AND_EXPERIMENTED_ON_BY', 'High evolutionary', 'AIMED_TO_ENHANCE_AND_ANTHROPOMORPHIZE', 'Animal lifeforms'], ['FOUND_AND_EXPERIMENTED_ON_BY', 'High evolutionary', 'THREATENED', 'Sovereign'], ['FOUND_AND_EXPERIMENTED_ON_BY', 'High evolutionary', 'SPECIALIZES_IN', 'Creating hybrid creatures'], ['FOUND_AND_EXPERIMENTED_ON_BY', 'High evolutionary', 'DESCRIBED_AS', 'Cruelest mcu villain'], ['FOUND_AND_EXPERIMENTED_ON_BY', 'High evolutionary', 'LEADER_OF', 'Orgocorp'], ['FOUND_AND_EXPERIMENTED_ON_BY', 'High evolutionary', 'CREATED', 'Animen']]}
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> routing towards fixed database: neo4j
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> pinning database: 'neo4j'
# DEBUG:neo4j.pool:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database=AcquisitionDatabase(name='neo4j', guessed=False)
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> picked existing connection bolt-7
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> handing out existing connection
# DEBUG:neo4j.io:[#CA7E]  C: BEGIN {'db': 'neo4j', 'bookmarks': ['FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAoZA=']}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> client state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#CA7E]  C: RUN "MATCH p=(n1:Entity)-[*1..2]->() WHERE toLower(n1.id) IN ['launch']UNWIND relationships(p) AS rel WITH n1.id AS subj, p, apoc.coll.flatten(apoc.coll.toSet(collect([type(rel), endNode(rel).id]))) AS flattened_rels RETURN subj, collect(flattened_rels) AS flattened_rels LIMIT 30" {'subjs': ['launch']} {}
# DEBUG:neo4j.io:[#CA7E]  C: PULL {'n': 1000}
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> server state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'t_first': 38, 'fields': ['subj', 'flattened_rels'], 'qid': 0}
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'statuses': [{'gql_status': '02000', 'status_description': 'note: no data'}], 'type': 'r', 't_last': 5, 'db': 'neo4j'}
# DEBUG:neo4j.io:[#CA7E]  C: COMMIT
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> client state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'bookmark': 'FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAoZA='}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> server state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> released bolt-7
# DEBUG:llama_index.core.indices.knowledge_graph.retrievers:rel_map: {}
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> routing towards fixed database: neo4j
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> pinning database: 'neo4j'
# DEBUG:neo4j.pool:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database=AcquisitionDatabase(name='neo4j', guessed=False)
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> picked existing connection bolt-7
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> handing out existing connection
# DEBUG:neo4j.io:[#CA7E]  C: BEGIN {'db': 'neo4j', 'bookmarks': ['FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAoZA=']}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> client state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#CA7E]  C: RUN "MATCH p=(n1:Entity)-[*1..2]->() WHERE toLower(n1.id) IN ['facts']UNWIND relationships(p) AS rel WITH n1.id AS subj, p, apoc.coll.flatten(apoc.coll.toSet(collect([type(rel), endNode(rel).id]))) AS flattened_rels RETURN subj, collect(flattened_rels) AS flattened_rels LIMIT 30" {'subjs': ['facts']} {}
# DEBUG:neo4j.io:[#CA7E]  C: PULL {'n': 1000}
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> server state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'t_first': 43, 'fields': ['subj', 'flattened_rels'], 'qid': 0}
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'statuses': [{'gql_status': '02000', 'status_description': 'note: no data'}], 'type': 'r', 't_last': 2, 'db': 'neo4j'}
# DEBUG:neo4j.io:[#CA7E]  C: COMMIT
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> client state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'bookmark': 'FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAoZA='}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> server state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> released bolt-7
# DEBUG:llama_index.core.indices.knowledge_graph.retrievers:rel_map: {}
# WARNING:llama_index.core.indices.knowledge_graph.retrievers:Index was not constructed with embeddings, skipping embedding usage...
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/completions', 'files': None, 'idempotency_key': 'stainless-python-retry-ab17af7a-f4d3-4d16-9149-e78427cde872', 'json_data': {'model': 'qwen2.5', 'prompt': "Context information from multiple sources is below.\n---------------------\nkg_schema: {'schema': 'Node properties are the following:\\nEntity {id: STRING}\\nRelationship properties are the following:\\n\\nThe relationships are the following:\\n(:Entity)-[:IS]->(:Entity),(:Entity)-[:PRODUCED_BY]->(:Entity),(:Entity)-[:PREMIERED_AT]->(:Entity),(:Entity)-[:RELEASED_IN]->(:Entity),(:Entity)-[:RELEASED_BY]->(:Entity),(:Entity)-[:FINAL_PHYSICAL_MEDIA_RELEASE_FOR]->(:Entity),(:Entity)-[:HAS_APPROVAL_RATING_OF]->(:Entity),(:Entity)-[:RECEIVED_AVERAGE_GRADE_OF]->(:Entity),(:Entity)-[:HAS_OFFICIAL_WEBSITE_AT]->(:Entity),(:Entity)-[:LISTED_AT]->(:Entity),(:Entity)-[:FOUND_AND_EXPERIMENTED_ON_BY]->(:Entity),(:Entity)-[:AIMED_TO_ENHANCE_AND_ANTHROPOMORPHIZE]->(:Entity),(:Entity)-[:THREATENED]->(:Entity),(:Entity)-[:SPECIALIZES_IN]->(:Entity),(:Entity)-[:DESCRIBED_AS]->(:Entity),(:Entity)-[:FOLLOWED]->(:Entity),(:Entity)-[:OPENS_FIRE_ON]->(:Entity),(:Entity)-[:INCLUDE]->(:Entity),(:Entity)-[:PORTRAYS]->(:Entity),(:Entity)-[:CONFIRMED_TO_REPRISE_ROLE_AS]->(:Entity),(:Entity)-[:PLAYS]->(:Entity),(:Entity)-[:IS_MEMBER_OF]->(:Entity),(:Entity)-[:LIKENED]->(:Entity),(:Entity)-[:ANNOUNCED]->(:Entity),(:Entity)-[:RETURN_TO_WRITE_AND_DIRECT]->(:Entity),(:Entity)-[:EXPECTED_TO_BE_PAID]->(:Entity),(:Entity)-[:IDENTIFIES_WITH]->(:Entity),(:Entity)-[:CONFIRMED_SCRIPT_FINISHED_FOR]->(:Entity),(:Entity)-[:SAID]->(:Entity),(:Entity)-[:TURNED_IN]->(:Entity),(:Entity)-[:NOTED]->(:Entity),(:Entity)-[:BEGAN_STORYBOARDING]->(:Entity),(:Entity)-[:WROTE_CAMEO_APPEARANCE_FOR]->(:Entity),(:Entity)-[:CAST_WILL_POULTER_AS]->(:Entity),(:Entity)-[:CHOSE_POULTER_FOR]->(:Entity),(:Entity)-[:USED]->(:Entity),(:Entity)-[:FELT_MUSIC_DIFFERENT_FROM]->(:Entity),(:Entity)-[:SELECTED_SONGS_BY]->(:Entity),(:Entity)-[:RECEIVED]->(:Entity),(:Entity)-[:REPRISES_ROLE_AS]->(:Entity),(:Entity)-[:FIRED_BY]->(:Entity),(:Entity)-[:TWEETS_ABOUT]->(:Entity),(:Entity)-[:SAID_TWEETS_WERE]->(:Entity),(:Entity)-[:MET_WITH]->(:Entity),(:Entity)-[:SET_TO_WRITE_AND_POTENTIALLY_DIRECT]->(:Entity),(:Entity)-[:NOT_PLANNING_TO_REHIRE]->(:Entity),(:Entity)-[:SET_TO_REPRISE_ROLE_AS]->(:Entity),(:Entity)-[:TWEETED_SUPPORT_FOR]->(:Entity),(:Entity)-[:IS_RIVAL_OF]->(:Entity),(:Entity)-[:ASKED_TO_CONSIDER_DIRECTING]->(:Entity),(:Entity)-[:FEATURES]->(:Entity),(:Entity)-[:RETURNS_AS]->(:Entity),(:Entity)-[:RETURNED_TO_PLAY]->(:Entity),(:Entity)-[:CAST_AS]->(:Entity),(:Entity)-[:SCREEN_TEST_FOR]->(:Entity),(:Entity)-[:DISCUSSED_DURING]->(:Entity),(:Entity)-[:FIRST_FOOTAGE_REVEALED_AT]->(:Entity),(:Entity)-[:PRAISED]->(:Entity),(:Entity)-[:STATED]->(:Entity),(:Entity)-[:LIFE_ENDANGERED]->(:Entity),(:Entity)-[:DECLARED]->(:Entity)'}\n\nThe following are knowledge sequence in max depth 2 in the form of directed graph like:\n`subject -[predicate]->, object, <-[predicate_next_hop]-, object_next_hop ...`\n['FOUND_AND_EXPERIMENTED_ON_BY', 'High evolutionary']\n['FOUND_AND_EXPERIMENTED_ON_BY', 'High evolutionary', 'AIMED_TO_ENHANCE_AND_ANTHROPOMORPHIZE', 'Animal lifeforms']\n['FOUND_AND_EXPERIMENTED_ON_BY', 'High evolutionary', 'THREATENED', 'Sovereign']\n['FOUND_AND_EXPERIMENTED_ON_BY', 'High evolutionary', 'SPECIALIZES_IN', 'Creating hybrid creatures']\n['FOUND_AND_EXPERIMENTED_ON_BY', 'High evolutionary', 'DESCRIBED_AS', 'Cruelest mcu villain']\n['FOUND_AND_EXPERIMENTED_ON_BY', 'High evolutionary', 'LEADER_OF', 'Orgocorp']\n['FOUND_AND_EXPERIMENTED_ON_BY', 'High evolutionary', 'CREATED', 'Animen']\n---------------------\nGiven the information from multiple sources and not prior knowledge, answer the query.\nQuery: Tell me more about Rocket\nAnswer: ", 'stream': False, 'temperature': 0.1}}
# DEBUG:openai._base_client:Sending HTTP Request: POST https://llms-inference.innkube.fim.uni-passau.de/completions
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Sun, 13 Jul 2025 09:33:33 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'1140'), (b'Connection', b'keep-alive'), (b'x-litellm-call-id', b'bd639b98-a08f-4c61-bb8f-178ea3f9b48c'), (b'x-litellm-model-id', b'4fc98ad04997d06d243fa1037a8527856cb537a73abc970ce37122958bbea148'), (b'x-litellm-model-api-base', b'http://qwen2-5-ollama:11434'), (b'x-litellm-version', b'1.42.2'), (b'x-litellm-response-cost', b'0.549445'), (b'x-litellm-key-tpm-limit', b'None'), (b'x-litellm-key-rpm-limit', b'100'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains'), (b'Access-Control-Allow-Origin', b'*'), (b'Access-Control-Allow-Credentials', b'true'), (b'Access-Control-Allow-Methods', b'PUT, GET, POST'), (b'Access-Control-Allow-Headers', b'DNT,Keep-Alive,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range,Authorization'), (b'Access-Control-Max-Age', b'1728000')])
# INFO:httpx:HTTP Request: POST https://llms-inference.innkube.fim.uni-passau.de/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Response: POST https://llms-inference.innkube.fim.uni-passau.de/completions "200 OK" Headers({'date': 'Sun, 13 Jul 2025 09:33:33 GMT', 'content-type': 'application/json', 'content-length': '1140', 'connection': 'keep-alive', 'x-litellm-call-id': 'bd639b98-a08f-4c61-bb8f-178ea3f9b48c', 'x-litellm-model-id': '4fc98ad04997d06d243fa1037a8527856cb537a73abc970ce37122958bbea148', 'x-litellm-model-api-base': 'http://qwen2-5-ollama:11434', 'x-litellm-version': '1.42.2', 'x-litellm-response-cost': '0.549445', 'x-litellm-key-tpm-limit': 'None', 'x-litellm-key-rpm-limit': '100', 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'access-control-allow-origin': '*', 'access-control-allow-credentials': 'true', 'access-control-allow-methods': 'PUT, GET, POST', 'access-control-allow-headers': 'DNT,Keep-Alive,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range,Authorization', 'access-control-max-age': '1728000'})
# DEBUG:openai._base_client:request_id: None

# %%
display(Markdown(f"<b>{response}</b>"))
# Out:
# <b>Based on the provided context, there is no direct information about Rocket. However, given that the context revolves around the High Evolutionary, who experiments on and creates various lifeforms, it's possible to infer some connections:
#
# - The High Evolutionary is known for experimenting on and creating hybrid creatures.
# - He aims to enhance and anthropomorphize animal lifeforms.
#
# Rocket, a character from the Marvel Cinematic Universe (MCU), is a genetically modified raccoon who was experimented on. While not explicitly mentioned in the provided context, it's likely that Rocket could be one of the many lifeforms that the High Evolutionary has experimented on or created, given his background and the High Evolutionary’s goals.
#
# If you have more specific information about Rocket or any other related entities, please let me know!</b>

# %%
# Create a query engine from the index
# This will allow you to query the knowledge graph index including text = True making the response more informative 
query_engine = index.as_query_engine(
    include_text=True, response_mode="tree_summarize"
)

response = query_engine.query("Tell me more about Rocket")
# Out:
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/completions', 'files': None, 'idempotency_key': 'stainless-python-retry-a7bd2195-162b-4391-9d92-870b1b6cf95b', 'json_data': {'model': 'qwen2.5', 'prompt': "A question is provided below. Given the question, extract up to 10 keywords from the text. Focus on extracting the keywords that we can use to best lookup answers to the question. Avoid stopwords.\n---------------------\nTell me more about Rocket\n---------------------\nProvide keywords in the following comma-separated format: 'KEYWORDS: <keywords>'\n", 'stream': False, 'temperature': 0.1}}
# DEBUG:openai._base_client:Sending HTTP Request: POST https://llms-inference.innkube.fim.uni-passau.de/completions
# DEBUG:httpcore.connection:close.started
# DEBUG:httpcore.connection:close.complete
# DEBUG:httpcore.connection:connect_tcp.started host='llms-inference.innkube.fim.uni-passau.de' port=443 local_address=None timeout=60.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x000001D148F56FD0>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x000001D143A558C0> server_hostname='llms-inference.innkube.fim.uni-passau.de' timeout=60.0
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x000001D128487D00>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Sun, 13 Jul 2025 09:33:53 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'406'), (b'Connection', b'keep-alive'), (b'x-litellm-call-id', b'1c233e06-b0fb-484a-a04d-421a54bcf455'), (b'x-litellm-model-id', b'4fc98ad04997d06d243fa1037a8527856cb537a73abc970ce37122958bbea148'), (b'x-litellm-model-api-base', b'http://qwen2-5-ollama:11434'), (b'x-litellm-version', b'1.42.2'), (b'x-litellm-response-cost', b'0.055323'), (b'x-litellm-key-tpm-limit', b'None'), (b'x-litellm-key-rpm-limit', b'100'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains'), (b'Access-Control-Allow-Origin', b'*'), (b'Access-Control-Allow-Credentials', b'true'), (b'Access-Control-Allow-Methods', b'PUT, GET, POST'), (b'Access-Control-Allow-Headers', b'DNT,Keep-Alive,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range,Authorization'), (b'Access-Control-Max-Age', b'1728000')])
# INFO:httpx:HTTP Request: POST https://llms-inference.innkube.fim.uni-passau.de/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Response: POST https://llms-inference.innkube.fim.uni-passau.de/completions "200 OK" Headers({'date': 'Sun, 13 Jul 2025 09:33:53 GMT', 'content-type': 'application/json', 'content-length': '406', 'connection': 'keep-alive', 'x-litellm-call-id': '1c233e06-b0fb-484a-a04d-421a54bcf455', 'x-litellm-model-id': '4fc98ad04997d06d243fa1037a8527856cb537a73abc970ce37122958bbea148', 'x-litellm-model-api-base': 'http://qwen2-5-ollama:11434', 'x-litellm-version': '1.42.2', 'x-litellm-response-cost': '0.055323', 'x-litellm-key-tpm-limit': 'None', 'x-litellm-key-rpm-limit': '100', 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'access-control-allow-origin': '*', 'access-control-allow-credentials': 'true', 'access-control-allow-methods': 'PUT, GET, POST', 'access-control-allow-headers': 'DNT,Keep-Alive,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range,Authorization', 'access-control-max-age': '1728000'})
# DEBUG:openai._base_client:request_id: None
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> routing towards fixed database: neo4j
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> pinning database: 'neo4j'
# DEBUG:neo4j.pool:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database=AcquisitionDatabase(name='neo4j', guessed=False)
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> picked existing connection bolt-7
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> handing out existing connection
# DEBUG:neo4j.io:[#CA7E]  C: BEGIN {'db': 'neo4j', 'bookmarks': ['FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAoZA=']}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> client state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#CA7E]  C: RUN "MATCH p=(n1:Entity)-[*1..2]->() WHERE toLower(n1.id) IN ['history']UNWIND relationships(p) AS rel WITH n1.id AS subj, p, apoc.coll.flatten(apoc.coll.toSet(collect([type(rel), endNode(rel).id]))) AS flattened_rels RETURN subj, collect(flattened_rels) AS flattened_rels LIMIT 30" {'subjs': ['history']} {}
# DEBUG:neo4j.io:[#CA7E]  C: PULL {'n': 1000}
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> server state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'t_first': 1, 'fields': ['subj', 'flattened_rels'], 'qid': 0}
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'statuses': [{'gql_status': '02000', 'status_description': 'note: no data'}], 'type': 'r', 't_last': 2, 'db': 'neo4j'}
# DEBUG:neo4j.io:[#CA7E]  C: COMMIT
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> client state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'bookmark': 'FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAoZA='}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> server state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> released bolt-7
# DEBUG:llama_index.core.indices.knowledge_graph.retrievers:rel_map: {}
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> routing towards fixed database: neo4j
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> pinning database: 'neo4j'
# DEBUG:neo4j.pool:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database=AcquisitionDatabase(name='neo4j', guessed=False)
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> picked existing connection bolt-7
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> handing out existing connection
# DEBUG:neo4j.io:[#CA7E]  C: BEGIN {'db': 'neo4j', 'bookmarks': ['FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAoZA=']}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> client state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#CA7E]  C: RUN "MATCH p=(n1:Entity)-[*1..2]->() WHERE toLower(n1.id) IN ['applications']UNWIND relationships(p) AS rel WITH n1.id AS subj, p, apoc.coll.flatten(apoc.coll.toSet(collect([type(rel), endNode(rel).id]))) AS flattened_rels RETURN subj, collect(flattened_rels) AS flattened_rels LIMIT 30" {'subjs': ['applications']} {}
# DEBUG:neo4j.io:[#CA7E]  C: PULL {'n': 1000}
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> server state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'t_first': 2, 'fields': ['subj', 'flattened_rels'], 'qid': 0}
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'statuses': [{'gql_status': '02000', 'status_description': 'note: no data'}], 'type': 'r', 't_last': 3, 'db': 'neo4j'}
# DEBUG:neo4j.io:[#CA7E]  C: COMMIT
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> client state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'bookmark': 'FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAoZA='}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> server state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> released bolt-7
# DEBUG:llama_index.core.indices.knowledge_graph.retrievers:rel_map: {}
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> routing towards fixed database: neo4j
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> pinning database: 'neo4j'
# DEBUG:neo4j.pool:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database=AcquisitionDatabase(name='neo4j', guessed=False)
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> picked existing connection bolt-7
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> handing out existing connection
# DEBUG:neo4j.io:[#CA7E]  C: BEGIN {'db': 'neo4j', 'bookmarks': ['FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAoZA=']}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> client state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#CA7E]  C: RUN "MATCH p=(n1:Entity)-[*1..2]->() WHERE toLower(n1.id) IN ['information']UNWIND relationships(p) AS rel WITH n1.id AS subj, p, apoc.coll.flatten(apoc.coll.toSet(collect([type(rel), endNode(rel).id]))) AS flattened_rels RETURN subj, collect(flattened_rels) AS flattened_rels LIMIT 30" {'subjs': ['information']} {}
# DEBUG:neo4j.io:[#CA7E]  C: PULL {'n': 1000}
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> server state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'t_first': 2, 'fields': ['subj', 'flattened_rels'], 'qid': 0}
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'statuses': [{'gql_status': '02000', 'status_description': 'note: no data'}], 'type': 'r', 't_last': 2, 'db': 'neo4j'}
# DEBUG:neo4j.io:[#CA7E]  C: COMMIT
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> client state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'bookmark': 'FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAoZA='}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> server state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> released bolt-7
# DEBUG:llama_index.core.indices.knowledge_graph.retrievers:rel_map: {}
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> routing towards fixed database: neo4j
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> pinning database: 'neo4j'
# DEBUG:neo4j.pool:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database=AcquisitionDatabase(name='neo4j', guessed=False)
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> picked existing connection bolt-7
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> handing out existing connection
# DEBUG:neo4j.io:[#CA7E]  C: BEGIN {'db': 'neo4j', 'bookmarks': ['FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAoZA=']}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> client state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#CA7E]  C: RUN "MATCH p=(n1:Entity)-[*1..2]->() WHERE toLower(n1.id) IN ['details']UNWIND relationships(p) AS rel WITH n1.id AS subj, p, apoc.coll.flatten(apoc.coll.toSet(collect([type(rel), endNode(rel).id]))) AS flattened_rels RETURN subj, collect(flattened_rels) AS flattened_rels LIMIT 30" {'subjs': ['details']} {}
# DEBUG:neo4j.io:[#CA7E]  C: PULL {'n': 1000}
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> server state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'t_first': 6, 'fields': ['subj', 'flattened_rels'], 'qid': 0}
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'statuses': [{'gql_status': '02000', 'status_description': 'note: no data'}], 'type': 'r', 't_last': 32, 'db': 'neo4j'}
# DEBUG:neo4j.io:[#CA7E]  C: COMMIT
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> client state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'bookmark': 'FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAoZA='}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> server state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> released bolt-7
# DEBUG:llama_index.core.indices.knowledge_graph.retrievers:rel_map: {}
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> routing towards fixed database: neo4j
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> pinning database: 'neo4j'
# DEBUG:neo4j.pool:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database=AcquisitionDatabase(name='neo4j', guessed=False)
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> picked existing connection bolt-7
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> handing out existing connection
# DEBUG:neo4j.io:[#CA7E]  C: BEGIN {'db': 'neo4j', 'bookmarks': ['FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAoZA=']}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> client state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#CA7E]  C: RUN "MATCH p=(n1:Entity)-[*1..2]->() WHERE toLower(n1.id) IN ['technology']UNWIND relationships(p) AS rel WITH n1.id AS subj, p, apoc.coll.flatten(apoc.coll.toSet(collect([type(rel), endNode(rel).id]))) AS flattened_rels RETURN subj, collect(flattened_rels) AS flattened_rels LIMIT 30" {'subjs': ['technology']} {}
# DEBUG:neo4j.io:[#CA7E]  C: PULL {'n': 1000}
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> server state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'t_first': 2, 'fields': ['subj', 'flattened_rels'], 'qid': 0}
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'statuses': [{'gql_status': '02000', 'status_description': 'note: no data'}], 'type': 'r', 't_last': 3, 'db': 'neo4j'}
# DEBUG:neo4j.io:[#CA7E]  C: COMMIT
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> client state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'bookmark': 'FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAoZA='}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> server state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> released bolt-7
# DEBUG:llama_index.core.indices.knowledge_graph.retrievers:rel_map: {}
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> routing towards fixed database: neo4j
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> pinning database: 'neo4j'
# DEBUG:neo4j.pool:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database=AcquisitionDatabase(name='neo4j', guessed=False)
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> picked existing connection bolt-7
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> handing out existing connection
# DEBUG:neo4j.io:[#CA7E]  C: BEGIN {'db': 'neo4j', 'bookmarks': ['FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAoZA=']}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> client state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#CA7E]  C: RUN "MATCH p=(n1:Entity)-[*1..2]->() WHERE toLower(n1.id) IN ['characteristics']UNWIND relationships(p) AS rel WITH n1.id AS subj, p, apoc.coll.flatten(apoc.coll.toSet(collect([type(rel), endNode(rel).id]))) AS flattened_rels RETURN subj, collect(flattened_rels) AS flattened_rels LIMIT 30" {'subjs': ['characteristics']} {}
# DEBUG:neo4j.io:[#CA7E]  C: PULL {'n': 1000}
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> server state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'t_first': 2, 'fields': ['subj', 'flattened_rels'], 'qid': 0}
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'statuses': [{'gql_status': '02000', 'status_description': 'note: no data'}], 'type': 'r', 't_last': 2, 'db': 'neo4j'}
# DEBUG:neo4j.io:[#CA7E]  C: COMMIT
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> client state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'bookmark': 'FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAoZA='}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> server state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> released bolt-7
# DEBUG:llama_index.core.indices.knowledge_graph.retrievers:rel_map: {}
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> routing towards fixed database: neo4j
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> pinning database: 'neo4j'
# DEBUG:neo4j.pool:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database=AcquisitionDatabase(name='neo4j', guessed=False)
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> picked existing connection bolt-7
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> handing out existing connection
# DEBUG:neo4j.io:[#CA7E]  C: BEGIN {'db': 'neo4j', 'bookmarks': ['FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAoZA=']}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> client state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#CA7E]  C: RUN "MATCH p=(n1:Entity)-[*1..2]->() WHERE toLower(n1.id) IN ['rocket']UNWIND relationships(p) AS rel WITH n1.id AS subj, p, apoc.coll.flatten(apoc.coll.toSet(collect([type(rel), endNode(rel).id]))) AS flattened_rels RETURN subj, collect(flattened_rels) AS flattened_rels LIMIT 30" {'subjs': ['Rocket']} {}
# DEBUG:neo4j.io:[#CA7E]  C: PULL {'n': 1000}
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> server state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'t_first': 1, 'fields': ['subj', 'flattened_rels'], 'qid': 0}
# DEBUG:neo4j.io:[#CA7E]  S: RECORD * 1
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'statuses': [{'gql_status': '00000', 'status_description': 'note: successful completion'}], 'type': 'r', 't_last': 7, 'db': 'neo4j'}
# DEBUG:neo4j.io:[#CA7E]  C: COMMIT
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> client state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'bookmark': 'FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAoZA='}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> server state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> released bolt-7
# DEBUG:llama_index.core.indices.knowledge_graph.retrievers:rel_map: {'Rocket': [['FOUND_AND_EXPERIMENTED_ON_BY', 'High evolutionary'], ['FOUND_AND_EXPERIMENTED_ON_BY', 'High evolutionary', 'AIMED_TO_ENHANCE_AND_ANTHROPOMORPHIZE', 'Animal lifeforms'], ['FOUND_AND_EXPERIMENTED_ON_BY', 'High evolutionary', 'THREATENED', 'Sovereign'], ['FOUND_AND_EXPERIMENTED_ON_BY', 'High evolutionary', 'SPECIALIZES_IN', 'Creating hybrid creatures'], ['FOUND_AND_EXPERIMENTED_ON_BY', 'High evolutionary', 'DESCRIBED_AS', 'Cruelest mcu villain'], ['FOUND_AND_EXPERIMENTED_ON_BY', 'High evolutionary', 'LEADER_OF', 'Orgocorp'], ['FOUND_AND_EXPERIMENTED_ON_BY', 'High evolutionary', 'CREATED', 'Animen']]}
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> routing towards fixed database: neo4j
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> pinning database: 'neo4j'
# DEBUG:neo4j.pool:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database=AcquisitionDatabase(name='neo4j', guessed=False)
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> picked existing connection bolt-7
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> handing out existing connection
# DEBUG:neo4j.io:[#CA7E]  C: BEGIN {'db': 'neo4j', 'bookmarks': ['FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAoZA=']}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> client state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#CA7E]  C: RUN "MATCH p=(n1:Entity)-[*1..2]->() WHERE toLower(n1.id) IN ['development']UNWIND relationships(p) AS rel WITH n1.id AS subj, p, apoc.coll.flatten(apoc.coll.toSet(collect([type(rel), endNode(rel).id]))) AS flattened_rels RETURN subj, collect(flattened_rels) AS flattened_rels LIMIT 30" {'subjs': ['development']} {}
# DEBUG:neo4j.io:[#CA7E]  C: PULL {'n': 1000}
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> server state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'t_first': 37, 'fields': ['subj', 'flattened_rels'], 'qid': 0}
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'statuses': [{'gql_status': '02000', 'status_description': 'note: no data'}], 'type': 'r', 't_last': 3, 'db': 'neo4j'}
# DEBUG:neo4j.io:[#CA7E]  C: COMMIT
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> client state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'bookmark': 'FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAoZA='}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> server state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> released bolt-7
# DEBUG:llama_index.core.indices.knowledge_graph.retrievers:rel_map: {}
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> routing towards fixed database: neo4j
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> pinning database: 'neo4j'
# DEBUG:neo4j.pool:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database=AcquisitionDatabase(name='neo4j', guessed=False)
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> picked existing connection bolt-7
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> handing out existing connection
# DEBUG:neo4j.io:[#CA7E]  C: BEGIN {'db': 'neo4j', 'bookmarks': ['FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAoZA=']}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> client state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#CA7E]  C: RUN "MATCH p=(n1:Entity)-[*1..2]->() WHERE toLower(n1.id) IN ['uses']UNWIND relationships(p) AS rel WITH n1.id AS subj, p, apoc.coll.flatten(apoc.coll.toSet(collect([type(rel), endNode(rel).id]))) AS flattened_rels RETURN subj, collect(flattened_rels) AS flattened_rels LIMIT 30" {'subjs': ['uses']} {}
# DEBUG:neo4j.io:[#CA7E]  C: PULL {'n': 1000}
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> server state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'t_first': 83, 'fields': ['subj', 'flattened_rels'], 'qid': 0}
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'statuses': [{'gql_status': '02000', 'status_description': 'note: no data'}], 'type': 'r', 't_last': 2, 'db': 'neo4j'}
# DEBUG:neo4j.io:[#CA7E]  C: COMMIT
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> client state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'bookmark': 'FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAoZA='}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> server state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> released bolt-7
# DEBUG:llama_index.core.indices.knowledge_graph.retrievers:rel_map: {}
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> routing towards fixed database: neo4j
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> pinning database: 'neo4j'
# DEBUG:neo4j.pool:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database=AcquisitionDatabase(name='neo4j', guessed=False)
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> picked existing connection bolt-7
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> handing out existing connection
# DEBUG:neo4j.io:[#CA7E]  C: BEGIN {'db': 'neo4j', 'bookmarks': ['FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAoZA=']}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> client state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#CA7E]  C: RUN "MATCH p=(n1:Entity)-[*1..2]->() WHERE toLower(n1.id) IN ['facts']UNWIND relationships(p) AS rel WITH n1.id AS subj, p, apoc.coll.flatten(apoc.coll.toSet(collect([type(rel), endNode(rel).id]))) AS flattened_rels RETURN subj, collect(flattened_rels) AS flattened_rels LIMIT 30" {'subjs': ['facts']} {}
# DEBUG:neo4j.io:[#CA7E]  C: PULL {'n': 1000}
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> server state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'t_first': 2, 'fields': ['subj', 'flattened_rels'], 'qid': 0}
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'statuses': [{'gql_status': '02000', 'status_description': 'note: no data'}], 'type': 'r', 't_last': 2, 'db': 'neo4j'}
# DEBUG:neo4j.io:[#CA7E]  C: COMMIT
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> client state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.io:[#CA7E]  S: SUCCESS {'bookmark': 'FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAoZA='}
# DEBUG:neo4j.io:[#CA7E]  _: <CONNECTION> server state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.pool:[#CA7E]  _: <POOL> released bolt-7
# DEBUG:llama_index.core.indices.knowledge_graph.retrievers:rel_map: {}
# WARNING:llama_index.core.indices.knowledge_graph.retrievers:Index was not constructed with embeddings, skipping embedding usage...
# INFO:llama_index.core.indices.knowledge_graph.retrievers:> Querying with idx: 7cc9c8aa-00c5-4054-af77-4637d5ca32eb: By the end of April, the franchise's five main stars—Pratt, Saldaña, Bautista...
# INFO:llama_index.core.indices.knowledge_graph.retrievers:> Querying with idx: 118a7ac7-54ed-4779-a601-81598e08745a: The Guardians travel to Orgocorp's headquarters to find the switch's override...
# INFO:llama_index.core.indices.knowledge_graph.retrievers:> Querying with idx: 821632e7-b590-436c-8c18-995d9746d009: The new Guardians—Rocket, Groot, Kraglin, Cosmo, Adam, Phyla (one of the resc...
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/completions', 'files': None, 'idempotency_key': 'stainless-python-retry-66821904-aae3-47dc-b5d5-e615e8600e87', 'json_data': {'model': 'qwen2.5', 'prompt': 'Context information from multiple sources is below.\n---------------------\nBy the end of April, the franchise\'s five main stars—Pratt, Saldaña, Bautista, Cooper, and Diesel—were all expected to return for the sequel, with filming to take place in 2020.\nDiscussing his firing and re-hiring in May 2019, Gunn said that of all the elements of the film that he had been sad to leave when he was fired, the most meaningful to him was the character of Rocket. Gunn personally identifies with Rocket, describing himself and the character as "the same". He had grown to love the character since working on the first film due to feeling that an origin story for Rocket could justify what a Bugs Bunny-like "goofy character" like him could exist in the MCU if it were the saddest one in the universe, crediting it as the "seed" of the trilogy. While Vol. 3 effectively reveals Rocket\'s backstory through flashbacks akin to those from the story structure of The Godfather Part II (1974), Gunn initially considered telling Rocket\'s origins in a team-up movie between him and Groot without the other Guardians. He was eventually convinced to make a third Guardians-centric film instead of the Rocket and Groot film but chose to use it to tell Rocket\'s story. That month, Gillan confirmed that she was returning for the sequel and expressed excitement for Gunn\'s return to the franchise. In June, Saldaña was asked about her role in the film after her character Gamora was killed in Infinity War, and she returned to play a younger version in Endgame who travels through time to the present. Saldaña said that Gamora\'s fate would depend on the plans that Marvel and Gunn have for Vol. 3, but that she would like to see Gamora rejoin the Guardians and also be portrayed as "the most lethal woman in the galaxy" as she has been referred to previously. Gunn was asked in October if he was unhappy about Marvel\'s decision to kill Gamora in Infinity War and said he was not, adding that he had discussed the storyline with the studio beforehand. According to Infinity War and Endgame screenwriters Christopher Markus and Stephen McFeely, Gamora was brought back in Endgame specifically so that Gunn could include her in Vol. 3.\n\nThe Guardians travel to Orgocorp\'s headquarters to find the switch\'s override code and save Rocket\'s life.\nAs Rocket lies dying, he recalls his past. He was found and experimented on as a baby raccoon by the High Evolutionary, leader of Orgocorp, who aimed to enhance and anthropomorphize animal lifeforms into "Humanimals" for an ideal society, Counter-Earth. Rocket\'s fellow Batch 89 test subjects included the otter Lylla, walrus Teefs, and rabbit Floor. Impressed by Rocket\'s intelligence, the High Evolutionary used his insights to improve later batches of Humanimals. Angry that one of his creations could solve a problem that he could not, the High Evolutionary planned to harvest Rocket\'s brain and incinerate all of Batch 89. Rocket tried to rescue his friends, but the High Evolutionary killed Lylla and mocked Rocket\'s grief. Enraged, Rocket attacked the High Evolutionary while henchmen killed Teefs and Floor during the chaos. Rocket kills the henchmen and then escapes in a spaceship.\nIn the present, an alternate version of Gamora, who has joined the Ravagers, helps the Guardians infiltrate Orgocorp. They retrieve Rocket\'s file but discover that Theel, one of the High Evolutionary\'s advisors, has removed the override code. The Guardians and Gamora travel to Counter-Earth to find him. They are followed by Ayesha and Adam after the High Evolutionary, their race\'s creator, threatened to wipe out the Sovereign if they failed to retrieve Rocket. At Counter-Earth, Drax and Mantis remain with Gamora and Rocket while Peter  ...
# DEBUG:openai._base_client:Sending HTTP Request: POST https://llms-inference.innkube.fim.uni-passau.de/completions
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Sun, 13 Jul 2025 09:34:25 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'2795'), (b'Connection', b'keep-alive'), (b'x-litellm-call-id', b'0528e5a1-2c66-45bf-bc46-0cfb23b55387'), (b'x-litellm-model-id', b'4fc98ad04997d06d243fa1037a8527856cb537a73abc970ce37122958bbea148'), (b'x-litellm-model-api-base', b'http://qwen2-5-ollama:11434'), (b'x-litellm-version', b'1.42.2'), (b'x-litellm-response-cost', b'1.159128'), (b'x-litellm-key-tpm-limit', b'None'), (b'x-litellm-key-rpm-limit', b'100'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains'), (b'Access-Control-Allow-Origin', b'*'), (b'Access-Control-Allow-Credentials', b'true'), (b'Access-Control-Allow-Methods', b'PUT, GET, POST'), (b'Access-Control-Allow-Headers', b'DNT,Keep-Alive,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range,Authorization'), (b'Access-Control-Max-Age', b'1728000')])
# INFO:httpx:HTTP Request: POST https://llms-inference.innkube.fim.uni-passau.de/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Response: POST https://llms-inference.innkube.fim.uni-passau.de/completions "200 OK" Headers({'date': 'Sun, 13 Jul 2025 09:34:25 GMT', 'content-type': 'application/json', 'content-length': '2795', 'connection': 'keep-alive', 'x-litellm-call-id': '0528e5a1-2c66-45bf-bc46-0cfb23b55387', 'x-litellm-model-id': '4fc98ad04997d06d243fa1037a8527856cb537a73abc970ce37122958bbea148', 'x-litellm-model-api-base': 'http://qwen2-5-ollama:11434', 'x-litellm-version': '1.42.2', 'x-litellm-response-cost': '1.159128', 'x-litellm-key-tpm-limit': 'None', 'x-litellm-key-rpm-limit': '100', 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'access-control-allow-origin': '*', 'access-control-allow-credentials': 'true', 'access-control-allow-methods': 'PUT, GET, POST', 'access-control-allow-headers': 'DNT,Keep-Alive,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range,Authorization', 'access-control-max-age': '1728000'})
# DEBUG:openai._base_client:request_id: None

# %%
display(Markdown(f"<b>{response}</b>"))
# Out:
# <b>Rocket is a key character in the Marvel Cinematic Universe (MCU), particularly known for his role in the "Guardians of the Galaxy" films and the broader MCU series. Here are some detailed points about Rocket:
#
# 1. **Background**:
#    - **Found and Experimented On**: Rocket was found and experimented on by the High Evolutionary, a character described as one of the cruelest villains in the MCU.
#    - **Aimed to Enhance and Anthropomorphize**: The High Evolutionary aimed to enhance and anthropomorphize animal lifeforms, which is how Rocket came to be.
#
# 2. **Character Traits**:
#    - **Hybrid Creature**: Rocket is a genetically modified raccoon with enhanced intelligence, strength, and combat skills.
#    - **Personality**: He is known for his sharp wit, sarcasm, and a tough exterior that often masks deep emotional pain and a sense of abandonment due to his past.
#
# 3. **Role in the MCU**:
#    - **Guardians of the Galaxy**: Rocket is one of the core members of the Guardians of the Galaxy, alongside Star-Lord, Gamora, Drax, and Groot.
#    - **Combat Skills**: He is an expert marksman and a skilled fighter, often providing tactical support and humor in battle situations.
#
# 4. **Backstory**:
#    - **Orgocorp**: The High Evolutionary's organization, Orgocorp, was responsible for Rocket's creation and the experiments that shaped him.
#    - **Painful Past**: Rocket's past is marked by the cruel experiments he endured, which have left him with a deep-seated mistrust of authority and a strong sense of independence.
#
# 5. **Portrayal**:
#    - **Voice Actor**: Rocket is voiced by Bradley Cooper in the films.
#    - **Motion Capture**: The physical performance for Rocket is provided by Sean Gunn, who also plays Kraglin in the MCU.
#
# 6. **Significant Moments**:
#    - **Guardians of the Galaxy (2014)**: Rocket's first appearance where he and Groot are introduced as part of a group of bounty hunters.
#    - **Avengers: Infinity War (2018) and Endgame (2019)**: Rocket plays crucial roles in these films, particularly in the battle against Thanos.
#
# 7. **Future Appearances**:
#    - **Guardians of the Galaxy Vol. 3**: James Gunn, who directed the first two "Guardians" films, is set to return to write and direct this installment, which will likely delve deeper into Rocket's backstory and his relationship with the other Guardians.
#
# Rocket's complex character and compelling backstory make him a fan favorite in the MCU, known for his humor, loyalty, and deep emotional depth.</b>

# %% [markdown]
# ## Store and visualize the graph in the html format

# %%
from neo4j import GraphDatabase

# Connect to the database
uri = "bolt://localhost:7687"
username = "neo4j"
password = "neo4j123"

driver = GraphDatabase.driver(uri, auth=(username, password))
# Out:
# DEBUG:neo4j.pool:[#0000]  _: <POOL> created, direct address IPv4Address(('localhost', 7687))

# %%
# Function to fetch the graph data
# This function retrieves nodes and relationships from the Neo4j database
def fetch_graph(tx, limit=50):
    query = """
    MATCH (n)-[r]->(m)
    RETURN n, r, m
    LIMIT $limit
    """
    result = tx.run(query, limit=limit)
    data = []

    for record in result:
        data.append({
            "source": dict(record["n"]),
            "relation": record["r"].type,
            "target": dict(record["m"])
        })

    return data

# Safely extract and store the graph data
with driver.session() as session:
    graph_data = session.read_transaction(fetch_graph)

# Now build the sets for visualization
nodes = set()
edges = []

for entry in graph_data:
    source = entry["source"].get("name", str(entry["source"]))
    target = entry["target"].get("name", str(entry["target"]))
    relation = entry["relation"]

    nodes.add(source)
    nodes.add(target)
    edges.append((source, target, relation))
# Out:
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> routing towards fixed database: None
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> pinning database: None
# DEBUG:neo4j.pool:[#0000]  _: <POOL> acquire direct connection, access_mode='READ', database=AcquisitionDatabase(name=None, guessed=False)
# DEBUG:neo4j.pool:[#F88E]  _: <POOL> picked existing connection bolt-25
# DEBUG:neo4j.pool:[#F88E]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j.pool:[#F88E]  _: <POOL> handing out existing connection
# DEBUG:neo4j.io:[#F88E]  C: BEGIN {'mode': 'r'}
# DEBUG:neo4j.io:[#F88E]  _: <CONNECTION> client state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#F88E]  S: SUCCESS {}
# DEBUG:neo4j.io:[#F88E]  _: <CONNECTION> server state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#F88E]  C: RUN '\n    MATCH (n)-[r]->(m)\n    RETURN n, r, m\n    LIMIT $limit\n    ' {'limit': 50} {}
# DEBUG:neo4j.io:[#F88E]  C: PULL {'n': 1000}
# DEBUG:neo4j.io:[#F88E]  S: SUCCESS {'t_first': 0, 'fields': ['n', 'r', 'm'], 'qid': 0}
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: SUCCESS {'statuses': [{'gql_status': '00000', 'status_description': 'note: successful completion'}], 'type': 'r', 't_last': 7, 'db': 'neo4j'}
# DEBUG:neo4j.io:[#F88E]  C: COMMIT
# DEBUG:neo4j.io:[#F88E]  _: <CONNECTION> client state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.io:[#F88E]  S: SUCCESS {'bookmark': 'FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAiJA='}
# DEBUG:neo4j.io:[#F88E]  _: <CONNECTION> server state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.pool:[#F88E]  _: <POOL> released bolt-25
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_17196\2671942141.py:21: DeprecationWarning: read_transaction has been renamed to execute_read
#   graph_data = session.read_transaction(fetch_graph)

# %%
from pyvis.network import Network
from IPython.display import IFrame

# Create a PyVis network graph
# This will visualize the graph data using PyVis

net = Network(notebook=True, height="600px", width="100%", cdn_resources='in_line')

for node in nodes:
    net.add_node(node, label=node)

for source, target, rel in edges:
    net.add_edge(source, target, label=rel)

# Save the graph to an HTML file
# This will create an interactive HTML file that can be viewed in a web browser
net.show("neo4j_graph.html")
# Out:
# neo4j_graph.html
#         <iframe
#             width="100%"
#             height="600px"
#             src="neo4j_graph.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
