# %%
import os
import sys
import logging

# %%
logging.basicConfig(stream=sys.stdout, level=logging.DEBUG) 
# logging.DEBUG for debug, logging.INFO for info

# %%
from llama_index.core import (
    KnowledgeGraphIndex,
    # LLMPredictor,
    ServiceContext,
    SimpleDirectoryReader,
)

# %%
from llama_index.core.storage.storage_context import StorageContext
from llama_index.graph_stores.nebula import NebulaGraphStore

# %%
from langchain import OpenAI
from IPython.display import Markdown, display

# %%
# Install dependencies
# !pip install InstructorEmbedding torch transformers sentence-transformers
# !pip uninstall -y transformers sentence-transformers InstructorEmbedding
# !pip install transformers==4.31.0 sentence-transformers==2.2.2 InstructorEmbedding
# !pip install wikipedia
# %pip install ipython-ngql nebula3-python
# %pip install llama-index-graph-stores-neo4j
# %pip install neo4j

# %%
# from typing import Any, List
# from InstructorEmbedding import INSTRUCTOR


# from llama_index.core.bridge.pydantic import PrivateAttr
# from llama_index.core.embeddings import BaseEmbedding

# %%
from llama_index.core import SimpleDirectoryReader, VectorStoreIndex
from llama_index.core import Settings

# %%
import requests
from typing import Any, List
from llama_index.core.embeddings import BaseEmbedding
from llama_index.core.bridge.pydantic import PrivateAttr

# %%
# This is a custom embedding class for remote instructor embeddings
# It uses the requests library to make HTTP POST requests to a remote server
# to get the embeddings for the provided texts.
# The class is initialized with the base URL of the server, an API key for authentication,
# the model name, and an instruction string.


class RemoteInstructorEmbeddings(BaseEmbedding):
    _base_url: str = PrivateAttr()
    _api_key: str = PrivateAttr()
    _model_name: str = PrivateAttr()
    _instruction: str = PrivateAttr()

    def __init__(
        self,
        base_url: str,
        api_key: str,
        model_name: str = "snowflake-arctic-embed-s",  # Change as needed
        # model_name: str, 
        instruction: str = "Represent the text for semantic search:",
        **kwargs: Any,
    ):
        super().__init__(**kwargs)
        self._base_url = base_url.rstrip("/")
        self._api_key = api_key
        self._model_name = model_name
        self._instruction = instruction

    def _post_request(self, texts: List[str]) -> List[List[float]]:
        headers = {
            "Authorization": f"Bearer {self._api_key}",
            "Content-Type": "application/json"
        }

        # If you want to keep using instructions
        inputs = [f"{self._instruction} {text}" for text in texts]

        payload = {
            "model": self._model_name,
            "input": inputs if len(inputs) > 1 else inputs[0]  # API accepts string or list
        }

        response = requests.post(
            f"{self._base_url}/embeddings",
            headers=headers,
            json=payload
        )
        response.raise_for_status()
        return response.json()["data"]
    
    async def _aget_query_embedding(self, query: str) -> List[float]:
        return self._get_query_embedding(query)

    async def _aget_text_embedding(self, text: str) -> List[float]:
        return self._get_text_embedding(text)
    
    def _get_query_embedding(self, query: str) -> List[float]:
        return self._post_request([query])[0]

    def _get_text_embedding(self, text: str) -> List[float]:
        return self._post_request([text])[0]

    def _get_text_embeddings(self, texts: List[str]) -> List[List[float]]:
        return self._post_request(texts)

# %%
# from llama_index.core import Settings
# from llama_index.core import SimpleDirectoryReader, VectorStoreIndex

embed_model_snow = RemoteInstructorEmbeddings(
    base_url="http://llms-inference.innkube.fim.uni-passau.de",
    api_key="sk-Fr2TEolkvrxjjs235KJqkg",
    model_name="Snowflake/snowflake-arctic-embed-xs",  # or whatever model your server uses
)

embed_model_intfloat = RemoteInstructorEmbeddings(
    base_url="http://llms-inference.innkube.fim.uni-passau.de",
    api_key="sk-Fr2TEolkvrxjjs235KJqkg",
    model_name="intfloat/multilingual-e5-large",  # or whatever model your server uses
)

embed_model_jinaai = RemoteInstructorEmbeddings(
    base_url="http://llms-inference.innkube.fim.uni-passau.de",
    api_key="sk-Fr2TEolkvrxjjs235KJqkg",
    model_name="jinaai/jina-embeddings-v2-base-de",  # or whatever model your server uses
)


# Example usage
sentence = "What did the author do growing up?"

# %%
embedding_snow = embed_model_snow._get_query_embedding(sentence)

print(f"Embedding vector:\n{embedding_snow}")
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): llms-inference.innkube.fim.uni-passau.de:80
# DEBUG:urllib3.connectionpool:http://llms-inference.innkube.fim.uni-passau.de:80 "POST /embeddings HTTP/1.1" 308 164
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): llms-inference.innkube.fim.uni-passau.de:443
# DEBUG:urllib3.connectionpool:https://llms-inference.innkube.fim.uni-passau.de:443 "POST /embeddings HTTP/1.1" 200 4883
# Embedding vector:
# {'object': 'embedding', 'index': 0, 'embedding': [0.03755944, 0.03179579, -0.0016535937, -0.006316622, -0.007491683, -0.0060295025, -0.088815525, -0.019279521, 0.062740855, 0.013409528, -0.0010979649, 0.09170799, -0.0106818965, -0.044152547, 0.015897894, 0.018162945, -0.045811456, 0.084051475, -0.10999854, -0.017663145, -0.014483566, 0.08315822, -0.0026611693, 0.029541371, -0.016801788, 0.02788246, -0.047512904, 0.0020483825, 0.013643477, -0.094855666, 0.043025337, 0.011601741, -0.012261052, -0.037495635, -0.027818657, -0.045428634, 0.030519703, -0.00079290086, -0.05478659, -0.052404564, -0.014143277, 0.019917563, 0.0052505587, -0.010852041, -0.026287355, -0.06495274, -0.011718716, -0.01967298, 0.020800188, 0.094090015, -0.10208681, -0.07345997, -0.01912001, 0.037176613, -0.022033738, 0.01672735, 0.0274571, -0.055849995, 0.036985204, -0.022969533, 0.054106012, 0.06656911, -0.26372427, -0.044577908, 0.0036873545, 0.026266087, -0.023586307, -0.042812657, -0.00080154097, 0.02611721, -0.03222115, 0.032816656, 0.044492837, 0.01838626, -0.0031981885, -0.065845996, 0.014345324, -0.008278603, 0.10455391, 0.0024896953, 0.051043406, 0.021640278, -0.021746619, 0.013813622, 0.011261452, 0.024394495, -0.03824002, -0.07911728, 0.04776812, -0.0022517587, -0.017865192, -0.051851593, 0.009007035, -0.0058008707, -0.051681448, 0.009692931, 0.007177979, 0.0274571, 0.025521703, 0.31731984, 0.037282955, 0.0020204682, -0.010357558, -0.040983602, -0.032922998, -0.042366028, -0.025585508, 0.030349558, 0.029179813, 0.054020938, -0.0049262205, -0.04776812, -0.0524471, -0.00093513116, -0.004564663, 0.056062676, -0.040047806, -0.026861593, 0.039494835, 0.020747017, -0.01433469, 0.026925396, -0.02543663, 0.03675125, -0.011474133, 0.0089964, 0.0065824725, 0.058955133, 0.0509158, -0.0049102693, 0.0007171333, 0.031264085, -0.0579768, 0.0050564874, -0.021629643, -0.04034556, 0.008438113, -0.08804987, 0.0224591, -0.014015669, -0.01438786, -0.10115102, 0.08830509, 0.01378172, 0.10302261, 0.065250486, 0.005101682, 0.004314763, -0.020821456, -0.09613175, 0.011165746, 0.047257688, 0.004434396, 0.0014741442, 0.011623009, -0.01008639, -0.05712608, -0.027924998, -0.01951347, 0.02656384, -0.07784119, -0.028967133, 0.0394523, 0.05602014, 0.04755544, -0.026585108, 0.014462299, 0.036836326, 0.09238856, -0.0067100814, 0.05346797, -0.013526503, 0.04364211, 0.07273685, -0.0062847193, -0.041153748, 0.04389733, 0.03668745, 0.008273286, -0.08132916, 0.027435832, 0.06848324, 0.010410728, -0.04164291, -0.023650112, -0.017971532, 0.044152547, 0.05248964, 0.028286554, 0.07316221, 0.0030732385, 0.093579575, 0.0077894367, -0.020523703, -0.016429596, -0.0073162215, -0.003434796, 0.020098342, 0.04179179, -0.036091942, 0.014653712, -0.0053436067, -0.09255871, -0.0008739854, 0.0002804729, -0.0059976005, -0.023713917, -0.0052080224, -0.031731986, -0.05912528, 0.0045620045, -0.032518905, 0.075629316, -0.023628844, 0.059040207, 0.0066090575, -0.00021085313, 0.003690013, 0.04968225, 0.058614846, 0.014972732, 0.0006430273, -0.03900567, -0.07307714, -0.03322075, -0.0017320197, -0.01656784, 0.017131444, 0.0035411364, -0.053723186, 0.022714317, 0.06363411, 0.06848324, 0.0873693, 0.00044363897, 0.046917398, -0.026500035, 0.0017599341, 0.051809058, -0.02177852, 0.01822675, -0.047427833, 0.018152311, 0.006635643, -0.02043863, -0.0014515469, -0.04602414, -0.04555624, 0.024607176, 0.11629389, 0.07826655, 0.01144223, -0.015142878, 0.031327892, 0.011452864, 0.0644423, -0.11152984, 0.030838724, -0.024032937, 0.03466698, 0.023862792, -0.0838388, 0.014962099, -0.0070397365, 0.0659736, -0.0279888, -0.06627136, -0.024841124, -0.013037337, -0.04810841, -0.065250486, 0.032625243, -0.015759652, -0.028137678, -0.02511761, 0.027393294, 0.0034374543, -0.0015525703, -0.051511306, -0.040707115, 0.038750455, 0.010517068, -0.00437325, 0.018152311, -0.075544246, 0.048065875, -0.09791827, -0.016918762, -0.037772123, 0.0033656745, -0.04525849, -0.06554824, 0.01194203, -0.015982967, 0.14292154, 0.012792754, 0.032965533,  ...

# %%
embedding_intfloat = embed_model_intfloat._get_query_embedding(sentence)

print(f"Embedding vector:\n{embedding_intfloat}")
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): llms-inference.innkube.fim.uni-passau.de:80
# DEBUG:urllib3.connectionpool:http://llms-inference.innkube.fim.uni-passau.de:80 "POST /embeddings HTTP/1.1" 308 164
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): llms-inference.innkube.fim.uni-passau.de:443
# DEBUG:urllib3.connectionpool:https://llms-inference.innkube.fim.uni-passau.de:443 "POST /embeddings HTTP/1.1" 200 12859
# Embedding vector:
# {'object': 'embedding', 'index': 0, 'embedding': [-0.0053951642, -0.013991855, -0.02413849, -0.046007115, 0.026205083, -0.035877418, -0.00933355, 0.08340907, 0.02869516, -0.03106666, 0.026018752, 0.025730783, -0.049191702, -0.034064915, -0.0435001, -0.01627866, -0.02437564, 0.046040993, 0.005115666, -0.011518719, 0.026679384, -0.023511736, -0.02866128, -0.0329808, -0.007199199, -0.003658887, -0.027763499, -0.012416501, -0.012585893, -0.04949661, -0.016837656, -0.009934895, -0.037097048, -0.011459431, -0.047430016, 0.033184074, 0.033963278, 0.042009443, -0.026459174, 0.023054376, -0.023969097, 0.054171853, -0.02608651, -0.025104031, -0.025425877, 0.0116711715, 0.035098214, -0.0073685916, -0.010332968, 0.020598179, 0.024206247, 0.03851995, -0.00103065, -0.008461176, -0.044177674, 0.029762335, -0.02654387, 0.011789747, -0.04641366, -0.00752528, -0.0105362395, -0.029084764, 0.035030454, -0.0136869475, -0.040789813, 0.027627984, 0.03110054, 0.010739511, -0.04258538, 0.010129697, -0.033590615, 0.026154267, -0.044618092, -0.022309046, -0.023952158, -0.012382622, 0.025544452, -0.0011614002, 0.028102284, 0.0032354046, 0.04803983, -0.014008794, 0.030643178, -0.016219372, 0.03516597, 0.03757135, 0.025222605, 0.036622748, 0.02534118, 0.02584936, -0.024240127, 0.05329101, 0.02344398, -0.02989785, -0.02393522, -0.006525862, 0.05068236, 0.047938194, 0.0031845868, 0.018717917, 0.009248853, -0.027441652, 0.021140236, -0.052952226, -0.022681711, 0.0033645667, 0.011518719, 0.026425295, 0.031676475, 0.012501197, 0.032642014, 0.025019333, 0.016634384, -0.023630312, -0.023291526, -0.01029062, 0.018955067, -0.016295599, -0.035741907, 0.018345254, 0.04803983, 0.043838885, -0.0014948925, -0.044753607, 0.012323335, -0.013797053, 0.02464667, 0.02535812, 0.0020189518, 0.013365101, 0.023511736, 0.05119054, -0.042754773, -0.02556139, -0.03352286, -0.0416029, 7.404323e-05, -0.01985285, -0.013670009, -0.03990897, -0.0107903285, 0.033421222, 0.028136164, -0.033590615, -0.054917183, -0.04204332, -0.05400246, -0.0019511946, -0.022512319, -0.022918861, 0.022088837, -0.029271096, -0.010815738, 0.02845801, 0.041264113, -0.030795632, -0.015008212, 0.033793885, 0.03513209, -0.0013540846, -0.03162566, -0.03252344, 0.0017500406, -0.0136869475, -0.0114170825, -0.018768735, 0.026848776, 0.05213914, 0.011052888, -0.025917117, -0.01985285, -0.048209224, 0.03919752, -0.047904316, -0.0060642664, 0.02559527, 0.07006091, 0.026713263, 0.04902231, -0.018751796, 0.008952416, 0.0363856, 0.032642014, -0.017032458, -0.0030384853, 0.030253574, 0.057085413, 0.0016642854, 0.026103448, 0.032811407, 0.01123922, -0.052952226, -0.0025218371, 0.030439908, -0.031049721, 0.06213332, 0.044753607, 0.04224659, -0.015440164, -0.032387927, 0.01266212, 0.041704535, -0.0229358, 0.007931823, 0.007991111, -0.0177185, -0.029796213, -0.0435001, 0.05044521, -0.044550337, -0.03201526, -0.026001813, 0.023291526, -0.015236893, -0.04448258, -0.04068818, -0.019514063, -0.014627079, 0.007881005, 0.001770156, -0.0008268492, 0.041535143, 0.021462083, 0.0074194097, 0.025883237, 0.030050304, 0.029813154, 0.025256483, 0.055188213, -0.023833584, 0.012458849, 0.041264113, -0.04783656, -0.0238844, 0.0039764987, -0.025188727, -0.009062521, -0.035030454, 0.029796213, 0.02700123, -0.035945177, 0.011306977, 0.012755287, -0.011281569, -0.01863322, -0.010468482, 0.017167972, -0.034928817, 0.033133253, -0.016126206, 0.041467387, 0.016177023, -0.026374476, 0.0019363727, 0.051766474, 0.01934467, 0.032591198, -0.016066918, -0.01744747, -0.04739614, 0.017870953, 0.0049801515, -0.008240965, 0.02462973, 0.010248272, 0.010883495, -0.02820392, -0.031168297, -0.020394906, -0.02102166, -0.03753747, -0.029017007, -0.041433506, -0.040755935, -0.017515227, -0.012484258, -0.015922934, -0.015008212, -0.000841671, 0.023630312, 0.0033285709, -0.001726749, 0.03990897, -0.056001298, -0.0012715056, -0.022054957, 0.047633287, -0.0368599, 0.028271677, -0.02080145, 0.028051468, -0.024511155, 0.10319416, 0.020716753, -0.014516973, 0.03159178, -0.0 ...

# %%
embedding_jinaai = embed_model_jinaai._get_query_embedding(sentence)

print(f"Embedding vector:\n{embedding_jinaai}")
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): llms-inference.innkube.fim.uni-passau.de:80
# DEBUG:urllib3.connectionpool:http://llms-inference.innkube.fim.uni-passau.de:80 "POST /embeddings HTTP/1.1" 308 164
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): llms-inference.innkube.fim.uni-passau.de:443
# DEBUG:urllib3.connectionpool:https://llms-inference.innkube.fim.uni-passau.de:443 "POST /embeddings HTTP/1.1" 200 9678
# Embedding vector:
# {'object': 'embedding', 'index': 0, 'embedding': [0.01325042, -0.074396856, -0.024057414, 0.046972133, 0.032117072, -0.039483823, -0.06496353, 0.036031418, 0.004974986, 0.02041051, -0.03136338, -0.023328034, 0.041890778, -0.050327286, 0.04631569, 0.0415504, 0.014222928, -0.004838227, 0.03702824, -0.010460538, -0.0030314894, -0.033624463, -0.03722274, 0.017371424, 0.014089208, 0.0014466055, -0.012715541, 0.011159528, -0.014830746, -0.033429958, 0.032433137, -0.08485132, 0.095500275, -0.044808302, 0.017492985, -0.0070871515, -0.058885355, 0.01541425, 0.011323639, -0.030512435, -0.007062839, 0.025406769, -0.034864407, -0.007998877, 0.013663736, -0.03984851, 0.0075126234, 0.052320927, -0.002669838, 0.05256405, -0.08878997, 0.012411633, 0.061413873, -0.029928932, -0.017492985, 0.034451094, 0.069096684, 0.020349728, 0.0549467, -0.0670058, -0.049986906, -0.019960726, 0.0478717, 0.0038140544, 0.026379278, -0.046729006, 0.060927622, 0.029175237, 0.07099308, -0.0139919575, 0.05640546, -0.030682625, 0.044200484, -0.008776884, -0.014235085, -0.115339436, 0.02866467, 0.037271366, 0.018599214, -0.011858518, 0.025285205, -0.053633813, 0.032919392, 0.0024419066, -0.0017945811, 0.05723209, 0.018234523, -0.047920328, 0.0007601517, 0.022647278, -0.0050236112, -0.019717598, 0.014563306, 0.04259585, -0.0004209136, 0.08353843, 0.013153169, -0.025358144, -0.023303721, -0.0047592106, 0.030342247, -0.0055858423, 0.047093697, -0.01015663, 0.05966336, 0.009646063, -0.016338132, -0.061267998, 0.027716476, -0.024653075, 0.043544043, 0.013578642, -0.025382457, 0.020094445, 0.026792593, 0.057280716, 0.040966894, -0.017444361, 0.05407144, 0.03902188, -0.028956423, -0.018659996, -0.019425845, -0.031217504, -0.04035908, 0.0702637, 0.019766223, 0.0013493547, 0.023729194, 0.0070263697, -0.031412005, 0.044735365, -0.0074700764, -0.016897324, 0.08582383, 0.004804797, -0.0024510238, -0.022622965, 0.025333831, -0.016216569, -0.02334019, 0.035472225, 0.00892276, 0.0103572095, -0.08533757, 0.013274733, -0.030561062, -0.066276416, -0.025479708, 0.078578636, 0.0018553628, -0.007840845, -0.0032244716, -0.021589676, 0.017833363, -0.02983168, 0.051786046, 0.034840096, 0.019839162, -0.025649896, 0.061754253, 0.08217692, -0.007384982, -0.005719562, 0.047725827, 0.015973443, -0.03685805, -0.046121188, 0.030974377, 0.025017766, -0.028810548, 0.025722835, -0.011639704, 0.0028415467, 0.048625395, -0.0030208528, -0.044929866, 0.03289508, 0.042304095, -0.036250234, -0.04913596, -0.0205807, 0.01301945, 0.02496914, -0.012727697, 0.019827005, -0.011244623, -0.037198428, 0.0035374975, -0.036201607, 0.012125958, 0.00075559306, -0.024081727, 0.06530391, -0.07541799, 0.051786046, -0.0036955301, 0.04522162, 0.03498597, -0.034913033, 0.011858518, -0.035010286, -0.04325229, 0.02064148, -0.025382457, 0.039799888, 0.026743967, -0.03452403, 0.029928932, 0.03975126, -0.009621751, 0.032311574, 0.032676265, 0.022161024, 0.020994015, -0.025309518, -0.0139919575, -0.03000187, 0.026209088, -0.0051694876, 0.0020225125, -0.0152319055, 0.045391805, -0.011834206, -0.018793715, -0.020763043, -0.06870768, 0.039240696, 0.0027822843, -0.03296802, 0.060684495, -0.05659996, -0.02456798, -0.0027929212, 0.00087677664, 0.0046224515, -0.056843087, -0.020167382, 0.062240507, 0.021091266, 0.026209088, 0.02693847, -0.02640359, 0.0325547, 0.0048990087, 0.011110903, -0.0012680591, 0.05596783, 0.03941088, 0.009810174, -0.0029980596, -0.024446419, -0.0023264212, 0.05387694, 0.040407702, 0.0032092761, -0.014636244, -0.026841218, 0.11378343, -0.04181784, -0.022914717, -0.004321582, 0.012350851, -0.04038339, 0.026987094, 0.020617168, -0.020434823, 0.01162147, 0.04198803, 0.023328034, 0.064234145, 0.0048230314, 0.022647278, 0.0354236, -0.03452403, 0.048357956, 0.033016644, -0.064282775, 0.018757246, 0.07546661, 0.07731438, -0.010727978, 0.039240696, -0.012861418, 0.028032541, -0.03999439, 0.01951094, 0.048090518, -0.02847017, 0.039872825, 0.006661679, -0.07872452, 0.081836544, -0.04913596, -0.01675145, 0.06885356, 0.0453918 ...

# %%
import os
from llama_index.core import download_loader

# %%
# Load the WikipediaReader
WikipediaReader = download_loader("WikipediaReader")
loader = WikipediaReader()

# Define the page you want to fetch
page_title = 'Guardians of the Galaxy Vol. 3'

# Load data from Wikipedia
documents = loader.load_data(pages=[page_title], auto_suggest=False)

# Prepare folder and filename
folder_name = 'wiki_data'
os.makedirs(folder_name, exist_ok=True)

# Clean filename (remove special characters, keep it safe)
safe_filename = page_title.replace(" ", "_").replace("/", "_") + ".txt"
file_path = os.path.join(folder_name, safe_filename)

# Save the text content
with open(file_path, "w", encoding="utf-8") as f:
    for doc in documents:
        f.write(doc.text + "\n\n")

print(f"Saved to: {file_path}")
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_17196\332848010.py:2: DeprecationWarning: Call to deprecated function (or staticmethod) download_loader. (`download_loader()` is deprecated. Please install tool using pip install directly instead.)
#   WikipediaReader = download_loader("WikipediaReader")
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): en.wikipedia.org:80
# DEBUG:urllib3.connectionpool:http://en.wikipedia.org:80 "GET /w/api.php?prop=info%7Cpageprops&inprop=url&ppprop=disambiguation&redirects=&titles=Guardians+of+the+Galaxy+Vol.+3&format=json&action=query HTTP/1.1" 301 0
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): en.wikipedia.org:443
# DEBUG:urllib3.connectionpool:https://en.wikipedia.org:443 "GET /w/api.php?prop=info%7Cpageprops&inprop=url&ppprop=disambiguation&redirects=&titles=Guardians+of+the+Galaxy+Vol.+3&format=json&action=query HTTP/1.1" 200 299
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): en.wikipedia.org:80
# DEBUG:urllib3.connectionpool:http://en.wikipedia.org:80 "GET /w/api.php?prop=extracts%7Crevisions&explaintext=&rvprop=ids&titles=Guardians+of+the+Galaxy+Vol.+3&format=json&action=query HTTP/1.1" 301 0
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): en.wikipedia.org:443
# DEBUG:urllib3.connectionpool:https://en.wikipedia.org:443 "GET /w/api.php?prop=extracts%7Crevisions&explaintext=&rvprop=ids&titles=Guardians+of+the+Galaxy+Vol.+3&format=json&action=query HTTP/1.1" 200 None
# Saved to: wiki_data\Guardians_of_the_Galaxy_Vol._3.txt

# %%
from llama_index.llms.openai_like import OpenAILike
from llama_index.core.llms import ChatMessage

# %%
llm_qwen = OpenAILike(
  api_base="https://llms-inference.innkube.fim.uni-passau.de",
  api_key="sk-Fr2TEolkvrxjjs235KJqkg",
  model="qwen2.5")

# %%
# %%time
messages = [
    ChatMessage(
        role="system", content="You are a assitant that helps to provide knowledge and information."
    ),
    ChatMessage(role="user", content="Tell me more about Rocket"),
]
resp = llm_qwen.chat(messages)
# Out:
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/completions', 'files': None, 'idempotency_key': 'stainless-python-retry-5dbb9e5c-6ff1-4941-8da3-76b6b26d4a94', 'json_data': {'model': 'qwen2.5', 'prompt': 'system: You are a assitant that helps to provide knowledge and information.\nuser: Tell me more about Rocket\nassistant: ', 'stream': False, 'temperature': 0.1}}
# DEBUG:openai._base_client:Sending HTTP Request: POST https://llms-inference.innkube.fim.uni-passau.de/completions
# DEBUG:httpcore.connection:close.started
# DEBUG:httpcore.connection:close.complete
# DEBUG:httpcore.connection:connect_tcp.started host='llms-inference.innkube.fim.uni-passau.de' port=443 local_address=None timeout=60.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x00000146843D7A90>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x0000014683DF7BC0> server_hostname='llms-inference.innkube.fim.uni-passau.de' timeout=60.0
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x00000146844415B0>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Tue, 29 Apr 2025 07:02:33 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'2723'), (b'Connection', b'keep-alive'), (b'x-litellm-call-id', b'10e6f408-e3fa-4c22-b4d2-24627147a33c'), (b'x-litellm-model-id', b'4fc98ad04997d06d243fa1037a8527856cb537a73abc970ce37122958bbea148'), (b'x-litellm-model-api-base', b'http://qwen2-5-ollama:11434'), (b'x-litellm-version', b'1.42.2'), (b'x-litellm-response-cost', b'0.290881'), (b'x-litellm-key-tpm-limit', b'None'), (b'x-litellm-key-rpm-limit', b'100'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains'), (b'Access-Control-Allow-Origin', b'*'), (b'Access-Control-Allow-Credentials', b'true'), (b'Access-Control-Allow-Methods', b'PUT, GET, POST'), (b'Access-Control-Allow-Headers', b'DNT,Keep-Alive,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range,Authorization'), (b'Access-Control-Max-Age', b'1728000')])
# INFO:httpx:HTTP Request: POST https://llms-inference.innkube.fim.uni-passau.de/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Response: POST https://llms-inference.innkube.fim.uni-passau.de/completions "200 OK" Headers({'date': 'Tue, 29 Apr 2025 07:02:33 GMT', 'content-type': 'application/json', 'content-length': '2723', 'connection': 'keep-alive', 'x-litellm-call-id': '10e6f408-e3fa-4c22-b4d2-24627147a33c', 'x-litellm-model-id': '4fc98ad04997d06d243fa1037a8527856cb537a73abc970ce37122958bbea148', 'x-litellm-model-api-base': 'http://qwen2-5-ollama:11434', 'x-litellm-version': '1.42.2', 'x-litellm-response-cost': '0.290881', 'x-litellm-key-tpm-limit': 'None', 'x-litellm-key-rpm-limit': '100', 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'access-control-allow-origin': '*', 'access-control-allow-credentials': 'true', 'access-control-allow-methods': 'PUT, GET, POST', 'access-control-allow-headers': 'DNT,Keep-Alive,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range,Authorization', 'access-control-max-age': '1728000'})
# DEBUG:openai._base_client:request_id: None
# CPU times: total: 0 ns
# Wall time: 23.9 s

# %%
# print(dict(resp))
# print(dir(resp.message.blocks[0]))
print(resp.message.blocks[0].text)
# Out:
# ['__abstractmethods__', '__annotations__', '__class__', '__class_getitem__', '__class_vars__', '__copy__', '__deepcopy__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__fields__', '__fields_set__', '__format__', '__ge__', '__get_pydantic_core_schema__', '__get_pydantic_json_schema__', '__getattr__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__pretty__', '__private_attributes__', '__pydantic_complete__', '__pydantic_computed_fields__', '__pydantic_core_schema__', '__pydantic_custom_init__', '__pydantic_decorators__', '__pydantic_extra__', '__pydantic_fields__', '__pydantic_fields_set__', '__pydantic_generic_metadata__', '__pydantic_init_subclass__', '__pydantic_parent_namespace__', '__pydantic_post_init__', '__pydantic_private__', '__pydantic_root_model__', '__pydantic_serializer__', '__pydantic_setattr_handlers__', '__pydantic_validator__', '__reduce__', '__reduce_ex__', '__replace__', '__repr__', '__repr_args__', '__repr_name__', '__repr_recursion__', '__repr_str__', '__rich_repr__', '__setattr__', '__setstate__', '__signature__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_calculate_keys', '_copy_and_set_values', '_get_value', '_iter', '_setattr_handler', 'block_type', 'construct', 'copy', 'dict', 'from_orm', 'json', 'model_computed_fields', 'model_config', 'model_construct', 'model_copy', 'model_dump', 'model_dump_json', 'model_extra', 'model_fields', 'model_fields_set', 'model_json_schema', 'model_parametrized_name', 'model_post_init', 'model_rebuild', 'model_validate', 'model_validate_json', 'model_validate_strings', 'parse_file', 'parse_obj', 'parse_raw', 'schema', 'schema_json', 'text', 'update_forward_refs', 'validate']

# %%
from llama_index.graph_stores.neo4j import Neo4jGraphStore
from llama_index.core.storage.storage_context import StorageContext

graph_store = Neo4jGraphStore(
    username="neo4j",
    password="neo4j123",
    url="bolt://localhost:7687",
    database="neo4j"
)

storage_context = StorageContext.from_defaults(graph_store=graph_store)
# Out:
# DEBUG:neo4j.pool:[#0000]  _: <POOL> created, direct address IPv4Address(('localhost', 7687))
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> routing towards fixed database: None
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> pinning database: None
# DEBUG:neo4j.pool:[#0000]  _: <POOL> acquire direct connection, access_mode='READ', database=AcquisitionDatabase(name=None, guessed=False)
# DEBUG:neo4j.pool:[#0000]  _: <POOL> trying to hand out new connection
# DEBUG:neo4j.io:[#0000]  _: <RESOLVE> in: localhost:7687
# DEBUG:neo4j.io:[#0000]  _: <RESOLVE> dns resolver out: [::1]:7687
# DEBUG:neo4j.io:[#0000]  C: <OPEN> [::1]:7687
# DEBUG:neo4j.io:[#0000]  S: <ERROR> ConnectionRefusedError 10061 'Es konnte keine Verbindung hergestellt werden, da der Zielcomputer die Verbindung verweigerte' None 10061 None
# DEBUG:neo4j.io:[#0000]  C: <CLOSE> [::1]:7687
# DEBUG:neo4j.io:[#0000]  S: <CONNECTION FAILED> [::1]:7687 ServiceUnavailable: Failed to establish connection to ResolvedIPv6Address(('::1', 7687, 0, 0)) (reason [WinError 10061] Es konnte keine Verbindung hergestellt werden, da der Zielcomputer die Verbindung verweigerte)
# DEBUG:neo4j.io:[#0000]  _: <RESOLVE> dns resolver out: 127.0.0.1:7687
# DEBUG:neo4j.io:[#0000]  C: <OPEN> 127.0.0.1:7687
# DEBUG:neo4j.io:[#EC63]  C: <MAGIC> 0x6060B017
# DEBUG:neo4j.io:[#EC63]  C: <HANDSHAKE> 0x000001FF 0x00080805 0x00020404 0x00000003
# DEBUG:neo4j.io:[#EC63]  S: <HANDSHAKE> 0x00000605
# DEBUG:neo4j.io:[#EC63]  C: HELLO {'user_agent': 'neo4j-python/5.28.1 Python/3.9.21-final-0 (win32)', 'bolt_agent': {'product': 'neo4j-python/5.28.1', 'platform': 'Windows 10; AMD64', 'language': 'Python/3.9.21-final-0', 'language_details': 'CPython; 3.9.21-final-0 (main, Apr  9 2025 09:02:40) [MSC v.1929 64 bit (AMD64)]'}}
# DEBUG:neo4j.io:[#EC63]  _: <CONNECTION> client state: CONNECTED > AUTHENTICATION
# DEBUG:neo4j.io:[#EC63]  C: LOGON {'scheme': 'basic', 'principal': 'neo4j', 'credentials': '*******'}
# DEBUG:neo4j.io:[#EC63]  _: <CONNECTION> client state: AUTHENTICATION > READY
# DEBUG:neo4j.io:[#EC63]  S: SUCCESS {'server': 'Neo4j/5.24.0', 'connection_id': 'bolt-5', 'hints': {'connection.recv_timeout_seconds': 120}}
# DEBUG:neo4j.io:[#EC63]  _: <CONNECTION> server state: CONNECTED > AUTHENTICATION
# DEBUG:neo4j.io:[#EC63]  S: SUCCESS {}
# DEBUG:neo4j.io:[#EC63]  _: <CONNECTION> server state: AUTHENTICATION > READY
# DEBUG:neo4j.pool:[#EC63]  _: <POOL> released bolt-5
# DEBUG:neo4j.pool:[#0000]  _: <POOL> close
# DEBUG:neo4j.io:[#EC63]  C: GOODBYE
# DEBUG:neo4j.io:[#EC63]  C: <CLOSE>
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> routing towards fixed database: neo4j
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> pinning database: 'neo4j'
# DEBUG:neo4j.pool:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database=AcquisitionDatabase(name='neo4j', guessed=False)
# DEBUG:neo4j.pool:[#0000]  _: <POOL> trying to hand out new connection
# DEBUG:neo4j.io:[#0000]  _: <RESOLVE> in: localhost:7687
# DEBUG:neo4j.io:[#0000]  _: <RESOLVE> dns resolver out: [::1]:7687
# DEBUG:neo4j.io:[#0000]  C: <OPEN> [::1]:7687
# DEBUG:neo4j.io:[#0000]  S: <ERROR> ConnectionRefusedError 10061 'Es konnte keine Verbindung hergestellt werden, da der Zielcomputer die Verbindung verweigerte' None 10061 None
# DEBUG:neo4j.io:[#0000]  C: <CLOSE> [::1]:7687
# DEBUG:neo4j.io:[#0000]  S: <CONNECTION FAILED> [::1]:7687 ServiceUnavailable: Failed to establish connection to ResolvedIPv6Address(('::1', 7687, 0, 0)) (reason [WinError 10061] Es konnte keine Verbindung hergestellt werden, da der Zielcomputer die Verbindung verweigerte)
# DEBUG:neo4j.io:[#0000]  _: <RESOLVE> dns resolver out: 127.0.0.1:7687
# DEBUG:neo4j.io:[#0000]  C: <OPEN> 127.0.0.1:7687
# DEBUG:neo4j.io:[#EC65]  C: <MAGIC> 0x6060B017
# DEBUG:neo4j.io:[#EC65]  C: <HANDSHAKE> 0x000001FF 0x00080805 0x00020404 0x00000003
# DEBUG:neo4j.io:[#EC65]  S: <HANDSHAKE> 0x00000605
# DEBUG:neo4j.io:[#EC65]  C: HELLO {'user_agent': 'neo4j-python/5.28.1 Python/3.9.21-final-0 (win32)', 'bolt_agent': {'product': 'neo4j-python/5.28.1', 'platform': 'Windows 10; AMD64', 'language': 'Python/3.9.21-final-0', 'language_details': 'CPython; 3.9.21-final-0 (main, Apr  9 2025 09:02:40) [MSC v.1929 64 bit (AMD64)]'}}
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> client state: CONNECTED > AUTHENTICATION
# DEBUG:neo4j.io:[#EC65]  C: LOGON {'scheme': 'basic', 'principal': 'neo4j', 'credentials': '*******'}
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> client state: AUTHENTICATION > READY
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {'server': 'Neo4j/5.24.0', 'connection_id': 'bolt-6', 'hints': {'connection.recv_timeout_seconds': 120}}
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> server state: CONNECTED > AUTHENTICATION
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {}
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> server state: AUTHENTICATION > READY
# DEBUG:neo4j.io:[#EC65]  C: BEGIN {'db': 'neo4j'}
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> client state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#EC65]  C: RUN '\nCALL apoc.meta.data()\nYIELD label, other, elementType, type, property\nWHERE NOT type = "RELATIONSHIP" AND elementType = "node"\nWITH label AS nodeLabels, collect({property:property, type:type}) AS properties\nRETURN {labels: nodeLabels, properties: properties} AS output\n\n' {} {}
# DEBUG:neo4j.io:[#EC65]  C: PULL {'n': 1000}
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {}
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> server state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {'t_first': 280, 'fields': ['output'], 'qid': 0}
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {'statuses': [{'gql_status': '02000', 'status_description': 'note: no data'}], 'type': 'r', 't_last': 8, 'db': 'neo4j'}
# DEBUG:neo4j.io:[#EC65]  C: COMMIT
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> client state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {'bookmark': 'FB:kcwQBKSVGJtoSZS3C7vmPo+vEgKQ'}
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> server state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> released bolt-6
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> routing towards fixed database: neo4j
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> pinning database: 'neo4j'
# DEBUG:neo4j.pool:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database=AcquisitionDatabase(name='neo4j', guessed=False)
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> picked existing connection bolt-6
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> handing out existing connection
# DEBUG:neo4j.io:[#EC65]  C: BEGIN {'db': 'neo4j', 'bookmarks': ['FB:kcwQBKSVGJtoSZS3C7vmPo+vEgKQ']}
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> client state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#EC65]  C: RUN '\nCALL apoc.meta.data()\nYIELD label, other, elementType, type, property\nWHERE NOT type = "RELATIONSHIP" AND elementType = "relationship"\nWITH label AS nodeLabels, collect({property:property, type:type}) AS properties\nRETURN {type: nodeLabels, properties: properties} AS output\n' {} {}
# DEBUG:neo4j.io:[#EC65]  C: PULL {'n': 1000}
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {}
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> server state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {'t_first': 151, 'fields': ['output'], 'qid': 0}
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {'statuses': [{'gql_status': '02000', 'status_description': 'note: no data'}], 'type': 'r', 't_last': 3, 'db': 'neo4j'}
# DEBUG:neo4j.io:[#EC65]  C: COMMIT
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> client state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {'bookmark': 'FB:kcwQBKSVGJtoSZS3C7vmPo+vEgKQ'}
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> server state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> released bolt-6
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> routing towards fixed database: neo4j
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> pinning database: 'neo4j'
# DEBUG:neo4j.pool:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database=AcquisitionDatabase(name='neo4j', guessed=False)
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> picked existing connection bolt-6
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> handing out existing connection
# DEBUG:neo4j.io:[#EC65]  C: BEGIN {'db': 'neo4j', 'bookmarks': ['FB:kcwQBKSVGJtoSZS3C7vmPo+vEgKQ']}
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> client state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#EC65]  C: RUN '\nCALL apoc.meta.data()\nYIELD label, other, elementType, type, property\nWHERE type = "RELATIONSHIP" AND elementType = "node"\nUNWIND other AS other_node\nRETURN {start: label, type: property, end: toString(other_node)} AS output\n' {} {}
# DEBUG:neo4j.io:[#EC65]  C: PULL {'n': 1000}
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {}
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> server state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {'t_first': 155, 'fields': ['output'], 'qid': 0}
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {'statuses': [{'gql_status': '02000', 'status_description': 'note: no data'}], 'type': 'r', 't_last': 3, 'db': 'neo4j'}
# DEBUG:neo4j.io:[#EC65]  C: COMMIT
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> client state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {'bookmark': 'FB:kcwQBKSVGJtoSZS3C7vmPo+vEgKQ'}
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> server state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> released bolt-6
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> routing towards fixed database: neo4j
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> pinning database: 'neo4j'
# DEBUG:neo4j.pool:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database=AcquisitionDatabase(name='neo4j', guessed=False)
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> picked existing connection bolt-6
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> handing out existing connection
# DEBUG:neo4j.io:[#EC65]  C: BEGIN {'db': 'neo4j', 'bookmarks': ['FB:kcwQBKSVGJtoSZS3C7vmPo+vEgKQ']}
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> client state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#EC65]  C: RUN '\n                CREATE CONSTRAINT IF NOT EXISTS FOR (n:Entity) REQUIRE n.id IS UNIQUE;\n                ' {} {}
# DEBUG:neo4j.io:[#EC65]  C: PULL {'n': 1000}
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {}
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> server state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {'t_first': 155, 'fields': [], 'qid': 0}
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {'stats': {'contains-updates': True, 'constraints-added': 1}, 'statuses': [{'gql_status': '00001', 'status_description': 'note: successful completion - omitted result'}], 'type': 's', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j.io:[#EC65]  C: COMMIT
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> client state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {'bookmark': 'FB:kcwQBKSVGJtoSZS3C7vmPo+vEgaQ'}
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> server state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> released bolt-6

# %%
print(dir(Neo4jGraphStore))
print(dir(NebulaGraphStore))
# Out:
# ['__abstractmethods__', '__annotations__', '__class__', '__class_getitem__', '__del__', '__delattr__', '__dict__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__parameters__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_is_protocol', '_is_runtime_protocol', 'client', 'close', 'delete', 'get', 'get_rel_map', 'get_schema', 'persist', 'query', 'refresh_schema', 'schema', 'upsert_triplet']
# ['__abstractmethods__', '__annotations__', '__class__', '__class_getitem__', '__del__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__parameters__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_get_vid_type', '_is_protocol', '_is_runtime_protocol', 'client', 'config_dict', 'delete', 'execute', 'from_dict', 'get', 'get_flat_rel_map', 'get_rel_map', 'get_schema', 'init_session_pool', 'persist', 'query', 'refresh_schema', 'schema', 'upsert_triplet']

# %%
# Set global settings (optional, if not passed locally)
Settings.llm = llm_qwen
Settings.embed_model = embed_model_snow
Settings.chunk_size = 512

# %%
# NOTE: can take a while!
index = KnowledgeGraphIndex.from_documents(
    documents,
    storage_context=storage_context,
    max_triplets_per_chunk=2,
)
# Out:
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: Guardians of the Galaxy Vol. 3 (marketed as Gua...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: His return was publicly revealed in March 2019,...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: The Guardians travel to Orgocorp's headquarters...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: They are followed by Ayesha and Adam after the ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: The other Guardians orchestrate a rescue, which...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: The new Guardians—Rocket, Groot, Kraglin, Cosmo...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: Dave Bautista as Drax the Destroyer:A member of...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: Pom Klementieff as Mantis: A member of the Guar...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: Poulter believed there was "a lot of comedy" in...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: Gunn likened the High Evolutionary to "a space ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: Maria Bakalova reprises her voice and motion ca...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: Cameo appearances in the film include Lloyd Kau...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: In March 2017, Gunn said there would be a third...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 3 shortly after completing his work as executiv...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: In April, Chris Pratt was set to reprise his ro...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: My days saying something just because it's shoc...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: Despite this and the notable "vociferous suppor...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: for their rival superhero franchise, the DC Ext...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: At the end of the month, Cooper was asked if he...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: By the end of April, the franchise's five main ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: In June, Saldaña was asked about her role in th...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: In April, Gunn said the COVID-19 pandemic would...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: Gunn noted this ending was decided upon "in edi...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: Gunn originally wrote a cameo appearance for Ku...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: Poulter was cast as Adam Warlock in October, an...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: Iwuji's screen test for the film was shot on th...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 3, given the tonal difference between the two w...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: == Music ==
#
# In April 2017, Gunn felt the music...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: == Marketing ==
#
# The film was discussed during ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: Hermanns also said the second trailer "goes a s...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: === Home media ===
# Guardians of the Galaxy Vol....
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: === Critical response ===
# The review aggregator...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: Matt Singer from ScreenCrush praised the film f...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: A negative review from NPR criticized the appro...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: == Notes ==
#
#
# == References ==
#
#
# == External li...
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/completions', 'files': None, 'idempotency_key': 'stainless-python-retry-838dc8c7-3202-4909-b81c-600a09bcc4aa', 'json_data': {'model': 'qwen2.5', 'prompt': "Some text is provided below. Given the text, extract up to 2 knowledge triplets in the form of (subject, predicate, object). Avoid stopwords.\n---------------------\nExample:Text: Alice is Bob's mother.Triplets:\n(Alice, is mother of, Bob)\nText: Philz is a coffee shop founded in Berkeley in 1982.\nTriplets:\n(Philz, is, coffee shop)\n(Philz, founded in, Berkeley)\n(Philz, founded in, 1982)\n---------------------\nText: Guardians of the Galaxy Vol. 3 (marketed as Guardians of the Galaxy Volume 3) is a 2023 American superhero film based on the Marvel Comics superhero team Guardians of the Galaxy, produced by Marvel Studios and distributed by Walt Disney Studios Motion Pictures. It is the sequel to Guardians of the Galaxy (2014) and Guardians of the Galaxy Vol. 2 (2017), and the 32nd film in the Marvel Cinematic Universe (MCU). Written and directed by James Gunn, it features an ensemble cast including Chris Pratt, Zoe Saldaña, Dave Bautista, Karen Gillan, Pom Klementieff, Vin Diesel, Bradley Cooper, Will Poulter, Sean Gunn, Chukwudi Iwuji, Linda Cardellini, Nathan Fillion, and Sylvester Stallone. In the film, the other Guardians race to save the life of Rocket (Cooper) from his creator, the High Evolutionary (Iwuji), who is an alien scientist trying to perfect the universe.\nGunn had initial ideas for a third and final Guardians of the Galaxy film by November 2014, and announced his return to write and direct in April 2017 ahead of Vol. 2's release. Vol. 3 explores the origin story of Rocket, with whom Gunn personally identifies. Disney fired Gunn from Vol. 3 in July 2018 after controversial jokes he made on Twitter resurfaced. Gunn received support from several cast members, and the studio reversed course by that October. His return was publicly revealed in March 2019, and he restarted work on the film after completing his film The Suicide Squad (2021) and the first season of its spin-off series Peacemaker (2022) for DC Films. New cast members, including Iwuji and Poulter, joined by the start of filming, which took place at Trilith Studios in Atlanta, Georgia, from November 2021 to May 2022.\nGuardians of the Galaxy Vol. 3 premiered at Disneyland Paris on April 22, 2023, and was released in the United States on May 5, as part of Phase Five of the MCU. Like its predecessors, it was a critical and commercial success, with many deeming it to be a satisfactory conclusion to the trilogy. It grossed over $845.6 million worldwide, becoming the fourth-highest-grossing film of 2023.\nTriplets:\n", 'stream': False, 'temperature': 0.1}}
# DEBUG:openai._base_client:Sending HTTP Request: POST https://llms-inference.innkube.fim.uni-passau.de/completions
# DEBUG:httpcore.connection:connect_tcp.started host='llms-inference.innkube.fim.uni-passau.de' port=443 local_address=None timeout=60.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x0000014683FE7970>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x0000014683DF7BC0> server_hostname='llms-inference.innkube.fim.uni-passau.de' timeout=60.0
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x0000014683FE77F0>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Tue, 29 Apr 2025 06:44:13 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'405'), (b'Connection', b'keep-alive'), (b'x-litellm-call-id', b'cbb9eb26-922c-4906-b5eb-474857043b4e'), (b'x-litellm-model-id', b'4fc98ad04997d06d243fa1037a8527856cb537a73abc970ce37122958bbea148'), (b'x-litellm-model-api-base', b'http://qwen2-5-ollama:11434'), (b'x-litellm-version', b'1.42.2'), (b'x-litellm-response-cost', b'0.30311799999999994'), (b'x-litellm-key-tpm-limit', b'None'), (b'x-litellm-key-rpm-limit', b'100'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains'), (b'Access-Control-Allow-Origin', b'*'), (b'Access-Control-Allow-Credentials', b'true'), (b'Access-Control-Allow-Methods', b'PUT, GET, POST'), (b'Access-Control-Allow-Headers', b'DNT,Keep-Alive,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range,Authorization'), (b'Access-Control-Max-Age', b'1728000')])
# INFO:httpx:HTTP Request: POST https://llms-inference.innkube.fim.uni-passau.de/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Response: POST https://llms-inference.innkube.fim.uni-passau.de/completions "200 OK" Headers({'date': 'Tue, 29 Apr 2025 06:44:13 GMT', 'content-type': 'application/json', 'content-length': '405', 'connection': 'keep-alive', 'x-litellm-call-id': 'cbb9eb26-922c-4906-b5eb-474857043b4e', 'x-litellm-model-id': '4fc98ad04997d06d243fa1037a8527856cb537a73abc970ce37122958bbea148', 'x-litellm-model-api-base': 'http://qwen2-5-ollama:11434', 'x-litellm-version': '1.42.2', 'x-litellm-response-cost': '0.30311799999999994', 'x-litellm-key-tpm-limit': 'None', 'x-litellm-key-rpm-limit': '100', 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'access-control-allow-origin': '*', 'access-control-allow-credentials': 'true', 'access-control-allow-methods': 'PUT, GET, POST', 'access-control-allow-headers': 'DNT,Keep-Alive,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range,Authorization', 'access-control-max-age': '1728000'})
# DEBUG:openai._base_client:request_id: None
# DEBUG:llama_index.core.indices.knowledge_graph.base:> Extracted triplets: [('Guardians of the galaxy vol. 3', 'Is', 'Superhero film'), ('Guardians of the galaxy vol. 3', 'Produced by', 'Marvel studios')]
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> routing towards fixed database: neo4j
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> pinning database: 'neo4j'
# DEBUG:neo4j.pool:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database=AcquisitionDatabase(name='neo4j', guessed=False)
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> picked existing connection bolt-6
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> handing out existing connection
# DEBUG:neo4j.io:[#EC65]  C: RUN '\n            MERGE (n1:`Entity` {id:$subj})\n            MERGE (n2:`Entity` {id:$obj})\n            MERGE (n1)-[:`IS`]->(n2)\n        ' {'subj': 'Guardians of the galaxy vol. 3', 'obj': 'Superhero film'} {'db': 'neo4j'}
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> client state: READY > STREAMING
# DEBUG:neo4j.io:[#EC65]  C: PULL {'n': 1000}
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {'t_first': 676, 'fields': []}
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {'bookmark': 'FB:kcwQBKSVGJtoSZS3C7vmPo+vEgiQ', 'stats': {'contains-updates': True, 'labels-added': 2, 'relationships-created': 1, 'nodes-created': 2, 'properties-set': 2}, 'statuses': [{'gql_status': '00001', 'status_description': 'note: successful completion - omitted result'}], 'type': 'w', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> released bolt-6
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> routing towards fixed database: neo4j
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> pinning database: 'neo4j'
# DEBUG:neo4j.pool:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database=AcquisitionDatabase(name='neo4j', guessed=False)
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> picked existing connection bolt-6
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> handing out existing connection
# DEBUG:neo4j.io:[#EC65]  C: RUN '\n            MERGE (n1:`Entity` {id:$subj})\n            MERGE (n2:`Entity` {id:$obj})\n            MERGE (n1)-[:`PRODUCED_BY`]->(n2)\n        ' {'subj': 'Guardians of the galaxy vol. 3', 'obj': 'Marvel studios'} {'db': 'neo4j'}
# DEBUG:neo4j.io:[#EC65]  C: PULL {'n': 1000}
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {'t_first': 163, 'fields': []}
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {'bookmark': 'FB:kcwQBKSVGJtoSZS3C7vmPo+vEgqQ', 'stats': {'contains-updates': True, 'labels-added': 1, 'relationships-created': 1, 'nodes-created': 1, 'properties-set': 1}, 'statuses': [{'gql_status': '00001', 'status_description': 'note: successful completion - omitted result'}], 'type': 'w', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> released bolt-6
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/completions', 'files': None, 'idempotency_key': 'stainless-python-retry-a56ae6d4-84e3-41f8-9da6-bdb6360b6699', 'json_data': {'model': 'qwen2.5', 'prompt': 'Some text is provided below. Given the text, extract up to 2 knowledge triplets in the form of (subject, predicate, object). Avoid stopwords.\n---------------------\nExample:Text: Alice is Bob\'s mother.Triplets:\n(Alice, is mother of, Bob)\nText: Philz is a coffee shop founded in Berkeley in 1982.\nTriplets:\n(Philz, is, coffee shop)\n(Philz, founded in, Berkeley)\n(Philz, founded in, 1982)\n---------------------\nText: His return was publicly revealed in March 2019, and he restarted work on the film after completing his film The Suicide Squad (2021) and the first season of its spin-off series Peacemaker (2022) for DC Films. New cast members, including Iwuji and Poulter, joined by the start of filming, which took place at Trilith Studios in Atlanta, Georgia, from November 2021 to May 2022.\nGuardians of the Galaxy Vol. 3 premiered at Disneyland Paris on April 22, 2023, and was released in the United States on May 5, as part of Phase Five of the MCU. Like its predecessors, it was a critical and commercial success, with many deeming it to be a satisfactory conclusion to the trilogy. It grossed over $845.6 million worldwide, becoming the fourth-highest-grossing film of 2023. At the 96th Academy Awards, the film was nominated for Best Visual Effects.\n\n\n== Plot ==\nAt their new headquarters on Knowhere, the Guardians of the Galaxy are attacked by Adam Warlock, a Sovereign warrior created by High Priestess Ayesha who seeks to destroy them for stealing from her. After critically wounding Rocket, Adam is stabbed by Nebula and flees. The Guardians\' med-packs are ineffective at healing Rocket\'s wounds due to a kill switch embedded in him by the organization Orgocorp. The Guardians travel to Orgocorp\'s headquarters to find the switch\'s override code and save Rocket\'s life.\nAs Rocket lies dying, he recalls his past. He was found and experimented on as a baby raccoon by the High Evolutionary, leader of Orgocorp, who aimed to enhance and anthropomorphize animal lifeforms into "Humanimals" for an ideal society, Counter-Earth. Rocket\'s fellow Batch 89 test subjects included the otter Lylla, walrus Teefs, and rabbit Floor. Impressed by Rocket\'s intelligence, the High Evolutionary used his insights to improve later batches of Humanimals. Angry that one of his creations could solve a problem that he could not, the High Evolutionary planned to harvest Rocket\'s brain and incinerate all of Batch 89. Rocket tried to rescue his friends, but the High Evolutionary killed Lylla and mocked Rocket\'s grief.\nTriplets:\n', 'stream': False, 'temperature': 0.1}}
# DEBUG:openai._base_client:Sending HTTP Request: POST https://llms-inference.innkube.fim.uni-passau.de/completions
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Tue, 29 Apr 2025 06:44:16 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'416'), (b'Connection', b'keep-alive'), (b'x-litellm-call-id', b'e7b2a945-d737-4dbb-b120-b65fdb193805'), (b'x-litellm-model-id', b'4fc98ad04997d06d243fa1037a8527856cb537a73abc970ce37122958bbea148'), (b'x-litellm-model-api-base', b'http://qwen2-5-ollama:11434'), (b'x-litellm-version', b'1.42.2'), (b'x-litellm-response-cost', b'0.290166'), (b'x-litellm-key-tpm-limit', b'None'), (b'x-litellm-key-rpm-limit', b'100'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains'), (b'Access-Control-Allow-Origin', b'*'), (b'Access-Control-Allow-Credentials', b'true'), (b'Access-Control-Allow-Methods', b'PUT, GET, POST'), (b'Access-Control-Allow-Headers', b'DNT,Keep-Alive,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range,Authorization'), (b'Access-Control-Max-Age', b'1728000')])
# INFO:httpx:HTTP Request: POST https://llms-inference.innkube.fim.uni-passau.de/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Response: POST https://llms-inference.innkube.fim.uni-passau.de/completions "200 OK" Headers({'date': 'Tue, 29 Apr 2025 06:44:16 GMT', 'content-type': 'application/json', 'content-length': '416', 'connection': 'keep-alive', 'x-litellm-call-id': 'e7b2a945-d737-4dbb-b120-b65fdb193805', 'x-litellm-model-id': '4fc98ad04997d06d243fa1037a8527856cb537a73abc970ce37122958bbea148', 'x-litellm-model-api-base': 'http://qwen2-5-ollama:11434', 'x-litellm-version': '1.42.2', 'x-litellm-response-cost': '0.290166', 'x-litellm-key-tpm-limit': 'None', 'x-litellm-key-rpm-limit': '100', 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'access-control-allow-origin': '*', 'access-control-allow-credentials': 'true', 'access-control-allow-methods': 'PUT, GET, POST', 'access-control-allow-headers': 'DNT,Keep-Alive,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range,Authorization', 'access-control-max-age': '1728000'})
# DEBUG:openai._base_client:request_id: None
# DEBUG:llama_index.core.indices.knowledge_graph.base:> Extracted triplets: [('Guardians of the galaxy vol. 3', 'Premiered at', 'Disneyland paris'), ('Guardians of the galaxy vol. 3', 'Released in', 'United states')]
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> routing towards fixed database: neo4j
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> pinning database: 'neo4j'
# DEBUG:neo4j.pool:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database=AcquisitionDatabase(name='neo4j', guessed=False)
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> picked existing connection bolt-6
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> handing out existing connection
# DEBUG:neo4j.io:[#EC65]  C: RUN '\n            MERGE (n1:`Entity` {id:$subj})\n            MERGE (n2:`Entity` {id:$obj})\n            MERGE (n1)-[:`PREMIERED_AT`]->(n2)\n        ' {'subj': 'Guardians of the galaxy vol. 3', 'obj': 'Disneyland paris'} {'db': 'neo4j'}
# DEBUG:neo4j.io:[#EC65]  C: PULL {'n': 1000}
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {'t_first': 84, 'fields': []}
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {'bookmark': 'FB:kcwQBKSVGJtoSZS3C7vmPo+vEgyQ', 'stats': {'contains-updates': True, 'labels-added': 1, 'relationships-created': 1, 'nodes-created': 1, 'properties-set': 1}, 'statuses': [{'gql_status': '00001', 'status_description': 'note: successful completion - omitted result'}], 'type': 'w', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> released bolt-6
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> routing towards fixed database: neo4j
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> pinning database: 'neo4j'
# DEBUG:neo4j.pool:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database=AcquisitionDatabase(name='neo4j', guessed=False)
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> picked existing connection bolt-6
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> handing out existing connection
# DEBUG:neo4j.io:[#EC65]  C: RUN '\n            MERGE (n1:`Entity` {id:$subj})\n            MERGE (n2:`Entity` {id:$obj})\n            MERGE (n1)-[:`RELEASED_IN`]->(n2)\n        ' {'subj': 'Guardians of the galaxy vol. 3', 'obj': 'United states'} {'db': 'neo4j'}
# DEBUG:neo4j.io:[#EC65]  C: PULL {'n': 1000}
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {'t_first': 96, 'fields': []}
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {'bookmark': 'FB:kcwQBKSVGJtoSZS3C7vmPo+vEg6Q', 'stats': {'contains-updates': True, 'labels-added': 1, 'relationships-created': 1, 'nodes-created': 1, 'properties-set': 1}, 'statuses': [{'gql_status': '00001', 'status_description': 'note: successful completion - omitted result'}], 'type': 'w', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> released bolt-6
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/completions', 'files': None, 'idempotency_key': 'stainless-python-retry-cf819f84-69af-4012-a2d0-a908c73b9816', 'json_data': {'model': 'qwen2.5', 'prompt': 'Some text is provided below. Given the text, extract up to 2 knowledge triplets in the form of (subject, predicate, object). Avoid stopwords.\n---------------------\nExample:Text: Alice is Bob\'s mother.Triplets:\n(Alice, is mother of, Bob)\nText: Philz is a coffee shop founded in Berkeley in 1982.\nTriplets:\n(Philz, is, coffee shop)\n(Philz, founded in, Berkeley)\n(Philz, founded in, 1982)\n---------------------\nText: The Guardians travel to Orgocorp\'s headquarters to find the switch\'s override code and save Rocket\'s life.\nAs Rocket lies dying, he recalls his past. He was found and experimented on as a baby raccoon by the High Evolutionary, leader of Orgocorp, who aimed to enhance and anthropomorphize animal lifeforms into "Humanimals" for an ideal society, Counter-Earth. Rocket\'s fellow Batch 89 test subjects included the otter Lylla, walrus Teefs, and rabbit Floor. Impressed by Rocket\'s intelligence, the High Evolutionary used his insights to improve later batches of Humanimals. Angry that one of his creations could solve a problem that he could not, the High Evolutionary planned to harvest Rocket\'s brain and incinerate all of Batch 89. Rocket tried to rescue his friends, but the High Evolutionary killed Lylla and mocked Rocket\'s grief. Enraged, Rocket attacked the High Evolutionary, whose henchmen killed Teefs and Floor during the chaos. Rocket escaped in a spaceship.\nIn the present, an alternate version of Gamora, who has joined the Ravagers, helps the Guardians infiltrate Orgocorp. They retrieve Rocket\'s file but discover that Theel, one of the High Evolutionary\'s advisors, has removed the override code. The Guardians and Gamora travel to Counter-Earth to find him. They are followed by Ayesha and Adam after the High Evolutionary, their race\'s creator, threatened to wipe out the Sovereign if they failed to retrieve Rocket. At Counter-Earth, Drax and Mantis remain with Gamora and Rocket while Peter Quill, Groot, and Nebula go to the High Evolutionary\'s Arête Laboratories complex. Guards force Nebula to wait outside due to her cybernetic enhancements; Quill and Groot enter Arête. Drax tricks Mantis into pursuing Quill\'s group and Gamora saves Rocket from Adam and War Pig, one of the High Evolutionary\'s Hellspawn guards.\nThe High Evolutionary agrees with Quill that Counter-Earth is imperfect and begins bombarding the entire planet, killing the Humanimals and Ayesha. Arête, which is actually a spaceship, departs as Nebula, Drax, and Mantis board it to rescue Quill and Groot.\nTriplets:\n', 'stream': False, 'temperature': 0.1}}
# DEBUG:openai._base_client:Sending HTTP Request: POST https://llms-inference.innkube.fim.uni-passau.de/completions
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Tue, 29 Apr 2025 06:44:19 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'425'), (b'Connection', b'keep-alive'), (b'x-litellm-call-id', b'88fa4b18-fd94-4fe5-a8d5-53c24c14751e'), (b'x-litellm-model-id', b'4fc98ad04997d06d243fa1037a8527856cb537a73abc970ce37122958bbea148'), (b'x-litellm-model-api-base', b'http://qwen2-5-ollama:11434'), (b'x-litellm-version', b'1.42.2'), (b'x-litellm-response-cost', b'0.279344'), (b'x-litellm-key-tpm-limit', b'None'), (b'x-litellm-key-rpm-limit', b'100'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains'), (b'Access-Control-Allow-Origin', b'*'), (b'Access-Control-Allow-Credentials', b'true'), (b'Access-Control-Allow-Methods', b'PUT, GET, POST'), (b'Access-Control-Allow-Headers', b'DNT,Keep-Alive,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range,Authorization'), (b'Access-Control-Max-Age', b'1728000')])
# INFO:httpx:HTTP Request: POST https://llms-inference.innkube.fim.uni-passau.de/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Response: POST https://llms-inference.innkube.fim.uni-passau.de/completions "200 OK" Headers({'date': 'Tue, 29 Apr 2025 06:44:19 GMT', 'content-type': 'application/json', 'content-length': '425', 'connection': 'keep-alive', 'x-litellm-call-id': '88fa4b18-fd94-4fe5-a8d5-53c24c14751e', 'x-litellm-model-id': '4fc98ad04997d06d243fa1037a8527856cb537a73abc970ce37122958bbea148', 'x-litellm-model-api-base': 'http://qwen2-5-ollama:11434', 'x-litellm-version': '1.42.2', 'x-litellm-response-cost': '0.279344', 'x-litellm-key-tpm-limit': 'None', 'x-litellm-key-rpm-limit': '100', 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'access-control-allow-origin': '*', 'access-control-allow-credentials': 'true', 'access-control-allow-methods': 'PUT, GET, POST', 'access-control-allow-headers': 'DNT,Keep-Alive,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range,Authorization', 'access-control-max-age': '1728000'})
# DEBUG:openai._base_client:request_id: None
# DEBUG:llama_index.core.indices.knowledge_graph.base:> Extracted triplets: [('Rocket', 'Found and experimented on by', 'High evolutionary'), ('High evolutionary', 'Aimed to enhance and anthropomorphize', 'Animal lifeforms')]
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> routing towards fixed database: neo4j
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> pinning database: 'neo4j'
# DEBUG:neo4j.pool:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database=AcquisitionDatabase(name='neo4j', guessed=False)
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> picked existing connection bolt-6
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> handing out existing connection
# DEBUG:neo4j.io:[#EC65]  C: RUN '\n            MERGE (n1:`Entity` {id:$subj})\n            MERGE (n2:`Entity` {id:$obj})\n            MERGE (n1)-[:`FOUND_AND_EXPERIMENTED_ON_BY`]->(n2)\n        ' {'subj': 'Rocket', 'obj': 'High evolutionary'} {'db': 'neo4j'}
# DEBUG:neo4j.io:[#EC65]  C: PULL {'n': 1000}
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {'t_first': 113, 'fields': []}
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {'bookmark': 'FB:kcwQBKSVGJtoSZS3C7vmPo+vEhCQ', 'stats': {'contains-updates': True, 'labels-added': 2, 'relationships-created': 1, 'nodes-created': 2, 'properties-set': 2}, 'statuses': [{'gql_status': '00001', 'status_description': 'note: successful completion - omitted result'}], 'type': 'w', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> released bolt-6
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> routing towards fixed database: neo4j
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> pinning database: 'neo4j'
# DEBUG:neo4j.pool:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database=AcquisitionDatabase(name='neo4j', guessed=False)
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> picked existing connection bolt-6
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> handing out existing connection
# DEBUG:neo4j.io:[#EC65]  C: RUN '\n            MERGE (n1:`Entity` {id:$subj})\n            MERGE (n2:`Entity` {id:$obj})\n            MERGE (n1)-[:`AIMED_TO_ENHANCE_AND_ANTHROPOMORPHIZE`]->(n2)\n        ' {'subj': 'High evolutionary', 'obj': 'Animal lifeforms'} {'db': 'neo4j'}
# DEBUG:neo4j.io:[#EC65]  C: PULL {'n': 1000}
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {'t_first': 66, 'fields': []}
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {'bookmark': 'FB:kcwQBKSVGJtoSZS3C7vmPo+vEhKQ', 'stats': {'contains-updates': True, 'labels-added': 1, 'relationships-created': 1, 'nodes-created': 1, 'properties-set': 1}, 'statuses': [{'gql_status': '00001', 'status_description': 'note: successful completion - omitted result'}], 'type': 'w', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> released bolt-6
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/completions', 'files': None, 'idempotency_key': 'stainless-python-retry-fee8ee9d-8ed9-4004-aa6e-c5d671ee40b4', 'json_data': {'model': 'qwen2.5', 'prompt': "Some text is provided below. Given the text, extract up to 2 knowledge triplets in the form of (subject, predicate, object). Avoid stopwords.\n---------------------\nExample:Text: Alice is Bob's mother.Triplets:\n(Alice, is mother of, Bob)\nText: Philz is a coffee shop founded in Berkeley in 1982.\nTriplets:\n(Philz, is, coffee shop)\n(Philz, founded in, Berkeley)\n(Philz, founded in, 1982)\n---------------------\nText: They are followed by Ayesha and Adam after the High Evolutionary, their race's creator, threatened to wipe out the Sovereign if they failed to retrieve Rocket. At Counter-Earth, Drax and Mantis remain with Gamora and Rocket while Peter Quill, Groot, and Nebula go to the High Evolutionary's Arête Laboratories complex. Guards force Nebula to wait outside due to her cybernetic enhancements; Quill and Groot enter Arête. Drax tricks Mantis into pursuing Quill's group and Gamora saves Rocket from Adam and War Pig, one of the High Evolutionary's Hellspawn guards.\nThe High Evolutionary agrees with Quill that Counter-Earth is imperfect and begins bombarding the entire planet, killing the Humanimals and Ayesha. Arête, which is actually a spaceship, departs as Nebula, Drax, and Mantis board it to rescue Quill and Groot. However, the latter pair jump off the spaceship with Theel, whom they kill before retrieving the override code from his corpse. They are rescued by Gamora on their ship. As they use the code, Rocket flatlines and has a near-death experience in which he reunites with Lylla, Teefs, and Floor. Lylla tells him his time has not yet come, and Quill succeeds in disabling the kill switch and restarting Rocket's heart.\nDrax, Nebula, and Mantis encounter the High Evolutionary's next batch of test subjects—genetically modified humanoid children—before they are captured. The other Guardians orchestrate a rescue, which leads to a battle against the High Evolutionary's forces. Kraglin opens fire on Arête with Knowhere and then helps to save Knowhere citizens from a counter-attack by the High Evolutionary's Hellspawn. Intent on retreat, the High Evolutionary's crew mutinies, but their leader kills them. Drax, Nebula, and Mantis befriend three monstrous Abilisks to escape and reunite with the rest of the Guardians. The Guardians delay leaving Arête, choosing to rescue the children, who escape to Knowhere via a tunnel constructed by Cosmo's telekinesis. Rocket discovers imprisoned animals on the ship and is confronted by the High Evolutionary, whom the other Guardians defeat. Rocket spares the High Evolutionary, and the Guardians help the animals escape to Knowhere.\nTriplets:\n", 'stream': False, 'temperature': 0.1}}
# DEBUG:openai._base_client:Sending HTTP Request: POST https://llms-inference.innkube.fim.uni-passau.de/completions
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Tue, 29 Apr 2025 06:44:22 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'358'), (b'Connection', b'keep-alive'), (b'x-litellm-call-id', b'3dd13563-f2aa-49d6-ba6a-3927976370b4'), (b'x-litellm-model-id', b'4fc98ad04997d06d243fa1037a8527856cb537a73abc970ce37122958bbea148'), (b'x-litellm-model-api-base', b'http://qwen2-5-ollama:11434'), (b'x-litellm-version', b'1.42.2'), (b'x-litellm-response-cost', b'0.278478'), (b'x-litellm-key-tpm-limit', b'None'), (b'x-litellm-key-rpm-limit', b'100'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains'), (b'Access-Control-Allow-Origin', b'*'), (b'Access-Control-Allow-Credentials', b'true'), (b'Access-Control-Allow-Methods', b'PUT, GET, POST'), (b'Access-Control-Allow-Headers', b'DNT,Keep-Alive,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range,Authorization'), (b'Access-Control-Max-Age', b'1728000')])
# INFO:httpx:HTTP Request: POST https://llms-inference.innkube.fim.uni-passau.de/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Response: POST https://llms-inference.innkube.fim.uni-passau.de/completions "200 OK" Headers({'date': 'Tue, 29 Apr 2025 06:44:22 GMT', 'content-type': 'application/json', 'content-length': '358', 'connection': 'keep-alive', 'x-litellm-call-id': '3dd13563-f2aa-49d6-ba6a-3927976370b4', 'x-litellm-model-id': '4fc98ad04997d06d243fa1037a8527856cb537a73abc970ce37122958bbea148', 'x-litellm-model-api-base': 'http://qwen2-5-ollama:11434', 'x-litellm-version': '1.42.2', 'x-litellm-response-cost': '0.278478', 'x-litellm-key-tpm-limit': 'None', 'x-litellm-key-rpm-limit': '100', 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'access-control-allow-origin': '*', 'access-control-allow-credentials': 'true', 'access-control-allow-methods': 'PUT, GET, POST', 'access-control-allow-headers': 'DNT,Keep-Alive,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range,Authorization', 'access-control-max-age': '1728000'})
# DEBUG:openai._base_client:request_id: None
# DEBUG:llama_index.core.indices.knowledge_graph.base:> Extracted triplets: [('Ayesha', 'Followed', 'Adam'), ('High evolutionary', 'Threatened', 'Sovereign')]
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> routing towards fixed database: neo4j
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> pinning database: 'neo4j'
# DEBUG:neo4j.pool:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database=AcquisitionDatabase(name='neo4j', guessed=False)
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> picked existing connection bolt-6
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> handing out existing connection
# DEBUG:neo4j.io:[#EC65]  C: RUN '\n            MERGE (n1:`Entity` {id:$subj})\n            MERGE (n2:`Entity` {id:$obj})\n            MERGE (n1)-[:`FOLLOWED`]->(n2)\n        ' {'subj': 'Ayesha', 'obj': 'Adam'} {'db': 'neo4j'}
# DEBUG:neo4j.io:[#EC65]  C: PULL {'n': 1000}
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {'t_first': 56, 'fields': []}
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {'bookmark': 'FB:kcwQBKSVGJtoSZS3C7vmPo+vEhSQ', 'stats': {'contains-updates': True, 'labels-added': 2, 'relationships-created': 1, 'nodes-created': 2, 'properties-set': 2}, 'statuses': [{'gql_status': '00001', 'status_description': 'note: successful completion - omitted result'}], 'type': 'w', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> released bolt-6
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> routing towards fixed database: neo4j
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> pinning database: 'neo4j'
# DEBUG:neo4j.pool:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database=AcquisitionDatabase(name='neo4j', guessed=False)
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> picked existing connection bolt-6
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> handing out existing connection
# DEBUG:neo4j.io:[#EC65]  C: RUN '\n            MERGE (n1:`Entity` {id:$subj})\n            MERGE (n2:`Entity` {id:$obj})\n            MERGE (n1)-[:`THREATENED`]->(n2)\n        ' {'subj': 'High evolutionary', 'obj': 'Sovereign'} {'db': 'neo4j'}
# DEBUG:neo4j.io:[#EC65]  C: PULL {'n': 1000}
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {'t_first': 137, 'fields': []}
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {'bookmark': 'FB:kcwQBKSVGJtoSZS3C7vmPo+vEhaQ', 'stats': {'contains-updates': True, 'labels-added': 1, 'relationships-created': 1, 'nodes-created': 1, 'properties-set': 1}, 'statuses': [{'gql_status': '00001', 'status_description': 'note: successful completion - omitted result'}], 'type': 'w', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> released bolt-6
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/completions', 'files': None, 'idempotency_key': 'stainless-python-retry-f2f6f7be-e7c6-4db0-b5cf-91c74db33f3d', 'json_data': {'model': 'qwen2.5', 'prompt': 'Some text is provided below. Given the text, extract up to 2 knowledge triplets in the form of (subject, predicate, object). Avoid stopwords.\n---------------------\nExample:Text: Alice is Bob\'s mother.Triplets:\n(Alice, is mother of, Bob)\nText: Philz is a coffee shop founded in Berkeley in 1982.\nTriplets:\n(Philz, is, coffee shop)\n(Philz, founded in, Berkeley)\n(Philz, founded in, 1982)\n---------------------\nText: The other Guardians orchestrate a rescue, which leads to a battle against the High Evolutionary\'s forces. Kraglin opens fire on Arête with Knowhere and then helps to save Knowhere citizens from a counter-attack by the High Evolutionary\'s Hellspawn. Intent on retreat, the High Evolutionary\'s crew mutinies, but their leader kills them. Drax, Nebula, and Mantis befriend three monstrous Abilisks to escape and reunite with the rest of the Guardians. The Guardians delay leaving Arête, choosing to rescue the children, who escape to Knowhere via a tunnel constructed by Cosmo\'s telekinesis. Rocket discovers imprisoned animals on the ship and is confronted by the High Evolutionary, whom the other Guardians defeat. Rocket spares the High Evolutionary, and the Guardians help the animals escape to Knowhere. Quill nearly dies trying to reach Knowhere but is saved by Adam, whom Groot had earlier rescued from Arête\'s destruction.\nQuill decides to leave the Guardians, names Rocket as the new captain, and reunites with his grandfather Jason on Earth. Mantis embarks on a journey of self-discovery with the Abilisks, Gamora rejoins the Ravagers, and Nebula and Drax remain on Knowhere to raise the rescued children. The new Guardians—Rocket, Groot, Kraglin, Cosmo, Adam, Phyla (one of the rescued children), and Adam\'s pet Blurp—later take on a mission.\n\n\n== Cast ==\n\nChris Pratt as Peter Quill / Star-Lord:The half-human, half-Celestial leader of the Guardians of the Galaxy who was abducted from Earth as a child and raised by a group of alien thieves and smugglers, the Ravagers. In the film, Quill is in a "state of depression" following the appearance of a variant of his dead lover Gamora, who does not share the same affection for Quill as her older version had for him, which in turn affects his leadership of the Guardians.\nZoe Saldaña as Gamora:An orphan who seeks redemption for her past crimes, and was adopted and trained by Thanos to be his personal assassin.\nTriplets:\n', 'stream': False, 'temperature': 0.1}}
# DEBUG:openai._base_client:Sending HTTP Request: POST https://llms-inference.innkube.fim.uni-passau.de/completions
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Tue, 29 Apr 2025 06:44:25 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'365'), (b'Connection', b'keep-alive'), (b'x-litellm-call-id', b'a1f2e930-3f80-40ea-a54f-74505c46d155'), (b'x-litellm-model-id', b'4fc98ad04997d06d243fa1037a8527856cb537a73abc970ce37122958bbea148'), (b'x-litellm-model-api-base', b'http://qwen2-5-ollama:11434'), (b'x-litellm-version', b'1.42.2'), (b'x-litellm-response-cost', b'0.265897'), (b'x-litellm-key-tpm-limit', b'None'), (b'x-litellm-key-rpm-limit', b'100'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains'), (b'Access-Control-Allow-Origin', b'*'), (b'Access-Control-Allow-Credentials', b'true'), (b'Access-Control-Allow-Methods', b'PUT, GET, POST'), (b'Access-Control-Allow-Headers', b'DNT,Keep-Alive,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range,Authorization'), (b'Access-Control-Max-Age', b'1728000')])
# INFO:httpx:HTTP Request: POST https://llms-inference.innkube.fim.uni-passau.de/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Response: POST https://llms-inference.innkube.fim.uni-passau.de/completions "200 OK" Headers({'date': 'Tue, 29 Apr 2025 06:44:25 GMT', 'content-type': 'application/json', 'content-length': '365', 'connection': 'keep-alive', 'x-litellm-call-id': 'a1f2e930-3f80-40ea-a54f-74505c46d155', 'x-litellm-model-id': '4fc98ad04997d06d243fa1037a8527856cb537a73abc970ce37122958bbea148', 'x-litellm-model-api-base': 'http://qwen2-5-ollama:11434', 'x-litellm-version': '1.42.2', 'x-litellm-response-cost': '0.265897', 'x-litellm-key-tpm-limit': 'None', 'x-litellm-key-rpm-limit': '100', 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'access-control-allow-origin': '*', 'access-control-allow-credentials': 'true', 'access-control-allow-methods': 'PUT, GET, POST', 'access-control-allow-headers': 'DNT,Keep-Alive,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range,Authorization', 'access-control-max-age': '1728000'})
# DEBUG:openai._base_client:request_id: None
# DEBUG:llama_index.core.indices.knowledge_graph.base:> Extracted triplets: [('Kraglin', 'Opens fire on', 'Arête')]
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> routing towards fixed database: neo4j
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> pinning database: 'neo4j'
# DEBUG:neo4j.pool:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database=AcquisitionDatabase(name='neo4j', guessed=False)
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> picked existing connection bolt-6
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> handing out existing connection
# DEBUG:neo4j.io:[#EC65]  C: RUN '\n            MERGE (n1:`Entity` {id:$subj})\n            MERGE (n2:`Entity` {id:$obj})\n            MERGE (n1)-[:`OPENS_FIRE_ON`]->(n2)\n        ' {'subj': 'Kraglin', 'obj': 'Arête'} {'db': 'neo4j'}
# DEBUG:neo4j.io:[#EC65]  C: PULL {'n': 1000}
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {'t_first': 69, 'fields': []}
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {'bookmark': 'FB:kcwQBKSVGJtoSZS3C7vmPo+vEhiQ', 'stats': {'contains-updates': True, 'labels-added': 2, 'relationships-created': 1, 'nodes-created': 2, 'properties-set': 2}, 'statuses': [{'gql_status': '00001', 'status_description': 'note: successful completion - omitted result'}], 'type': 'w', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> released bolt-6
# ...
# DEBUG:openai._base_client:Sending HTTP Request: POST https://llms-inference.innkube.fim.uni-passau.de/completions
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Tue, 29 Apr 2025 06:46:00 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'432'), (b'Connection', b'keep-alive'), (b'x-litellm-call-id', b'20a1e9b4-4a15-4482-af13-a0f15052ed65'), (b'x-litellm-model-id', b'4fc98ad04997d06d243fa1037a8527856cb537a73abc970ce37122958bbea148'), (b'x-litellm-model-api-base', b'http://qwen2-5-ollama:11434'), (b'x-litellm-version', b'1.42.2'), (b'x-litellm-response-cost', b'0.350369'), (b'x-litellm-key-tpm-limit', b'None'), (b'x-litellm-key-rpm-limit', b'100'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains'), (b'Access-Control-Allow-Origin', b'*'), (b'Access-Control-Allow-Credentials', b'true'), (b'Access-Control-Allow-Methods', b'PUT, GET, POST'), (b'Access-Control-Allow-Headers', b'DNT,Keep-Alive,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range,Authorization'), (b'Access-Control-Max-Age', b'1728000')])
# INFO:httpx:HTTP Request: POST https://llms-inference.innkube.fim.uni-passau.de/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Response: POST https://llms-inference.innkube.fim.uni-passau.de/completions "200 OK" Headers({'date': 'Tue, 29 Apr 2025 06:46:00 GMT', 'content-type': 'application/json', 'content-length': '432', 'connection': 'keep-alive', 'x-litellm-call-id': '20a1e9b4-4a15-4482-af13-a0f15052ed65', 'x-litellm-model-id': '4fc98ad04997d06d243fa1037a8527856cb537a73abc970ce37122958bbea148', 'x-litellm-model-api-base': 'http://qwen2-5-ollama:11434', 'x-litellm-version': '1.42.2', 'x-litellm-response-cost': '0.350369', 'x-litellm-key-tpm-limit': 'None', 'x-litellm-key-rpm-limit': '100', 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'access-control-allow-origin': '*', 'access-control-allow-credentials': 'true', 'access-control-allow-methods': 'PUT, GET, POST', 'access-control-allow-headers': 'DNT,Keep-Alive,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range,Authorization', 'access-control-max-age': '1728000'})
# DEBUG:openai._base_client:request_id: None
# DEBUG:llama_index.core.indices.knowledge_graph.base:> Extracted triplets: [('People for the ethical treatment of animals', 'Declared', 'The best animal rights film of the year'), ('Gunn', 'Received', 'Not a number award')]
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> routing towards fixed database: neo4j
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> pinning database: 'neo4j'
# DEBUG:neo4j.pool:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database=AcquisitionDatabase(name='neo4j', guessed=False)
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> picked existing connection bolt-6
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> handing out existing connection
# DEBUG:neo4j.io:[#EC65]  C: RUN '\n            MERGE (n1:`Entity` {id:$subj})\n            MERGE (n2:`Entity` {id:$obj})\n            MERGE (n1)-[:`DECLARED`]->(n2)\n        ' {'subj': 'People for the ethical treatment of animals', 'obj': 'The best animal rights film of the year'} {'db': 'neo4j'}
# DEBUG:neo4j.io:[#EC65]  C: PULL {'n': 1000}
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {'t_first': 117, 'fields': []}
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {'bookmark': 'FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAgpA=', 'stats': {'contains-updates': True, 'labels-added': 2, 'relationships-created': 1, 'nodes-created': 2, 'properties-set': 2}, 'statuses': [{'gql_status': '00001', 'status_description': 'note: successful completion - omitted result'}], 'type': 'w', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> released bolt-6
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> routing towards fixed database: neo4j
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> pinning database: 'neo4j'
# DEBUG:neo4j.pool:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database=AcquisitionDatabase(name='neo4j', guessed=False)
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> picked existing connection bolt-6
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> handing out existing connection
# DEBUG:neo4j.io:[#EC65]  C: RUN '\n            MERGE (n1:`Entity` {id:$subj})\n            MERGE (n2:`Entity` {id:$obj})\n            MERGE (n1)-[:`RECEIVED`]->(n2)\n        ' {'subj': 'Gunn', 'obj': 'Not a number award'} {'db': 'neo4j'}
# DEBUG:neo4j.io:[#EC65]  C: PULL {'n': 1000}
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {'t_first': 148, 'fields': []}
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {'bookmark': 'FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAhJA=', 'stats': {'contains-updates': True, 'labels-added': 1, 'relationships-created': 1, 'nodes-created': 1, 'properties-set': 1}, 'statuses': [{'gql_status': '00001', 'status_description': 'note: successful completion - omitted result'}], 'type': 'w', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> released bolt-6
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/completions', 'files': None, 'idempotency_key': 'stainless-python-retry-5d635732-a60d-4464-8680-76d42f97ca30', 'json_data': {'model': 'qwen2.5', 'prompt': "Some text is provided below. Given the text, extract up to 2 knowledge triplets in the form of (subject, predicate, object). Avoid stopwords.\n---------------------\nExample:Text: Alice is Bob's mother.Triplets:\n(Alice, is mother of, Bob)\nText: Philz is a coffee shop founded in Berkeley in 1982.\nTriplets:\n(Philz, is, coffee shop)\n(Philz, founded in, Berkeley)\n(Philz, founded in, 1982)\n---------------------\nText: == Notes ==\n\n\n== References ==\n\n\n== External links ==\n\nOfficial website  at Marvel.com\nGuardians of the Galaxy Vol. 3 at IMDb \nGuardians of the Galaxy Vol. 3 at Disney A to Z \nGuardians of the Galaxy Vol. 3 at Disney.com\nTriplets:\n", 'stream': False, 'temperature': 0.1}}
# DEBUG:openai._base_client:Sending HTTP Request: POST https://llms-inference.innkube.fim.uni-passau.de/completions
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Tue, 29 Apr 2025 06:46:03 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'410'), (b'Connection', b'keep-alive'), (b'x-litellm-call-id', b'18e7a86b-861b-4797-b586-57d405f3abcc'), (b'x-litellm-model-id', b'4fc98ad04997d06d243fa1037a8527856cb537a73abc970ce37122958bbea148'), (b'x-litellm-model-api-base', b'http://qwen2-5-ollama:11434'), (b'x-litellm-version', b'1.42.2'), (b'x-litellm-response-cost', b'0.10713'), (b'x-litellm-key-tpm-limit', b'None'), (b'x-litellm-key-rpm-limit', b'100'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains'), (b'Access-Control-Allow-Origin', b'*'), (b'Access-Control-Allow-Credentials', b'true'), (b'Access-Control-Allow-Methods', b'PUT, GET, POST'), (b'Access-Control-Allow-Headers', b'DNT,Keep-Alive,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range,Authorization'), (b'Access-Control-Max-Age', b'1728000')])
# INFO:httpx:HTTP Request: POST https://llms-inference.innkube.fim.uni-passau.de/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Response: POST https://llms-inference.innkube.fim.uni-passau.de/completions "200 OK" Headers({'date': 'Tue, 29 Apr 2025 06:46:03 GMT', 'content-type': 'application/json', 'content-length': '410', 'connection': 'keep-alive', 'x-litellm-call-id': '18e7a86b-861b-4797-b586-57d405f3abcc', 'x-litellm-model-id': '4fc98ad04997d06d243fa1037a8527856cb537a73abc970ce37122958bbea148', 'x-litellm-model-api-base': 'http://qwen2-5-ollama:11434', 'x-litellm-version': '1.42.2', 'x-litellm-response-cost': '0.10713', 'x-litellm-key-tpm-limit': 'None', 'x-litellm-key-rpm-limit': '100', 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'access-control-allow-origin': '*', 'access-control-allow-credentials': 'true', 'access-control-allow-methods': 'PUT, GET, POST', 'access-control-allow-headers': 'DNT,Keep-Alive,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range,Authorization', 'access-control-max-age': '1728000'})
# DEBUG:openai._base_client:request_id: None
# DEBUG:llama_index.core.indices.knowledge_graph.base:> Extracted triplets: [('Guardians of the galaxy vol. 3', 'Has official website at', 'Marvel.com'), ('Guardians of the galaxy vol. 3', 'Listed at', 'Imdb')]
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> routing towards fixed database: neo4j
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> pinning database: 'neo4j'
# DEBUG:neo4j.pool:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database=AcquisitionDatabase(name='neo4j', guessed=False)
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> picked existing connection bolt-6
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> handing out existing connection
# DEBUG:neo4j.io:[#EC65]  C: RUN '\n            MERGE (n1:`Entity` {id:$subj})\n            MERGE (n2:`Entity` {id:$obj})\n            MERGE (n1)-[:`HAS_OFFICIAL_WEBSITE_AT`]->(n2)\n        ' {'subj': 'Guardians of the galaxy vol. 3', 'obj': 'Marvel.com'} {'db': 'neo4j'}
# DEBUG:neo4j.io:[#EC65]  C: PULL {'n': 1000}
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {'t_first': 105, 'fields': []}
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {'bookmark': 'FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAhpA=', 'stats': {'contains-updates': True, 'labels-added': 1, 'relationships-created': 1, 'nodes-created': 1, 'properties-set': 1}, 'statuses': [{'gql_status': '00001', 'status_description': 'note: successful completion - omitted result'}], 'type': 'w', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> released bolt-6
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> routing towards fixed database: neo4j
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> pinning database: 'neo4j'
# DEBUG:neo4j.pool:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database=AcquisitionDatabase(name='neo4j', guessed=False)
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> picked existing connection bolt-6
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> handing out existing connection
# DEBUG:neo4j.io:[#EC65]  C: RUN '\n            MERGE (n1:`Entity` {id:$subj})\n            MERGE (n2:`Entity` {id:$obj})\n            MERGE (n1)-[:`LISTED_AT`]->(n2)\n        ' {'subj': 'Guardians of the galaxy vol. 3', 'obj': 'Imdb'} {'db': 'neo4j'}
# DEBUG:neo4j.io:[#EC65]  C: PULL {'n': 1000}
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {'t_first': 146, 'fields': []}
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> server state: READY > STREAMING
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {'bookmark': 'FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAiJA=', 'stats': {'contains-updates': True, 'labels-added': 1, 'relationships-created': 1, 'nodes-created': 1, 'properties-set': 1}, 'statuses': [{'gql_status': '00001', 'status_description': 'note: successful completion - omitted result'}], 'type': 'w', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> server state: STREAMING > READY
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> released bolt-6

# %%
index.storage_context.persist()
# Out:
# DEBUG:fsspec.local:open file: c:/Research/PHD_Related_research/Experiments/storage/docstore.json
# DEBUG:fsspec.local:open file: c:/Research/PHD_Related_research/Experiments/storage/index_store.json
# DEBUG:fsspec.local:open file: c:/Research/PHD_Related_research/Experiments/storage/default__vector_store.json
# DEBUG:fsspec.local:open file: c:/Research/PHD_Related_research/Experiments/storage/image__vector_store.json

# %%
query_engine = index.as_query_engine(
    include_text=False, response_mode="tree_summarize"
)

response = query_engine.query("Tell me more about Rocket")
# Out:
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/completions', 'files': None, 'idempotency_key': 'stainless-python-retry-592c6128-a9cb-4865-8020-790ec57ea3c1', 'json_data': {'model': 'qwen2.5', 'prompt': "A question is provided below. Given the question, extract up to 10 keywords from the text. Focus on extracting the keywords that we can use to best lookup answers to the question. Avoid stopwords.\n---------------------\nTell me more about Rocket\n---------------------\nProvide keywords in the following comma-separated format: 'KEYWORDS: <keywords>'\n", 'stream': False, 'temperature': 0.1}}
# DEBUG:openai._base_client:Sending HTTP Request: POST https://llms-inference.innkube.fim.uni-passau.de/completions
# DEBUG:httpcore.connection:close.started
# DEBUG:httpcore.connection:close.complete
# DEBUG:httpcore.connection:connect_tcp.started host='llms-inference.innkube.fim.uni-passau.de' port=443 local_address=None timeout=60.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x000001468401C3A0>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x0000014683DF7BC0> server_hostname='llms-inference.innkube.fim.uni-passau.de' timeout=60.0
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x00000146FC76E640>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Tue, 29 Apr 2025 06:48:25 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'406'), (b'Connection', b'keep-alive'), (b'x-litellm-call-id', b'b931c304-8264-490f-8f3c-cf08e70babee'), (b'x-litellm-model-id', b'4fc98ad04997d06d243fa1037a8527856cb537a73abc970ce37122958bbea148'), (b'x-litellm-model-api-base', b'http://qwen2-5-ollama:11434'), (b'x-litellm-version', b'1.42.2'), (b'x-litellm-response-cost', b'0.055323'), (b'x-litellm-key-tpm-limit', b'None'), (b'x-litellm-key-rpm-limit', b'100'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains'), (b'Access-Control-Allow-Origin', b'*'), (b'Access-Control-Allow-Credentials', b'true'), (b'Access-Control-Allow-Methods', b'PUT, GET, POST'), (b'Access-Control-Allow-Headers', b'DNT,Keep-Alive,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range,Authorization'), (b'Access-Control-Max-Age', b'1728000')])
# INFO:httpx:HTTP Request: POST https://llms-inference.innkube.fim.uni-passau.de/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Response: POST https://llms-inference.innkube.fim.uni-passau.de/completions "200 OK" Headers({'date': 'Tue, 29 Apr 2025 06:48:25 GMT', 'content-type': 'application/json', 'content-length': '406', 'connection': 'keep-alive', 'x-litellm-call-id': 'b931c304-8264-490f-8f3c-cf08e70babee', 'x-litellm-model-id': '4fc98ad04997d06d243fa1037a8527856cb537a73abc970ce37122958bbea148', 'x-litellm-model-api-base': 'http://qwen2-5-ollama:11434', 'x-litellm-version': '1.42.2', 'x-litellm-response-cost': '0.055323', 'x-litellm-key-tpm-limit': 'None', 'x-litellm-key-rpm-limit': '100', 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'access-control-allow-origin': '*', 'access-control-allow-credentials': 'true', 'access-control-allow-methods': 'PUT, GET, POST', 'access-control-allow-headers': 'DNT,Keep-Alive,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range,Authorization', 'access-control-max-age': '1728000'})
# DEBUG:openai._base_client:request_id: None
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> routing towards fixed database: neo4j
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> pinning database: 'neo4j'
# DEBUG:neo4j.pool:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database=AcquisitionDatabase(name='neo4j', guessed=False)
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> picked existing connection bolt-6
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> handing out existing connection
# DEBUG:neo4j.io:[#EC65]  C: BEGIN {'db': 'neo4j', 'bookmarks': ['FB:kcwQBKSVGJtoSZS3C7vmPo+vEgaQ']}
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> client state: STREAMING > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#EC65]  C: RUN "MATCH p=(n1:Entity)-[*1..2]->() WHERE toLower(n1.id) IN ['development']UNWIND relationships(p) AS rel WITH n1.id AS subj, p, apoc.coll.flatten(apoc.coll.toSet(collect([type(rel), endNode(rel).id]))) AS flattened_rels RETURN subj, collect(flattened_rels) AS flattened_rels LIMIT 30" {'subjs': ['development']} {}
# DEBUG:neo4j.io:[#EC65]  C: PULL {'n': 1000}
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {}
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> server state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {'t_first': 468, 'fields': ['subj', 'flattened_rels'], 'qid': 0}
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {'statuses': [{'gql_status': '02000', 'status_description': 'note: no data'}], 'type': 'r', 't_last': 39, 'db': 'neo4j'}
# DEBUG:neo4j.io:[#EC65]  C: COMMIT
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> client state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {'bookmark': 'FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAiJA='}
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> server state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> released bolt-6
# DEBUG:llama_index.core.indices.knowledge_graph.retrievers:rel_map: {}
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> routing towards fixed database: neo4j
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> pinning database: 'neo4j'
# DEBUG:neo4j.pool:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database=AcquisitionDatabase(name='neo4j', guessed=False)
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> picked existing connection bolt-6
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> handing out existing connection
# DEBUG:neo4j.io:[#EC65]  C: BEGIN {'db': 'neo4j', 'bookmarks': ['FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAiJA=']}
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> client state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#EC65]  C: RUN "MATCH p=(n1:Entity)-[*1..2]->() WHERE toLower(n1.id) IN ['applications']UNWIND relationships(p) AS rel WITH n1.id AS subj, p, apoc.coll.flatten(apoc.coll.toSet(collect([type(rel), endNode(rel).id]))) AS flattened_rels RETURN subj, collect(flattened_rels) AS flattened_rels LIMIT 30" {'subjs': ['applications']} {}
# DEBUG:neo4j.io:[#EC65]  C: PULL {'n': 1000}
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {}
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> server state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {'t_first': 42, 'fields': ['subj', 'flattened_rels'], 'qid': 0}
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {'statuses': [{'gql_status': '02000', 'status_description': 'note: no data'}], 'type': 'r', 't_last': 7, 'db': 'neo4j'}
# DEBUG:neo4j.io:[#EC65]  C: COMMIT
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> client state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {'bookmark': 'FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAiJA='}
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> server state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> released bolt-6
# DEBUG:llama_index.core.indices.knowledge_graph.retrievers:rel_map: {}
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> routing towards fixed database: neo4j
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> pinning database: 'neo4j'
# DEBUG:neo4j.pool:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database=AcquisitionDatabase(name='neo4j', guessed=False)
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> picked existing connection bolt-6
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> handing out existing connection
# DEBUG:neo4j.io:[#EC65]  C: BEGIN {'db': 'neo4j', 'bookmarks': ['FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAiJA=']}
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> client state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#EC65]  C: RUN "MATCH p=(n1:Entity)-[*1..2]->() WHERE toLower(n1.id) IN ['history']UNWIND relationships(p) AS rel WITH n1.id AS subj, p, apoc.coll.flatten(apoc.coll.toSet(collect([type(rel), endNode(rel).id]))) AS flattened_rels RETURN subj, collect(flattened_rels) AS flattened_rels LIMIT 30" {'subjs': ['history']} {}
# DEBUG:neo4j.io:[#EC65]  C: PULL {'n': 1000}
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {}
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> server state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {'t_first': 48, 'fields': ['subj', 'flattened_rels'], 'qid': 0}
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {'statuses': [{'gql_status': '02000', 'status_description': 'note: no data'}], 'type': 'r', 't_last': 3, 'db': 'neo4j'}
# DEBUG:neo4j.io:[#EC65]  C: COMMIT
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> client state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {'bookmark': 'FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAiJA='}
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> server state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> released bolt-6
# DEBUG:llama_index.core.indices.knowledge_graph.retrievers:rel_map: {}
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> routing towards fixed database: neo4j
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> pinning database: 'neo4j'
# DEBUG:neo4j.pool:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database=AcquisitionDatabase(name='neo4j', guessed=False)
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> picked existing connection bolt-6
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> handing out existing connection
# DEBUG:neo4j.io:[#EC65]  C: BEGIN {'db': 'neo4j', 'bookmarks': ['FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAiJA=']}
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> client state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#EC65]  C: RUN "MATCH p=(n1:Entity)-[*1..2]->() WHERE toLower(n1.id) IN ['rocket']UNWIND relationships(p) AS rel WITH n1.id AS subj, p, apoc.coll.flatten(apoc.coll.toSet(collect([type(rel), endNode(rel).id]))) AS flattened_rels RETURN subj, collect(flattened_rels) AS flattened_rels LIMIT 30" {'subjs': ['Rocket']} {}
# DEBUG:neo4j.io:[#EC65]  C: PULL {'n': 1000}
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {}
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> server state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {'t_first': 31, 'fields': ['subj', 'flattened_rels'], 'qid': 0}
# DEBUG:neo4j.io:[#EC65]  S: RECORD * 1
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {'statuses': [{'gql_status': '00000', 'status_description': 'note: successful completion'}], 'type': 'r', 't_last': 38, 'db': 'neo4j'}
# DEBUG:neo4j.io:[#EC65]  C: COMMIT
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> client state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {'bookmark': 'FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAiJA='}
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> server state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> released bolt-6
# DEBUG:llama_index.core.indices.knowledge_graph.retrievers:rel_map: {'Rocket': [['FOUND_AND_EXPERIMENTED_ON_BY', 'High evolutionary'], ['FOUND_AND_EXPERIMENTED_ON_BY', 'High evolutionary', 'AIMED_TO_ENHANCE_AND_ANTHROPOMORPHIZE', 'Animal lifeforms'], ['FOUND_AND_EXPERIMENTED_ON_BY', 'High evolutionary', 'THREATENED', 'Sovereign'], ['FOUND_AND_EXPERIMENTED_ON_BY', 'High evolutionary', 'SPECIALIZES_IN', 'Creating hybrid creatures'], ['FOUND_AND_EXPERIMENTED_ON_BY', 'High evolutionary', 'DESCRIBED_AS', 'Cruelest mcu villain']]}
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> routing towards fixed database: neo4j
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> pinning database: 'neo4j'
# DEBUG:neo4j.pool:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database=AcquisitionDatabase(name='neo4j', guessed=False)
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> picked existing connection bolt-6
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> handing out existing connection
# DEBUG:neo4j.io:[#EC65]  C: BEGIN {'db': 'neo4j', 'bookmarks': ['FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAiJA=']}
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> client state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#EC65]  C: RUN "MATCH p=(n1:Entity)-[*1..2]->() WHERE toLower(n1.id) IN ['facts']UNWIND relationships(p) AS rel WITH n1.id AS subj, p, apoc.coll.flatten(apoc.coll.toSet(collect([type(rel), endNode(rel).id]))) AS flattened_rels RETURN subj, collect(flattened_rels) AS flattened_rels LIMIT 30" {'subjs': ['facts']} {}
# DEBUG:neo4j.io:[#EC65]  C: PULL {'n': 1000}
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {}
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> server state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {'t_first': 35, 'fields': ['subj', 'flattened_rels'], 'qid': 0}
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {'statuses': [{'gql_status': '02000', 'status_description': 'note: no data'}], 'type': 'r', 't_last': 7, 'db': 'neo4j'}
# DEBUG:neo4j.io:[#EC65]  C: COMMIT
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> client state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {'bookmark': 'FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAiJA='}
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> server state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> released bolt-6
# DEBUG:llama_index.core.indices.knowledge_graph.retrievers:rel_map: {}
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> routing towards fixed database: neo4j
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> pinning database: 'neo4j'
# DEBUG:neo4j.pool:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database=AcquisitionDatabase(name='neo4j', guessed=False)
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> picked existing connection bolt-6
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> handing out existing connection
# DEBUG:neo4j.io:[#EC65]  C: BEGIN {'db': 'neo4j', 'bookmarks': ['FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAiJA=']}
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> client state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#EC65]  C: RUN "MATCH p=(n1:Entity)-[*1..2]->() WHERE toLower(n1.id) IN ['uses']UNWIND relationships(p) AS rel WITH n1.id AS subj, p, apoc.coll.flatten(apoc.coll.toSet(collect([type(rel), endNode(rel).id]))) AS flattened_rels RETURN subj, collect(flattened_rels) AS flattened_rels LIMIT 30" {'subjs': ['uses']} {}
# DEBUG:neo4j.io:[#EC65]  C: PULL {'n': 1000}
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {}
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> server state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {'t_first': 16, 'fields': ['subj', 'flattened_rels'], 'qid': 0}
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {'statuses': [{'gql_status': '02000', 'status_description': 'note: no data'}], 'type': 'r', 't_last': 3, 'db': 'neo4j'}
# DEBUG:neo4j.io:[#EC65]  C: COMMIT
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> client state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {'bookmark': 'FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAiJA='}
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> server state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> released bolt-6
# DEBUG:llama_index.core.indices.knowledge_graph.retrievers:rel_map: {}
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> routing towards fixed database: neo4j
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> pinning database: 'neo4j'
# DEBUG:neo4j.pool:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database=AcquisitionDatabase(name='neo4j', guessed=False)
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> picked existing connection bolt-6
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> handing out existing connection
# DEBUG:neo4j.io:[#EC65]  C: BEGIN {'db': 'neo4j', 'bookmarks': ['FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAiJA=']}
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> client state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#EC65]  C: RUN "MATCH p=(n1:Entity)-[*1..2]->() WHERE toLower(n1.id) IN ['characteristics']UNWIND relationships(p) AS rel WITH n1.id AS subj, p, apoc.coll.flatten(apoc.coll.toSet(collect([type(rel), endNode(rel).id]))) AS flattened_rels RETURN subj, collect(flattened_rels) AS flattened_rels LIMIT 30" {'subjs': ['characteristics']} {}
# DEBUG:neo4j.io:[#EC65]  C: PULL {'n': 1000}
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {}
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> server state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {'t_first': 31, 'fields': ['subj', 'flattened_rels'], 'qid': 0}
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {'statuses': [{'gql_status': '02000', 'status_description': 'note: no data'}], 'type': 'r', 't_last': 10, 'db': 'neo4j'}
# DEBUG:neo4j.io:[#EC65]  C: COMMIT
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> client state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {'bookmark': 'FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAiJA='}
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> server state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> released bolt-6
# DEBUG:llama_index.core.indices.knowledge_graph.retrievers:rel_map: {}
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> routing towards fixed database: neo4j
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> pinning database: 'neo4j'
# DEBUG:neo4j.pool:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database=AcquisitionDatabase(name='neo4j', guessed=False)
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> picked existing connection bolt-6
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> handing out existing connection
# DEBUG:neo4j.io:[#EC65]  C: BEGIN {'db': 'neo4j', 'bookmarks': ['FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAiJA=']}
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> client state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#EC65]  C: RUN "MATCH p=(n1:Entity)-[*1..2]->() WHERE toLower(n1.id) IN ['technology']UNWIND relationships(p) AS rel WITH n1.id AS subj, p, apoc.coll.flatten(apoc.coll.toSet(collect([type(rel), endNode(rel).id]))) AS flattened_rels RETURN subj, collect(flattened_rels) AS flattened_rels LIMIT 30" {'subjs': ['technology']} {}
# DEBUG:neo4j.io:[#EC65]  C: PULL {'n': 1000}
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {}
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> server state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {'t_first': 35, 'fields': ['subj', 'flattened_rels'], 'qid': 0}
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {'statuses': [{'gql_status': '02000', 'status_description': 'note: no data'}], 'type': 'r', 't_last': 5, 'db': 'neo4j'}
# DEBUG:neo4j.io:[#EC65]  C: COMMIT
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> client state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {'bookmark': 'FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAiJA='}
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> server state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> released bolt-6
# DEBUG:llama_index.core.indices.knowledge_graph.retrievers:rel_map: {}
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> routing towards fixed database: neo4j
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> pinning database: 'neo4j'
# DEBUG:neo4j.pool:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database=AcquisitionDatabase(name='neo4j', guessed=False)
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> picked existing connection bolt-6
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> handing out existing connection
# DEBUG:neo4j.io:[#EC65]  C: BEGIN {'db': 'neo4j', 'bookmarks': ['FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAiJA=']}
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> client state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#EC65]  C: RUN "MATCH p=(n1:Entity)-[*1..2]->() WHERE toLower(n1.id) IN ['information']UNWIND relationships(p) AS rel WITH n1.id AS subj, p, apoc.coll.flatten(apoc.coll.toSet(collect([type(rel), endNode(rel).id]))) AS flattened_rels RETURN subj, collect(flattened_rels) AS flattened_rels LIMIT 30" {'subjs': ['information']} {}
# DEBUG:neo4j.io:[#EC65]  C: PULL {'n': 1000}
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {}
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> server state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {'t_first': 33, 'fields': ['subj', 'flattened_rels'], 'qid': 0}
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {'statuses': [{'gql_status': '02000', 'status_description': 'note: no data'}], 'type': 'r', 't_last': 12, 'db': 'neo4j'}
# DEBUG:neo4j.io:[#EC65]  C: COMMIT
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> client state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {'bookmark': 'FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAiJA='}
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> server state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> released bolt-6
# DEBUG:llama_index.core.indices.knowledge_graph.retrievers:rel_map: {}
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> routing towards fixed database: neo4j
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> pinning database: 'neo4j'
# DEBUG:neo4j.pool:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database=AcquisitionDatabase(name='neo4j', guessed=False)
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> picked existing connection bolt-6
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> handing out existing connection
# DEBUG:neo4j.io:[#EC65]  C: BEGIN {'db': 'neo4j', 'bookmarks': ['FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAiJA=']}
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> client state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#EC65]  C: RUN "MATCH p=(n1:Entity)-[*1..2]->() WHERE toLower(n1.id) IN ['details']UNWIND relationships(p) AS rel WITH n1.id AS subj, p, apoc.coll.flatten(apoc.coll.toSet(collect([type(rel), endNode(rel).id]))) AS flattened_rels RETURN subj, collect(flattened_rels) AS flattened_rels LIMIT 30" {'subjs': ['details']} {}
# DEBUG:neo4j.io:[#EC65]  C: PULL {'n': 1000}
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {}
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> server state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {'t_first': 23, 'fields': ['subj', 'flattened_rels'], 'qid': 0}
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {'statuses': [{'gql_status': '02000', 'status_description': 'note: no data'}], 'type': 'r', 't_last': 2, 'db': 'neo4j'}
# DEBUG:neo4j.io:[#EC65]  C: COMMIT
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> client state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.io:[#EC65]  S: SUCCESS {'bookmark': 'FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAiJA='}
# DEBUG:neo4j.io:[#EC65]  _: <CONNECTION> server state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.pool:[#EC65]  _: <POOL> released bolt-6
# DEBUG:llama_index.core.indices.knowledge_graph.retrievers:rel_map: {}
# WARNING:llama_index.core.indices.knowledge_graph.retrievers:Index was not constructed with embeddings, skipping embedding usage...
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/completions', 'files': None, 'idempotency_key': 'stainless-python-retry-6bf75926-2624-46c1-b857-4487f3f5dbbb', 'json_data': {'model': 'qwen2.5', 'prompt': "Context information from multiple sources is below.\n---------------------\nkg_schema: {'schema': 'Node properties are the following:\\n\\nRelationship properties are the following:\\n\\nThe relationships are the following:\\n'}\n\nThe following are knowledge sequence in max depth 2 in the form of directed graph like:\n`subject -[predicate]->, object, <-[predicate_next_hop]-, object_next_hop ...`\n['FOUND_AND_EXPERIMENTED_ON_BY', 'High evolutionary']\n['FOUND_AND_EXPERIMENTED_ON_BY', 'High evolutionary', 'AIMED_TO_ENHANCE_AND_ANTHROPOMORPHIZE', 'Animal lifeforms']\n['FOUND_AND_EXPERIMENTED_ON_BY', 'High evolutionary', 'THREATENED', 'Sovereign']\n['FOUND_AND_EXPERIMENTED_ON_BY', 'High evolutionary', 'SPECIALIZES_IN', 'Creating hybrid creatures']\n['FOUND_AND_EXPERIMENTED_ON_BY', 'High evolutionary', 'DESCRIBED_AS', 'Cruelest mcu villain']\n---------------------\nGiven the information from multiple sources and not prior knowledge, answer the query.\nQuery: Tell me more about Rocket\nAnswer: ", 'stream': False, 'temperature': 0.1}}
# DEBUG:openai._base_client:Sending HTTP Request: POST https://llms-inference.innkube.fim.uni-passau.de/completions
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Tue, 29 Apr 2025 06:48:36 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'1334'), (b'Connection', b'keep-alive'), (b'x-litellm-call-id', b'433f35e8-c020-449a-999c-aedd644036a1'), (b'x-litellm-model-id', b'4fc98ad04997d06d243fa1037a8527856cb537a73abc970ce37122958bbea148'), (b'x-litellm-model-api-base', b'http://qwen2-5-ollama:11434'), (b'x-litellm-version', b'1.42.2'), (b'x-litellm-response-cost', b'0.223291'), (b'x-litellm-key-tpm-limit', b'None'), (b'x-litellm-key-rpm-limit', b'100'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains'), (b'Access-Control-Allow-Origin', b'*'), (b'Access-Control-Allow-Credentials', b'true'), (b'Access-Control-Allow-Methods', b'PUT, GET, POST'), (b'Access-Control-Allow-Headers', b'DNT,Keep-Alive,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range,Authorization'), (b'Access-Control-Max-Age', b'1728000')])
# INFO:httpx:HTTP Request: POST https://llms-inference.innkube.fim.uni-passau.de/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Response: POST https://llms-inference.innkube.fim.uni-passau.de/completions "200 OK" Headers({'date': 'Tue, 29 Apr 2025 06:48:36 GMT', 'content-type': 'application/json', 'content-length': '1334', 'connection': 'keep-alive', 'x-litellm-call-id': '433f35e8-c020-449a-999c-aedd644036a1', 'x-litellm-model-id': '4fc98ad04997d06d243fa1037a8527856cb537a73abc970ce37122958bbea148', 'x-litellm-model-api-base': 'http://qwen2-5-ollama:11434', 'x-litellm-version': '1.42.2', 'x-litellm-response-cost': '0.223291', 'x-litellm-key-tpm-limit': 'None', 'x-litellm-key-rpm-limit': '100', 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'access-control-allow-origin': '*', 'access-control-allow-credentials': 'true', 'access-control-allow-methods': 'PUT, GET, POST', 'access-control-allow-headers': 'DNT,Keep-Alive,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range,Authorization', 'access-control-max-age': '1728000'})
# DEBUG:openai._base_client:request_id: None

# %%
display(Markdown(f"<b>{response}</b>"))
# Out:
# <b>Based on the provided context, there is no direct mention of Rocket. However, given that we are discussing a character described as "Cruelest mcu villain" who specializes in creating hybrid creatures and has experimented on animal lifeforms to enhance and anthropomorphize them, it's likely that this information pertains to the High Evolutionary, a character from the Marvel Cinematic Universe (MCU).
#
# Rocket, also known as Rocket Raccoon, is a highly intelligent and genetically modified raccoon who is part of the Guardians of the Galaxy. While not directly mentioned in the provided context, Rocket could be one of the "animal lifeforms" that the High Evolutionary has experimented on to enhance and anthropomorphize.
#
# If you're looking for more specific information about Rocket, he is known for his sharp wit, combat skills, and close friendship with Groot. He plays a significant role in the Guardians of the Galaxy films and other MCU projects. If you have any more specific questions or need further details, feel free to ask!</b>

# %%
query_engine = index.as_query_engine(
    include_text=True, response_mode="tree_summarize"
)

response = query_engine.query("Tell me more about Rocket")
# Out:
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/completions', 'files': None, 'idempotency_key': 'stainless-python-retry-a9357011-d9be-4381-a4fa-2335948ffb97', 'json_data': {'model': 'qwen2.5', 'prompt': "A question is provided below. Given the question, extract up to 10 keywords from the text. Focus on extracting the keywords that we can use to best lookup answers to the question. Avoid stopwords.\n---------------------\nTell me more about Rocket\n---------------------\nProvide keywords in the following comma-separated format: 'KEYWORDS: <keywords>'\n", 'stream': False, 'temperature': 0.1}}
# DEBUG:openai._base_client:Sending HTTP Request: POST https://llms-inference.innkube.fim.uni-passau.de/completions
# DEBUG:httpcore.connection:close.started
# DEBUG:httpcore.connection:close.complete
# DEBUG:httpcore.connection:connect_tcp.started host='llms-inference.innkube.fim.uni-passau.de' port=443 local_address=None timeout=60.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x00000146847033D0>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x0000014683DF7BC0> server_hostname='llms-inference.innkube.fim.uni-passau.de' timeout=60.0
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x0000014684B3E340>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Tue, 29 Apr 2025 10:05:57 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'406'), (b'Connection', b'keep-alive'), (b'x-litellm-call-id', b'e7e7a491-fe1c-4a43-8e63-a554a735aca4'), (b'x-litellm-model-id', b'4fc98ad04997d06d243fa1037a8527856cb537a73abc970ce37122958bbea148'), (b'x-litellm-model-api-base', b'http://qwen2-5-ollama:11434'), (b'x-litellm-version', b'1.42.2'), (b'x-litellm-response-cost', b'0.055323'), (b'x-litellm-key-tpm-limit', b'None'), (b'x-litellm-key-rpm-limit', b'100'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains'), (b'Access-Control-Allow-Origin', b'*'), (b'Access-Control-Allow-Credentials', b'true'), (b'Access-Control-Allow-Methods', b'PUT, GET, POST'), (b'Access-Control-Allow-Headers', b'DNT,Keep-Alive,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range,Authorization'), (b'Access-Control-Max-Age', b'1728000')])
# INFO:httpx:HTTP Request: POST https://llms-inference.innkube.fim.uni-passau.de/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Response: POST https://llms-inference.innkube.fim.uni-passau.de/completions "200 OK" Headers({'date': 'Tue, 29 Apr 2025 10:05:57 GMT', 'content-type': 'application/json', 'content-length': '406', 'connection': 'keep-alive', 'x-litellm-call-id': 'e7e7a491-fe1c-4a43-8e63-a554a735aca4', 'x-litellm-model-id': '4fc98ad04997d06d243fa1037a8527856cb537a73abc970ce37122958bbea148', 'x-litellm-model-api-base': 'http://qwen2-5-ollama:11434', 'x-litellm-version': '1.42.2', 'x-litellm-response-cost': '0.055323', 'x-litellm-key-tpm-limit': 'None', 'x-litellm-key-rpm-limit': '100', 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'access-control-allow-origin': '*', 'access-control-allow-credentials': 'true', 'access-control-allow-methods': 'PUT, GET, POST', 'access-control-allow-headers': 'DNT,Keep-Alive,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range,Authorization', 'access-control-max-age': '1728000'})
# DEBUG:openai._base_client:request_id: None
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> routing towards fixed database: neo4j
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> pinning database: 'neo4j'
# DEBUG:neo4j.pool:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database=AcquisitionDatabase(name='neo4j', guessed=False)
# DEBUG:neo4j.pool:[#F672]  _: <POOL> found unhealthy connection bolt-3 (closed=False, defunct=False, stale=True, in_use=True)
# DEBUG:neo4j.io:[#F672]  C: GOODBYE
# DEBUG:neo4j.io:[#F672]  C: <CLOSE>
# DEBUG:neo4j.pool:[#F672]  _: <POOL> remove connection from pool IPv4Address(('localhost', 7687)) bolt-3
# DEBUG:neo4j.pool:[#0000]  _: <POOL> trying to hand out new connection
# DEBUG:neo4j.io:[#0000]  _: <RESOLVE> in: localhost:7687
# DEBUG:neo4j.io:[#0000]  _: <RESOLVE> dns resolver out: [::1]:7687
# DEBUG:neo4j.io:[#0000]  C: <OPEN> [::1]:7687
# DEBUG:neo4j.io:[#0000]  S: <ERROR> ConnectionRefusedError 10061 'Es konnte keine Verbindung hergestellt werden, da der Zielcomputer die Verbindung verweigerte' None 10061 None
# DEBUG:neo4j.io:[#0000]  C: <CLOSE> [::1]:7687
# DEBUG:neo4j.io:[#0000]  S: <CONNECTION FAILED> [::1]:7687 ServiceUnavailable: Failed to establish connection to ResolvedIPv6Address(('::1', 7687, 0, 0)) (reason [WinError 10061] Es konnte keine Verbindung hergestellt werden, da der Zielcomputer die Verbindung verweigerte)
# DEBUG:neo4j.io:[#0000]  _: <RESOLVE> dns resolver out: 127.0.0.1:7687
# DEBUG:neo4j.io:[#0000]  C: <OPEN> 127.0.0.1:7687
# DEBUG:neo4j.io:[#F047]  C: <MAGIC> 0x6060B017
# DEBUG:neo4j.io:[#F047]  C: <HANDSHAKE> 0x000001FF 0x00080805 0x00020404 0x00000003
# DEBUG:neo4j.io:[#F047]  S: <HANDSHAKE> 0x00000605
# DEBUG:neo4j.io:[#F047]  C: HELLO {'user_agent': 'neo4j-python/5.28.1 Python/3.9.21-final-0 (win32)', 'bolt_agent': {'product': 'neo4j-python/5.28.1', 'platform': 'Windows 10; AMD64', 'language': 'Python/3.9.21-final-0', 'language_details': 'CPython; 3.9.21-final-0 (main, Apr  9 2025 09:02:40) [MSC v.1929 64 bit (AMD64)]'}}
# DEBUG:neo4j.io:[#F047]  _: <CONNECTION> client state: CONNECTED > AUTHENTICATION
# DEBUG:neo4j.io:[#F047]  C: LOGON {'scheme': 'basic', 'principal': 'neo4j', 'credentials': '*******'}
# DEBUG:neo4j.io:[#F047]  _: <CONNECTION> client state: AUTHENTICATION > READY
# DEBUG:neo4j.io:[#F047]  S: SUCCESS {'server': 'Neo4j/5.24.0', 'connection_id': 'bolt-19', 'hints': {'connection.recv_timeout_seconds': 120}}
# DEBUG:neo4j.io:[#F047]  _: <CONNECTION> server state: CONNECTED > AUTHENTICATION
# DEBUG:neo4j.io:[#F047]  S: SUCCESS {}
# DEBUG:neo4j.io:[#F047]  _: <CONNECTION> server state: AUTHENTICATION > READY
# DEBUG:neo4j.io:[#F047]  C: BEGIN {'db': 'neo4j', 'bookmarks': ['FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAiJA=']}
# DEBUG:neo4j.io:[#F047]  _: <CONNECTION> client state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#F047]  C: RUN "MATCH p=(n1:Entity)-[*1..2]->() WHERE toLower(n1.id) IN ['development']UNWIND relationships(p) AS rel WITH n1.id AS subj, p, apoc.coll.flatten(apoc.coll.toSet(collect([type(rel), endNode(rel).id]))) AS flattened_rels RETURN subj, collect(flattened_rels) AS flattened_rels LIMIT 30" {'subjs': ['development']} {}
# DEBUG:neo4j.io:[#F047]  C: PULL {'n': 1000}
# DEBUG:neo4j.io:[#F047]  S: SUCCESS {}
# DEBUG:neo4j.io:[#F047]  _: <CONNECTION> server state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#F047]  S: SUCCESS {'t_first': 172, 'fields': ['subj', 'flattened_rels'], 'qid': 0}
# DEBUG:neo4j.io:[#F047]  S: SUCCESS {'statuses': [{'gql_status': '02000', 'status_description': 'note: no data'}], 'type': 'r', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j.io:[#F047]  C: COMMIT
# DEBUG:neo4j.io:[#F047]  _: <CONNECTION> client state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.io:[#F047]  S: SUCCESS {'bookmark': 'FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAiJA='}
# DEBUG:neo4j.io:[#F047]  _: <CONNECTION> server state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.pool:[#F047]  _: <POOL> released bolt-19
# DEBUG:llama_index.core.indices.knowledge_graph.retrievers:rel_map: {}
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> routing towards fixed database: neo4j
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> pinning database: 'neo4j'
# DEBUG:neo4j.pool:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database=AcquisitionDatabase(name='neo4j', guessed=False)
# DEBUG:neo4j.pool:[#F047]  _: <POOL> picked existing connection bolt-19
# DEBUG:neo4j.pool:[#F047]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j.pool:[#F047]  _: <POOL> handing out existing connection
# DEBUG:neo4j.io:[#F047]  C: BEGIN {'db': 'neo4j', 'bookmarks': ['FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAiJA=']}
# DEBUG:neo4j.io:[#F047]  _: <CONNECTION> client state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#F047]  C: RUN "MATCH p=(n1:Entity)-[*1..2]->() WHERE toLower(n1.id) IN ['applications']UNWIND relationships(p) AS rel WITH n1.id AS subj, p, apoc.coll.flatten(apoc.coll.toSet(collect([type(rel), endNode(rel).id]))) AS flattened_rels RETURN subj, collect(flattened_rels) AS flattened_rels LIMIT 30" {'subjs': ['applications']} {}
# DEBUG:neo4j.io:[#F047]  C: PULL {'n': 1000}
# DEBUG:neo4j.io:[#F047]  S: SUCCESS {}
# DEBUG:neo4j.io:[#F047]  _: <CONNECTION> server state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#F047]  S: SUCCESS {'t_first': 4, 'fields': ['subj', 'flattened_rels'], 'qid': 0}
# DEBUG:neo4j.io:[#F047]  S: SUCCESS {'statuses': [{'gql_status': '02000', 'status_description': 'note: no data'}], 'type': 'r', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j.io:[#F047]  C: COMMIT
# DEBUG:neo4j.io:[#F047]  _: <CONNECTION> client state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.io:[#F047]  S: SUCCESS {'bookmark': 'FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAiJA='}
# DEBUG:neo4j.io:[#F047]  _: <CONNECTION> server state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.pool:[#F047]  _: <POOL> released bolt-19
# DEBUG:llama_index.core.indices.knowledge_graph.retrievers:rel_map: {}
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> routing towards fixed database: neo4j
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> pinning database: 'neo4j'
# DEBUG:neo4j.pool:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database=AcquisitionDatabase(name='neo4j', guessed=False)
# DEBUG:neo4j.pool:[#F047]  _: <POOL> picked existing connection bolt-19
# DEBUG:neo4j.pool:[#F047]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j.pool:[#F047]  _: <POOL> handing out existing connection
# DEBUG:neo4j.io:[#F047]  C: BEGIN {'db': 'neo4j', 'bookmarks': ['FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAiJA=']}
# DEBUG:neo4j.io:[#F047]  _: <CONNECTION> client state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#F047]  C: RUN "MATCH p=(n1:Entity)-[*1..2]->() WHERE toLower(n1.id) IN ['history']UNWIND relationships(p) AS rel WITH n1.id AS subj, p, apoc.coll.flatten(apoc.coll.toSet(collect([type(rel), endNode(rel).id]))) AS flattened_rels RETURN subj, collect(flattened_rels) AS flattened_rels LIMIT 30" {'subjs': ['history']} {}
# DEBUG:neo4j.io:[#F047]  C: PULL {'n': 1000}
# DEBUG:neo4j.io:[#F047]  S: SUCCESS {}
# DEBUG:neo4j.io:[#F047]  _: <CONNECTION> server state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#F047]  S: SUCCESS {'t_first': 20, 'fields': ['subj', 'flattened_rels'], 'qid': 0}
# DEBUG:neo4j.io:[#F047]  S: SUCCESS {'statuses': [{'gql_status': '02000', 'status_description': 'note: no data'}], 'type': 'r', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j.io:[#F047]  C: COMMIT
# DEBUG:neo4j.io:[#F047]  _: <CONNECTION> client state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.io:[#F047]  S: SUCCESS {'bookmark': 'FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAiJA='}
# DEBUG:neo4j.io:[#F047]  _: <CONNECTION> server state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.pool:[#F047]  _: <POOL> released bolt-19
# DEBUG:llama_index.core.indices.knowledge_graph.retrievers:rel_map: {}
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> routing towards fixed database: neo4j
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> pinning database: 'neo4j'
# DEBUG:neo4j.pool:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database=AcquisitionDatabase(name='neo4j', guessed=False)
# DEBUG:neo4j.pool:[#F047]  _: <POOL> picked existing connection bolt-19
# DEBUG:neo4j.pool:[#F047]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j.pool:[#F047]  _: <POOL> handing out existing connection
# DEBUG:neo4j.io:[#F047]  C: BEGIN {'db': 'neo4j', 'bookmarks': ['FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAiJA=']}
# DEBUG:neo4j.io:[#F047]  _: <CONNECTION> client state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#F047]  C: RUN "MATCH p=(n1:Entity)-[*1..2]->() WHERE toLower(n1.id) IN ['rocket']UNWIND relationships(p) AS rel WITH n1.id AS subj, p, apoc.coll.flatten(apoc.coll.toSet(collect([type(rel), endNode(rel).id]))) AS flattened_rels RETURN subj, collect(flattened_rels) AS flattened_rels LIMIT 30" {'subjs': ['Rocket']} {}
# DEBUG:neo4j.io:[#F047]  C: PULL {'n': 1000}
# DEBUG:neo4j.io:[#F047]  S: SUCCESS {}
# DEBUG:neo4j.io:[#F047]  _: <CONNECTION> server state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#F047]  S: SUCCESS {'t_first': 12, 'fields': ['subj', 'flattened_rels'], 'qid': 0}
# DEBUG:neo4j.io:[#F047]  S: RECORD * 1
# DEBUG:neo4j.io:[#F047]  S: SUCCESS {'statuses': [{'gql_status': '00000', 'status_description': 'note: successful completion'}], 'type': 'r', 't_last': 22, 'db': 'neo4j'}
# DEBUG:neo4j.io:[#F047]  C: COMMIT
# DEBUG:neo4j.io:[#F047]  _: <CONNECTION> client state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.io:[#F047]  S: SUCCESS {'bookmark': 'FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAiJA='}
# DEBUG:neo4j.io:[#F047]  _: <CONNECTION> server state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.pool:[#F047]  _: <POOL> released bolt-19
# DEBUG:llama_index.core.indices.knowledge_graph.retrievers:rel_map: {'Rocket': [['FOUND_AND_EXPERIMENTED_ON_BY', 'High evolutionary'], ['FOUND_AND_EXPERIMENTED_ON_BY', 'High evolutionary', 'AIMED_TO_ENHANCE_AND_ANTHROPOMORPHIZE', 'Animal lifeforms'], ['FOUND_AND_EXPERIMENTED_ON_BY', 'High evolutionary', 'THREATENED', 'Sovereign'], ['FOUND_AND_EXPERIMENTED_ON_BY', 'High evolutionary', 'SPECIALIZES_IN', 'Creating hybrid creatures'], ['FOUND_AND_EXPERIMENTED_ON_BY', 'High evolutionary', 'DESCRIBED_AS', 'Cruelest mcu villain']]}
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> routing towards fixed database: neo4j
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> pinning database: 'neo4j'
# DEBUG:neo4j.pool:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database=AcquisitionDatabase(name='neo4j', guessed=False)
# DEBUG:neo4j.pool:[#F047]  _: <POOL> picked existing connection bolt-19
# DEBUG:neo4j.pool:[#F047]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j.pool:[#F047]  _: <POOL> handing out existing connection
# DEBUG:neo4j.io:[#F047]  C: BEGIN {'db': 'neo4j', 'bookmarks': ['FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAiJA=']}
# DEBUG:neo4j.io:[#F047]  _: <CONNECTION> client state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#F047]  C: RUN "MATCH p=(n1:Entity)-[*1..2]->() WHERE toLower(n1.id) IN ['facts']UNWIND relationships(p) AS rel WITH n1.id AS subj, p, apoc.coll.flatten(apoc.coll.toSet(collect([type(rel), endNode(rel).id]))) AS flattened_rels RETURN subj, collect(flattened_rels) AS flattened_rels LIMIT 30" {'subjs': ['facts']} {}
# DEBUG:neo4j.io:[#F047]  C: PULL {'n': 1000}
# DEBUG:neo4j.io:[#F047]  S: SUCCESS {}
# DEBUG:neo4j.io:[#F047]  _: <CONNECTION> server state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#F047]  S: SUCCESS {'t_first': 31, 'fields': ['subj', 'flattened_rels'], 'qid': 0}
# DEBUG:neo4j.io:[#F047]  S: SUCCESS {'statuses': [{'gql_status': '02000', 'status_description': 'note: no data'}], 'type': 'r', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j.io:[#F047]  C: COMMIT
# DEBUG:neo4j.io:[#F047]  _: <CONNECTION> client state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.io:[#F047]  S: SUCCESS {'bookmark': 'FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAiJA='}
# DEBUG:neo4j.io:[#F047]  _: <CONNECTION> server state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.pool:[#F047]  _: <POOL> released bolt-19
# DEBUG:llama_index.core.indices.knowledge_graph.retrievers:rel_map: {}
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> routing towards fixed database: neo4j
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> pinning database: 'neo4j'
# DEBUG:neo4j.pool:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database=AcquisitionDatabase(name='neo4j', guessed=False)
# DEBUG:neo4j.pool:[#F047]  _: <POOL> picked existing connection bolt-19
# DEBUG:neo4j.pool:[#F047]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j.pool:[#F047]  _: <POOL> handing out existing connection
# DEBUG:neo4j.io:[#F047]  C: BEGIN {'db': 'neo4j', 'bookmarks': ['FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAiJA=']}
# DEBUG:neo4j.io:[#F047]  _: <CONNECTION> client state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.pool:[#0000]  _: <POOL> close
# DEBUG:neo4j.io:[#F047]  C: RUN "MATCH p=(n1:Entity)-[*1..2]->() WHERE toLower(n1.id) IN ['uses']UNWIND relationships(p) AS rel WITH n1.id AS subj, p, apoc.coll.flatten(apoc.coll.toSet(collect([type(rel), endNode(rel).id]))) AS flattened_rels RETURN subj, collect(flattened_rels) AS flattened_rels LIMIT 30" {'subjs': ['uses']} {}
# DEBUG:neo4j.io:[#F047]  C: PULL {'n': 1000}
# DEBUG:neo4j.io:[#F047]  S: SUCCESS {}
# DEBUG:neo4j.io:[#F047]  _: <CONNECTION> server state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#F047]  S: SUCCESS {'t_first': 7, 'fields': ['subj', 'flattened_rels'], 'qid': 0}
# DEBUG:neo4j.io:[#F047]  S: SUCCESS {'statuses': [{'gql_status': '02000', 'status_description': 'note: no data'}], 'type': 'r', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j.io:[#F047]  C: COMMIT
# DEBUG:neo4j.io:[#F047]  _: <CONNECTION> client state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.io:[#F047]  S: SUCCESS {'bookmark': 'FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAiJA='}
# DEBUG:neo4j.io:[#F047]  _: <CONNECTION> server state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.pool:[#F047]  _: <POOL> released bolt-19
# DEBUG:llama_index.core.indices.knowledge_graph.retrievers:rel_map: {}
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> routing towards fixed database: neo4j
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> pinning database: 'neo4j'
# DEBUG:neo4j.pool:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database=AcquisitionDatabase(name='neo4j', guessed=False)
# DEBUG:neo4j.pool:[#F047]  _: <POOL> picked existing connection bolt-19
# DEBUG:neo4j.pool:[#F047]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j.pool:[#F047]  _: <POOL> handing out existing connection
# DEBUG:neo4j.io:[#F047]  C: BEGIN {'db': 'neo4j', 'bookmarks': ['FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAiJA=']}
# DEBUG:neo4j.io:[#F047]  _: <CONNECTION> client state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#F047]  C: RUN "MATCH p=(n1:Entity)-[*1..2]->() WHERE toLower(n1.id) IN ['characteristics']UNWIND relationships(p) AS rel WITH n1.id AS subj, p, apoc.coll.flatten(apoc.coll.toSet(collect([type(rel), endNode(rel).id]))) AS flattened_rels RETURN subj, collect(flattened_rels) AS flattened_rels LIMIT 30" {'subjs': ['characteristics']} {}
# DEBUG:neo4j.io:[#F047]  C: PULL {'n': 1000}
# DEBUG:neo4j.io:[#F047]  S: SUCCESS {}
# DEBUG:neo4j.io:[#F047]  _: <CONNECTION> server state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#F047]  S: SUCCESS {'t_first': 2, 'fields': ['subj', 'flattened_rels'], 'qid': 0}
# DEBUG:neo4j.io:[#F047]  S: SUCCESS {'statuses': [{'gql_status': '02000', 'status_description': 'note: no data'}], 'type': 'r', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j.io:[#F047]  C: COMMIT
# DEBUG:neo4j.io:[#F047]  _: <CONNECTION> client state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.io:[#F047]  S: SUCCESS {'bookmark': 'FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAiJA='}
# DEBUG:neo4j.io:[#F047]  _: <CONNECTION> server state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.pool:[#F047]  _: <POOL> released bolt-19
# DEBUG:llama_index.core.indices.knowledge_graph.retrievers:rel_map: {}
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> routing towards fixed database: neo4j
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> pinning database: 'neo4j'
# DEBUG:neo4j.pool:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database=AcquisitionDatabase(name='neo4j', guessed=False)
# DEBUG:neo4j.pool:[#F047]  _: <POOL> picked existing connection bolt-19
# DEBUG:neo4j.pool:[#F047]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j.pool:[#F047]  _: <POOL> handing out existing connection
# DEBUG:neo4j.io:[#F047]  C: BEGIN {'db': 'neo4j', 'bookmarks': ['FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAiJA=']}
# DEBUG:neo4j.io:[#F047]  _: <CONNECTION> client state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#F047]  C: RUN "MATCH p=(n1:Entity)-[*1..2]->() WHERE toLower(n1.id) IN ['technology']UNWIND relationships(p) AS rel WITH n1.id AS subj, p, apoc.coll.flatten(apoc.coll.toSet(collect([type(rel), endNode(rel).id]))) AS flattened_rels RETURN subj, collect(flattened_rels) AS flattened_rels LIMIT 30" {'subjs': ['technology']} {}
# DEBUG:neo4j.io:[#F047]  C: PULL {'n': 1000}
# DEBUG:neo4j.io:[#F047]  S: SUCCESS {}
# DEBUG:neo4j.io:[#F047]  _: <CONNECTION> server state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#F047]  S: SUCCESS {'t_first': 0, 'fields': ['subj', 'flattened_rels'], 'qid': 0}
# DEBUG:neo4j.io:[#F047]  S: SUCCESS {'statuses': [{'gql_status': '02000', 'status_description': 'note: no data'}], 'type': 'r', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j.io:[#F047]  C: COMMIT
# DEBUG:neo4j.io:[#F047]  _: <CONNECTION> client state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.io:[#F047]  S: SUCCESS {'bookmark': 'FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAiJA='}
# DEBUG:neo4j.io:[#F047]  _: <CONNECTION> server state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.pool:[#F047]  _: <POOL> released bolt-19
# DEBUG:llama_index.core.indices.knowledge_graph.retrievers:rel_map: {}
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> routing towards fixed database: neo4j
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> pinning database: 'neo4j'
# DEBUG:neo4j.pool:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database=AcquisitionDatabase(name='neo4j', guessed=False)
# DEBUG:neo4j.pool:[#F047]  _: <POOL> picked existing connection bolt-19
# DEBUG:neo4j.pool:[#F047]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j.pool:[#F047]  _: <POOL> handing out existing connection
# DEBUG:neo4j.io:[#F047]  C: BEGIN {'db': 'neo4j', 'bookmarks': ['FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAiJA=']}
# DEBUG:neo4j.io:[#F047]  _: <CONNECTION> client state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#F047]  C: RUN "MATCH p=(n1:Entity)-[*1..2]->() WHERE toLower(n1.id) IN ['information']UNWIND relationships(p) AS rel WITH n1.id AS subj, p, apoc.coll.flatten(apoc.coll.toSet(collect([type(rel), endNode(rel).id]))) AS flattened_rels RETURN subj, collect(flattened_rels) AS flattened_rels LIMIT 30" {'subjs': ['information']} {}
# DEBUG:neo4j.io:[#F047]  C: PULL {'n': 1000}
# DEBUG:neo4j.io:[#F047]  S: SUCCESS {}
# DEBUG:neo4j.io:[#F047]  _: <CONNECTION> server state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#F047]  S: SUCCESS {'t_first': 18, 'fields': ['subj', 'flattened_rels'], 'qid': 0}
# DEBUG:neo4j.io:[#F047]  S: SUCCESS {'statuses': [{'gql_status': '02000', 'status_description': 'note: no data'}], 'type': 'r', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j.io:[#F047]  C: COMMIT
# DEBUG:neo4j.io:[#F047]  _: <CONNECTION> client state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.io:[#F047]  S: SUCCESS {'bookmark': 'FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAiJA='}
# DEBUG:neo4j.io:[#F047]  _: <CONNECTION> server state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.pool:[#F047]  _: <POOL> released bolt-19
# DEBUG:llama_index.core.indices.knowledge_graph.retrievers:rel_map: {}
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> routing towards fixed database: neo4j
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> pinning database: 'neo4j'
# DEBUG:neo4j.pool:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database=AcquisitionDatabase(name='neo4j', guessed=False)
# DEBUG:neo4j.pool:[#F047]  _: <POOL> picked existing connection bolt-19
# DEBUG:neo4j.pool:[#F047]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j.pool:[#F047]  _: <POOL> handing out existing connection
# DEBUG:neo4j.io:[#F047]  C: BEGIN {'db': 'neo4j', 'bookmarks': ['FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAiJA=']}
# DEBUG:neo4j.io:[#F047]  _: <CONNECTION> client state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#F047]  C: RUN "MATCH p=(n1:Entity)-[*1..2]->() WHERE toLower(n1.id) IN ['details']UNWIND relationships(p) AS rel WITH n1.id AS subj, p, apoc.coll.flatten(apoc.coll.toSet(collect([type(rel), endNode(rel).id]))) AS flattened_rels RETURN subj, collect(flattened_rels) AS flattened_rels LIMIT 30" {'subjs': ['details']} {}
# DEBUG:neo4j.io:[#F047]  C: PULL {'n': 1000}
# DEBUG:neo4j.io:[#F047]  S: SUCCESS {}
# DEBUG:neo4j.io:[#F047]  _: <CONNECTION> server state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#F047]  S: SUCCESS {'t_first': 41, 'fields': ['subj', 'flattened_rels'], 'qid': 0}
# DEBUG:neo4j.io:[#F047]  S: SUCCESS {'statuses': [{'gql_status': '02000', 'status_description': 'note: no data'}], 'type': 'r', 't_last': 0, 'db': 'neo4j'}
# DEBUG:neo4j.io:[#F047]  C: COMMIT
# DEBUG:neo4j.io:[#F047]  _: <CONNECTION> client state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.io:[#F047]  S: SUCCESS {'bookmark': 'FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAiJA='}
# DEBUG:neo4j.io:[#F047]  _: <CONNECTION> server state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.pool:[#F047]  _: <POOL> released bolt-19
# DEBUG:llama_index.core.indices.knowledge_graph.retrievers:rel_map: {}
# WARNING:llama_index.core.indices.knowledge_graph.retrievers:Index was not constructed with embeddings, skipping embedding usage...
# INFO:llama_index.core.indices.knowledge_graph.retrievers:> Querying with idx: 5e22f21d-8c06-451b-a705-710b20e7c501: By the end of April, the franchise's five main stars—Pratt, Saldaña, Bautista...
# INFO:llama_index.core.indices.knowledge_graph.retrievers:> Querying with idx: 328077e3-a9e7-41f0-a79f-15c0e5245d4b: The Guardians travel to Orgocorp's headquarters to find the switch's override...
# INFO:llama_index.core.indices.knowledge_graph.retrievers:> Querying with idx: f28e7668-bc3f-4707-b5cb-a784ad14eaf6: The new Guardians—Rocket, Groot, Kraglin, Cosmo, Adam, Phyla (one of the resc...
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/completions', 'files': None, 'idempotency_key': 'stainless-python-retry-9facb942-76d9-4a51-a7f4-7e8c6dc3486a', 'json_data': {'model': 'qwen2.5', 'prompt': 'Context information from multiple sources is below.\n---------------------\nBy the end of April, the franchise\'s five main stars—Pratt, Saldaña, Bautista, Cooper, and Diesel—were all expected to return for the sequel, with filming to take place in 2020.\nDiscussing his firing and re-hiring in May 2019, Gunn said that of all the elements of the film that he had been sad to leave when he was fired, the most meaningful to him was the character of Rocket. Gunn personally identifies with Rocket, describing himself and the character as "the same". He had grown to love the character since working on the first film due to feeling that an origin story for Rocket could justify what a Bugs Bunny-like "goofy character" like him could exist in the MCU if it were the saddest one in the universe, crediting it as the "seed" of the trilogy. While Vol. 3 effectively reveals Rocket\'s backstory through flashbacks akin to those from the story structure of The Godfather Part II (1974), Gunn initially considered telling Rocket\'s origins in a team-up movie between him and Groot without the other Guardians. He was eventually convinced to make a third Guardians-centric film instead of the Rocket and Groot film but chose to use it to tell Rocket\'s story. That month, Gillan confirmed that she was returning for the sequel and expressed excitement for Gunn\'s return to the franchise. In June, Saldaña was asked about her role in the film after her character Gamora was killed in Infinity War, and she returned to play a younger version in Endgame who travels through time to the present. Saldaña said that Gamora\'s fate would depend on the plans that Marvel and Gunn have for Vol. 3, but that she would like to see Gamora rejoin the Guardians and also be portrayed as "the most lethal woman in the galaxy" as she has been referred to previously. Gunn was asked in October if he was unhappy about Marvel\'s decision to kill Gamora in Infinity War and said he was not, adding that he had discussed the storyline with the studio beforehand. According to Infinity War and Endgame screenwriters Christopher Markus and Stephen McFeely, Gamora was brought back in Endgame specifically so that Gunn could include her in Vol. 3.\n\nThe Guardians travel to Orgocorp\'s headquarters to find the switch\'s override code and save Rocket\'s life.\nAs Rocket lies dying, he recalls his past. He was found and experimented on as a baby raccoon by the High Evolutionary, leader of Orgocorp, who aimed to enhance and anthropomorphize animal lifeforms into "Humanimals" for an ideal society, Counter-Earth. Rocket\'s fellow Batch 89 test subjects included the otter Lylla, walrus Teefs, and rabbit Floor. Impressed by Rocket\'s intelligence, the High Evolutionary used his insights to improve later batches of Humanimals. Angry that one of his creations could solve a problem that he could not, the High Evolutionary planned to harvest Rocket\'s brain and incinerate all of Batch 89. Rocket tried to rescue his friends, but the High Evolutionary killed Lylla and mocked Rocket\'s grief. Enraged, Rocket attacked the High Evolutionary, whose henchmen killed Teefs and Floor during the chaos. Rocket escaped in a spaceship.\nIn the present, an alternate version of Gamora, who has joined the Ravagers, helps the Guardians infiltrate Orgocorp. They retrieve Rocket\'s file but discover that Theel, one of the High Evolutionary\'s advisors, has removed the override code. The Guardians and Gamora travel to Counter-Earth to find him. They are followed by Ayesha and Adam after the High Evolutionary, their race\'s creator, threatened to wipe out the Sovereign if they failed to retrieve Rocket. At Counter-Earth, Drax and Mantis remain with Gamora and Rocket while Peter Quill, Groot, and Nebula go ...
# DEBUG:openai._base_client:Sending HTTP Request: POST https://llms-inference.innkube.fim.uni-passau.de/completions
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Tue, 29 Apr 2025 10:06:38 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'3603'), (b'Connection', b'keep-alive'), (b'x-litellm-call-id', b'353dc800-c2d4-4175-90e0-f53321627229'), (b'x-litellm-model-id', b'4fc98ad04997d06d243fa1037a8527856cb537a73abc970ce37122958bbea148'), (b'x-litellm-model-api-base', b'http://qwen2-5-ollama:11434'), (b'x-litellm-version', b'1.42.2'), (b'x-litellm-response-cost', b'1.087178'), (b'x-litellm-key-tpm-limit', b'None'), (b'x-litellm-key-rpm-limit', b'100'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains'), (b'Access-Control-Allow-Origin', b'*'), (b'Access-Control-Allow-Credentials', b'true'), (b'Access-Control-Allow-Methods', b'PUT, GET, POST'), (b'Access-Control-Allow-Headers', b'DNT,Keep-Alive,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range,Authorization'), (b'Access-Control-Max-Age', b'1728000')])
# INFO:httpx:HTTP Request: POST https://llms-inference.innkube.fim.uni-passau.de/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Response: POST https://llms-inference.innkube.fim.uni-passau.de/completions "200 OK" Headers({'date': 'Tue, 29 Apr 2025 10:06:38 GMT', 'content-type': 'application/json', 'content-length': '3603', 'connection': 'keep-alive', 'x-litellm-call-id': '353dc800-c2d4-4175-90e0-f53321627229', 'x-litellm-model-id': '4fc98ad04997d06d243fa1037a8527856cb537a73abc970ce37122958bbea148', 'x-litellm-model-api-base': 'http://qwen2-5-ollama:11434', 'x-litellm-version': '1.42.2', 'x-litellm-response-cost': '1.087178', 'x-litellm-key-tpm-limit': 'None', 'x-litellm-key-rpm-limit': '100', 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'access-control-allow-origin': '*', 'access-control-allow-credentials': 'true', 'access-control-allow-methods': 'PUT, GET, POST', 'access-control-allow-headers': 'DNT,Keep-Alive,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range,Authorization', 'access-control-max-age': '1728000'})
# DEBUG:openai._base_client:request_id: None

# %%
display(Markdown(f"<b>{response}</b>"))
# Out:
# <b>Rocket is a central character in the Guardians of the Galaxy franchise, known for his sharp wit, combat skills, and complex backstory. Here’s a detailed look at Rocket's character:
#
# 1. **Background and Origin**:
#    - **Experimentation**: As a baby raccoon, Rocket was found and experimented on by the High Evolutionary, the leader of Orgocorp. The High Evolutionary aimed to enhance and anthropomorphize animal lifeforms into "Humanimals" for an ideal society called Counter-Earth.
#    - **Batch 89**: Rocket was part of Batch 89, which included other test subjects like Lylla (an otter), Teefs (a walrus), and Floor (a rabbit). The High Evolutionary used Rocket's intelligence to improve later batches of Humanimals.
#    - **Escape**: When the High Evolutionary planned to harvest Rocket's brain and incinerate Batch 89, Rocket tried to save his friends. However, Lylla was killed by the High Evolutionary, who mocked Rocket's grief. Enraged, Rocket attacked the High Evolutionary, leading to the deaths of Teefs and Floor during the chaos. Rocket managed to escape in a spaceship.
#
# 2. **Personality and Traits**:
#    - **Intelligence**: Rocket is highly intelligent and resourceful, often using his skills to solve complex problems.
#    - **Combat Skills**: He is a skilled fighter and marksman, contributing significantly to the Guardians' missions.
#    - **Emotional Depth**: Despite his tough exterior, Rocket has deep emotional scars from his past. His experiences with the High Evolutionary have left him with a sense of loss and anger.
#
# 3. **Role in the Guardians**:
#    - **Team Member**: Rocket is a founding member of the Guardians of the Galaxy, working alongside Peter Quill (Star-Lord), Gamora, Drax, and Nebula.
#    - **Leadership**: While not the official leader, Rocket often takes on leadership roles during missions, especially when it comes to tactical planning and problem-solving.
#
# 4. **Relationships**:
#    - **Peter Quill (Star-Lord)**: Rocket has a strong bond with Star-Lord, often acting as his right-hand man and providing support in both combat and emotional situations.
#    - **Gamora**: Rocket's relationship with Gamora is one of mutual respect and camaraderie. They have fought together and rely on each other in the field.
#    - **Drax and Nebula**: Rocket shares a deep friendship with Drax and Nebula, though their interactions can sometimes be tense due to their different personalities.
#
# 5. **Significance in the Franchise**:
#    - **Backstory Focus**: In "Guardians of the Galaxy Vol. 3," Rocket's backstory is explored in depth, providing insight into his past and the events that shaped him.
#    - **Character Development**: The film delves into Rocket's emotional journey, particularly his struggle with the loss of his friends and the trauma he endured at the hands of the High Evolutionary.
#
# 6. **Portrayal**:
#    - **Voice Actor**: Rocket is voiced by Bradley Cooper, who brings a mix of humor, toughness, and vulnerability to the character.
#    - **CGI Animation**: The character is brought to life through advanced CGI, making him one of the most visually impressive characters in the Marvel Cinematic Universe.
#
# Rocket's complex history and dynamic personality make him a fan favorite and a crucial part of the Guardians of the Galaxy story.</b>

# %%
from neo4j import GraphDatabase

# Connect to the database
uri = "bolt://localhost:7687"
username = "neo4j"
password = "neo4j123"

driver = GraphDatabase.driver(uri, auth=(username, password))
# Out:
# DEBUG:neo4j.pool:[#0000]  _: <POOL> created, direct address IPv4Address(('localhost', 7687))

# %%
def fetch_graph(tx, limit=50):
    query = """
    MATCH (n)-[r]->(m)
    RETURN n, r, m
    LIMIT $limit
    """
    result = tx.run(query, limit=limit)
    data = []

    for record in result:
        data.append({
            "source": dict(record["n"]),
            "relation": record["r"].type,
            "target": dict(record["m"])
        })

    return data

# Safely extract and store the graph data
with driver.session() as session:
    graph_data = session.read_transaction(fetch_graph)

# Now build the sets for visualization
nodes = set()
edges = []

for entry in graph_data:
    source = entry["source"].get("name", str(entry["source"]))
    target = entry["target"].get("name", str(entry["target"]))
    relation = entry["relation"]

    nodes.add(source)
    nodes.add(target)
    edges.append((source, target, relation))
# Out:
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> routing towards fixed database: None
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> pinning database: None
# DEBUG:neo4j.pool:[#0000]  _: <POOL> acquire direct connection, access_mode='READ', database=AcquisitionDatabase(name=None, guessed=False)
# DEBUG:neo4j.pool:[#F88E]  _: <POOL> picked existing connection bolt-25
# DEBUG:neo4j.pool:[#F88E]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j.pool:[#F88E]  _: <POOL> handing out existing connection
# DEBUG:neo4j.io:[#F88E]  C: BEGIN {'mode': 'r'}
# DEBUG:neo4j.io:[#F88E]  _: <CONNECTION> client state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#F88E]  S: SUCCESS {}
# DEBUG:neo4j.io:[#F88E]  _: <CONNECTION> server state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#F88E]  C: RUN '\n    MATCH (n)-[r]->(m)\n    RETURN n, r, m\n    LIMIT $limit\n    ' {'limit': 50} {}
# DEBUG:neo4j.io:[#F88E]  C: PULL {'n': 1000}
# DEBUG:neo4j.io:[#F88E]  S: SUCCESS {'t_first': 0, 'fields': ['n', 'r', 'm'], 'qid': 0}
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: RECORD * 1
# DEBUG:neo4j.io:[#F88E]  S: SUCCESS {'statuses': [{'gql_status': '00000', 'status_description': 'note: successful completion'}], 'type': 'r', 't_last': 7, 'db': 'neo4j'}
# DEBUG:neo4j.io:[#F88E]  C: COMMIT
# DEBUG:neo4j.io:[#F88E]  _: <CONNECTION> client state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.io:[#F88E]  S: SUCCESS {'bookmark': 'FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAiJA='}
# DEBUG:neo4j.io:[#F88E]  _: <CONNECTION> server state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.pool:[#F88E]  _: <POOL> released bolt-25
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_17196\2671942141.py:21: DeprecationWarning: read_transaction has been renamed to execute_read
#   graph_data = session.read_transaction(fetch_graph)

# %%
from pyvis.network import Network
from IPython.display import IFrame

net = Network(notebook=True, height="600px", width="100%", cdn_resources='in_line')

for node in nodes:
    net.add_node(node, label=node)

for source, target, rel in edges:
    net.add_edge(source, target, label=rel)

net.show("neo4j_graph.html")
# IFrame("neo4j_graph.html", width="100%", height="600px")
# Out:
# neo4j_graph.html
#         <iframe
#             width="100%"
#             height="600px"
#             src="neo4j_graph.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
print(dir(index))
# Out:
# ['__abstractmethods__', '__annotations__', '__class__', '__class_getitem__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__orig_bases__', '__parameters__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_build_index_from_nodes', '_callback_manager', '_delete_node', '_docstore', '_embed_model', '_extract_triplets', '_graph_store', '_index_struct', '_insert', '_is_protocol', '_kg_triplet_extract_fn', '_llm', '_llm_extract_triplets', '_max_object_length', '_object_map', '_parse_triplet_response', '_show_progress', '_storage_context', '_transformations', '_vector_store', 'add_node', 'as_chat_engine', 'as_query_engine', 'as_retriever', 'build_index_from_nodes', 'delete', 'delete_nodes', 'delete_ref_doc', 'docstore', 'from_documents', 'get_networkx_graph', 'graph_store', 'include_embeddings', 'index_id', 'index_struct', 'index_struct_cls', 'insert', 'insert_nodes', 'kg_triplet_extract_template', 'max_triplets_per_chunk', 'query_context', 'ref_doc_info', 'refresh', 'refresh_ref_docs', 'set_index_id', 'storage_context', 'summary', 'update', 'update_ref_doc', 'upsert_triplet', 'upsert_triplet_and_node']

# %%
graph = index.get_networkx_graph()
# print(graph.nodes())  # List all nodes in the graph
# print(graph.edges())  # List all edges in the graph
# print(graph.nodes(data=True))  # List all nodes with their attributes
# print(graph.edges(data=True))  # List all edges with their attributes
# Out:
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> routing towards fixed database: neo4j
# DEBUG:neo4j:[#0000]  _: <WORKSPACE> pinning database: 'neo4j'
# DEBUG:neo4j.pool:[#0000]  _: <POOL> acquire direct connection, access_mode='WRITE', database=AcquisitionDatabase(name='neo4j', guessed=False)
# DEBUG:neo4j.pool:[#F672]  _: <POOL> picked existing connection bolt-3
# DEBUG:neo4j.pool:[#F672]  _: <POOL> checked re_auth auth=None updated=False force=False
# DEBUG:neo4j.pool:[#F672]  _: <POOL> handing out existing connection
# DEBUG:neo4j.io:[#F672]  C: BEGIN {'db': 'neo4j', 'bookmarks': ['FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAiJA=']}
# DEBUG:neo4j.io:[#F672]  _: <CONNECTION> client state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#F672]  C: RUN 'MATCH p=(n1:Entity)-[*1..1]->() WHERE toLower(n1.id) IN [\'guardians of the galaxy vol. 3\', \'superhero film\', \'marvel studios\', \'disneyland paris\', \'united states\', \'rocket\', \'high evolutionary\', \'animal lifeforms\', \'ayesha\', \'adam\', \'sovereign\', \'kraglin\', \'arête\', \'guardians\', \'groot\', \'dave bautista\', \'drax the destroyer\', \'karen gillan\', \'nebula\', \'pom klementieff\', \'mantis\', \'chukwudi iwuji\', \'creating hybrid creatures\', \'gunn\', \'cruelest mcu villain\', \'maria bakalova\', \'cosmo\', \'cameo appearances\', \'lloyd kaufman as gridlemop\', \'james gunn\', \'writer and director of guardians of the galaxy\', \'april 2017\', \'disney\', \'controversial topics\', \'chris pratt\', \'peter quill / star-lord\', \'totally failed efforts\', \'guardians cast members\', \'$7-10 million\', \'dc extended universe\', \'horn\', \'cooper\', \'vol. 3\', \'the suicide squad\', \'saldaña\', \'younger gamora\', \'younger version of gamora\', \'covid-19 pandemic would not affect production plans for the film\', "new draft of the film\'s script", \'ending decided upon in editing\', \'june\', \'kumail nanjiani\', \'adam warlock\', \'poulter\', \'dramatic and comedic abilities\', \'iwuji\', \'film\', \'vol. 3 set and crew\', \'mcu film\', \'uncensored word "fuck\', \'awesome mix vol. 1 and vol. 2\', \'july 2017\', \'2022 san diego comic-con\', \'walt disney studios home entertainment\', \'walt disney studios home entertainment in australia\', \'82%\', \'a\', \'matt singer\', "rocket\'s arc story concludes", \'philz\', \'coffee shop\', \'rocket raccoon\', \'gives guardians reason to come together\', \'people for the ethical treatment of animals\', \'the best animal rights film of the year\', \'not a number award\', \'marvel.com\', \'imdb\']UNWIND relationships(p) AS rel WITH n1.id AS subj, p, apoc.coll.flatten(apoc.coll.toSet(collect([type(rel), endNode(rel).id]))) AS flattened_rels RETURN subj, collect(flattened_rels) AS flattened_rels LIMIT 100' {'subjs': ['Guardians of the galaxy vol. 3', 'Superhero film', 'Marvel studios', 'Disneyland paris', 'United states', 'Rocket', 'High evolutionary', 'Animal lifeforms', 'Ayesha', 'Adam', 'Sovereign', 'Kraglin', 'Arête', 'Guardians', 'Groot', 'Dave bautista', 'Drax the destroyer', 'Karen gillan', 'Nebula', 'Pom klementieff', 'Mantis', 'Chukwudi iwuji', 'Creating hybrid creatures', 'Gunn', 'Cruelest mcu villain', 'Maria bakalova', 'Cosmo', 'Cameo appearances', 'Lloyd kaufman as gridlemop', 'James gunn', 'Writer and director of guardians of the galaxy', 'April 2017', 'Disney', 'Controversial topics', 'Chris pratt', 'Peter quill / star-lord', 'Totally failed efforts', 'Guardians cast members', '$7-10 million', 'Dc extended universe', 'Horn', 'Cooper', 'Vol. 3', 'The suicide squad', 'Saldaña', 'Younger gamora', 'Younger version of gamora', 'Covid-19 pandemic would not affect production plans for the film', "New draft of the film's script", 'Ending decided upon in editing', 'June', 'Kumail nanjiani', 'Adam warlock', 'Poulter', 'Dramatic and comedic abilities', 'Iwuji', 'Film', 'Vol. 3 set and crew', 'Mcu film', 'Uncensored word "fuck', 'Awesome mix vol. 1 and vol. 2', 'July 2017', '2022 san diego comic-con', 'Walt disney studios home entertainment', 'Walt disney studios home entertainment in australia', '82%', 'A', 'Matt singer', "Rocket's arc story concludes", 'Philz', 'Coffee shop', 'Rocket raccoon', 'Gives guardians reason to come together', 'People for the ethical treatment of animals', 'The best animal rights film of the year', 'Not a number award', 'Marvel.com', 'Imdb']} {}
# DEBUG:neo4j.io:[#F672]  C: PULL {'n': 1000}
# DEBUG:neo4j.io:[#F672]  S: SUCCESS {}
# DEBUG:neo4j.io:[#F672]  _: <CONNECTION> server state: READY > TX_READY_OR_TX_STREAMING
# DEBUG:neo4j.io:[#F672]  S: SUCCESS {'t_first': 7, 'fields': ['subj', 'flattened_rels'], 'qid': 0}
# DEBUG:neo4j.io:[#F672]  S: RECORD * 1
# DEBUG:neo4j.io:[#F672]  S: RECORD * 1
# DEBUG:neo4j.io:[#F672]  S: RECORD * 1
# DEBUG:neo4j.io:[#F672]  S: RECORD * 1
# DEBUG:neo4j.io:[#F672]  S: RECORD * 1
# DEBUG:neo4j.io:[#F672]  S: RECORD * 1
# DEBUG:neo4j.io:[#F672]  S: RECORD * 1
# DEBUG:neo4j.io:[#F672]  S: RECORD * 1
# DEBUG:neo4j.io:[#F672]  S: RECORD * 1
# DEBUG:neo4j.io:[#F672]  S: RECORD * 1
# DEBUG:neo4j.io:[#F672]  S: RECORD * 1
# DEBUG:neo4j.io:[#F672]  S: RECORD * 1
# DEBUG:neo4j.io:[#F672]  S: RECORD * 1
# DEBUG:neo4j.io:[#F672]  S: RECORD * 1
# DEBUG:neo4j.io:[#F672]  S: RECORD * 1
# DEBUG:neo4j.io:[#F672]  S: RECORD * 1
# DEBUG:neo4j.io:[#F672]  S: RECORD * 1
# DEBUG:neo4j.io:[#F672]  S: RECORD * 1
# DEBUG:neo4j.io:[#F672]  S: RECORD * 1
# DEBUG:neo4j.io:[#F672]  S: RECORD * 1
# DEBUG:neo4j.io:[#F672]  S: RECORD * 1
# DEBUG:neo4j.io:[#F672]  S: RECORD * 1
# DEBUG:neo4j.io:[#F672]  S: RECORD * 1
# DEBUG:neo4j.io:[#F672]  S: RECORD * 1
# DEBUG:neo4j.io:[#F672]  S: RECORD * 1
# DEBUG:neo4j.io:[#F672]  S: RECORD * 1
# DEBUG:neo4j.io:[#F672]  S: RECORD * 1
# DEBUG:neo4j.io:[#F672]  S: RECORD * 1
# DEBUG:neo4j.io:[#F672]  S: RECORD * 1
# DEBUG:neo4j.io:[#F672]  S: RECORD * 1
# DEBUG:neo4j.io:[#F672]  S: SUCCESS {'statuses': [{'gql_status': '00000', 'status_description': 'note: successful completion'}], 'type': 'r', 't_last': 31, 'db': 'neo4j'}
# DEBUG:neo4j.io:[#F672]  C: COMMIT
# DEBUG:neo4j.io:[#F672]  _: <CONNECTION> client state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.io:[#F672]  S: SUCCESS {'bookmark': 'FB:kcwQBKSVGJtoSZS3C7vmPo+vEskAiJA='}
# DEBUG:neo4j.io:[#F672]  _: <CONNECTION> server state: TX_READY_OR_TX_STREAMING > READY
# DEBUG:neo4j.pool:[#F672]  _: <POOL> released bolt-3

# %%
os.environ['NEBULA_USER'] = "root"
os.environ['NEBULA_PASSWORD'] = "nebula"  # or replace with your password
os.environ['NEBULA_ADDRESS'] = "127.0.0.1:9669"  # Assuming NebulaGraph is running locally

# %%
# service_context = ServiceContext.from_defaults(
#     llm_predictor=llm_qwen,
#     embed_model=embed_model_snow
# )

# Set global settings (optional, if not passed locally)
Settings.llm = llm_qwen
Settings.embed_model = embed_model_snow
Settings.chunk_size = 512

space_name = "llamaindex"
edge_types, rel_prop_names = ["relationship"], ["relationship"] # default, could be omit if create from an empty kg
tags = ["entity"] # default, could be omit if create from an empty kg

graph_store = NebulaGraphStore(space_name=space_name, edge_types=edge_types, rel_prop_names=rel_prop_names, tags=tags)
storage_context = StorageContext.from_defaults(graph_store=graph_store)
# Out:
# WARNING:nebula3.logger:Connect 127.0.0.1:9669 failed: socket error connecting to host 127.0.0.1, port 9669 (('127.0.0.1', 9669)): ConnectionRefusedError(111, 'Connection refused')
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[139], line 15
#      12 edge_types, rel_prop_names = ["relationship"], ["relationship"] # default, could be omit if create from an empty kg
#      13 tags = ["entity"] # default, could be omit if create from an empty kg
# ---> 15 graph_store = NebulaGraphStore(space_name=space_name, edge_types=edge_types, rel_prop_names=rel_prop_names, tags=tags)
#      16 storage_context = StorageContext.from_defaults(graph_store=graph_store)
#
# File ~/envs/llmexp/lib/python3.9/site-packages/llama_index/graph_stores/nebula/nebula_graph_store.py:142, in NebulaGraphStore.__init__(self, session_pool, space_name, edge_types, rel_prop_names, tags, tag_prop_names, include_vid, session_pool_kwargs, **kwargs)
#     140 self._session_pool: Any = session_pool
#     141 if self._session_pool is None:
# --> 142     self.init_session_pool()
#     144 self._vid_type = self._get_vid_type()
#     146 self._tags = tags or ["entity"]
#
# File ~/envs/llmexp/lib/python3.9/site-packages/llama_index/graph_stores/nebula/nebula_graph_store.py:228, in NebulaGraphStore.init_session_pool(self)
#     220 session_pool = SessionPool(
#     221     os.environ["NEBULA_USER"],
#     222     os.environ["NEBULA_PASSWORD"],
#     223     self._space_name,
#     224     [(graphd_host, int(graphd_port))],
#     225 )
#     227 session_pool_config = SessionPoolConfig()
# --> 228 session_pool.init(session_pool_config)
#     229 self._session_pool = session_pool
#     230 return self._session_pool
#
# File ~/envs/llmexp/lib/python3.9/site-packages/nebula3/gclient/net/SessionPool.py:117, in SessionPool.init(self, configs, ssl_configs)
#     115 ok_num = self.get_ok_servers_num()
#     116 if ok_num < len(self._addresses):
# --> 117     raise RuntimeError(
#     118         "The services status exception: {}".format(self._get_services_status())
#     119     )
#     121 # iterate all addresses and create sessions to fullfil the min_size
#     122 for i in range(self._configs.min_size):
#
# RuntimeError: The services status exception: [services: ('127.0.0.1', 9669), status: BAD]

# %%
kg_index = KnowledgeGraphIndex.from_documents(
    documents,
    storage_context=storage_context,
    max_triplets_per_chunk=10,
    llm = llm_qwen,
    space_name=space_name,
    edge_types=edge_types,
    rel_prop_names=rel_prop_names,
    tags=tags,
    include_embeddings=False,
)
# Out:
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: Guardians of the Galaxy Vol. 3 (marketed as Gua...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: His return was publicly revealed in March 2019,...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: The Guardians travel to Orgocorp's headquarters...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: They are followed by Ayesha and Adam after the ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: The other Guardians orchestrate a rescue, which...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: The new Guardians—Rocket, Groot, Kraglin, Cosmo...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: Dave Bautista as Drax the Destroyer:A member of...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: Pom Klementieff as Mantis: A member of the Guar...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: Poulter believed there was "a lot of comedy" in...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: Gunn likened the High Evolutionary to "a space ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: Maria Bakalova reprises her voice and motion ca...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: Cameo appearances in the film include Lloyd Kau...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: In March 2017, Gunn said there would be a third...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 3 shortly after completing his work as executiv...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: In April, Chris Pratt was set to reprise his ro...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: My days saying something just because it's shoc...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: Despite this and the notable "vociferous suppor...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: for their rival superhero franchise, the DC Ext...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: At the end of the month, Cooper was asked if he...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: By the end of April, the franchise's five main ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: In June, Saldaña was asked about her role in th...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: In April, Gunn said the COVID-19 pandemic would...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: Gunn noted this ending was decided upon "in edi...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: Gunn originally wrote a cameo appearance for Ku...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: Poulter was cast as Adam Warlock in October, an...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: Iwuji's screen test for the film was shot on th...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: 3, given the tonal difference between the two w...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: == Music ==
#
# In April 2017, Gunn felt the music...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: == Marketing ==
#
# The film was discussed during ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: Hermanns also said the second trailer "goes a s...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: === Home media ===
# Guardians of the Galaxy Vol....
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: === Critical response ===
# The review aggregator...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: Matt Singer from ScreenCrush praised the film f...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: A negative review from NPR criticized the appro...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: == Notes ==
#
#
# == References ==
#
#
# == External li...
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/completions', 'files': None, 'json_data': {'model': 'qwen2.5', 'prompt': "Some text is provided below. Given the text, extract up to 10 knowledge triplets in the form of (subject, predicate, object). Avoid stopwords.\n---------------------\nExample:Text: Alice is Bob's mother.Triplets:\n(Alice, is mother of, Bob)\nText: Philz is a coffee shop founded in Berkeley in 1982.\nTriplets:\n(Philz, is, coffee shop)\n(Philz, founded in, Berkeley)\n(Philz, founded in, 1982)\n---------------------\nText: Guardians of the Galaxy Vol. 3 (marketed as Guardians of the Galaxy Volume 3) is a 2023 American superhero film based on the Marvel Comics superhero team Guardians of the Galaxy, produced by Marvel Studios and distributed by Walt Disney Studios Motion Pictures. It is the sequel to Guardians of the Galaxy (2014) and Guardians of the Galaxy Vol. 2 (2017), and the 32nd film in the Marvel Cinematic Universe (MCU). Written and directed by James Gunn, it features an ensemble cast including Chris Pratt, Zoe Saldaña, Dave Bautista, Karen Gillan, Pom Klementieff, Vin Diesel, Bradley Cooper, Will Poulter, Sean Gunn, Chukwudi Iwuji, Linda Cardellini, Nathan Fillion, and Sylvester Stallone. In the film, the other Guardians race to save the life of Rocket (Cooper) from his creator, the High Evolutionary (Iwuji), who is an alien scientist trying to perfect the universe.\nGunn had initial ideas for a third and final Guardians of the Galaxy film by November 2014, and announced his return to write and direct in April 2017 ahead of Vol. 2's release. Vol. 3 explores the origin story of Rocket, with whom Gunn personally identifies. Disney fired Gunn from Vol. 3 in July 2018 after controversial jokes he made on Twitter resurfaced. Gunn received support from several cast members, and the studio reversed course by that October. His return was publicly revealed in March 2019, and he restarted work on the film after completing his film The Suicide Squad (2021) and the first season of its spin-off series Peacemaker (2022) for DC Films. New cast members, including Iwuji and Poulter, joined by the start of filming, which took place at Trilith Studios in Atlanta, Georgia, from November 2021 to May 2022.\nGuardians of the Galaxy Vol. 3 premiered at Disneyland Paris on April 22, 2023, and was released in the United States on May 5, as part of Phase Five of the MCU. Like its predecessors, it was a critical and commercial success, with many deeming it to be a satisfactory conclusion to the trilogy. It grossed over $845.6 million worldwide, becoming the fourth-highest-grossing film of 2023.\nTriplets:\n", 'stream': False, 'temperature': 0.1}}
# DEBUG:openai._base_client:Sending HTTP Request: POST https://llms-inference.innkube.fim.uni-passau.de/completions
# DEBUG:httpcore.connection:connect_tcp.started host='llms-inference.innkube.fim.uni-passau.de' port=443 local_address=None timeout=60.0 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7f4bfb54ee20>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x7f4be2741cc0> server_hostname='llms-inference.innkube.fim.uni-passau.de' timeout=60.0
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x7f4bd8f2f760>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Thu, 24 Apr 2025 14:37:39 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'985'), (b'Connection', b'keep-alive'), (b'x-litellm-call-id', b'3c3bf409-e18c-4552-8986-de1769f69d75'), (b'x-litellm-model-id', b'4fc98ad04997d06d243fa1037a8527856cb537a73abc970ce37122958bbea148'), (b'x-litellm-model-api-base', b'http://qwen2-5-ollama:11434'), (b'x-litellm-version', b'1.42.2'), (b'x-litellm-response-cost', b'0.391939'), (b'x-litellm-key-tpm-limit', b'None'), (b'x-litellm-key-rpm-limit', b'100'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains'), (b'Access-Control-Allow-Origin', b'*'), (b'Access-Control-Allow-Credentials', b'true'), (b'Access-Control-Allow-Methods', b'PUT, GET, POST'), (b'Access-Control-Allow-Headers', b'DNT,Keep-Alive,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range,Authorization'), (b'Access-Control-Max-Age', b'1728000')])
# INFO:httpx:HTTP Request: POST https://llms-inference.innkube.fim.uni-passau.de/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Response: POST https://llms-inference.innkube.fim.uni-passau.de/completions "200 OK" Headers({'date': 'Thu, 24 Apr 2025 14:37:39 GMT', 'content-type': 'application/json', 'content-length': '985', 'connection': 'keep-alive', 'x-litellm-call-id': '3c3bf409-e18c-4552-8986-de1769f69d75', 'x-litellm-model-id': '4fc98ad04997d06d243fa1037a8527856cb537a73abc970ce37122958bbea148', 'x-litellm-model-api-base': 'http://qwen2-5-ollama:11434', 'x-litellm-version': '1.42.2', 'x-litellm-response-cost': '0.391939', 'x-litellm-key-tpm-limit': 'None', 'x-litellm-key-rpm-limit': '100', 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'access-control-allow-origin': '*', 'access-control-allow-credentials': 'true', 'access-control-allow-methods': 'PUT, GET, POST', 'access-control-allow-headers': 'DNT,Keep-Alive,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range,Authorization', 'access-control-max-age': '1728000'})
# DEBUG:openai._base_client:request_id: None
# DEBUG:llama_index.core.indices.knowledge_graph.base:> Extracted triplets: [('Guardians of the galaxy vol. 3', 'Is', 'American superhero film'), ('Guardians of the galaxy vol. 3', 'Based on', 'Marvel comics superhero team guardians of the galaxy'), ('Guardians of the galaxy vol. 3', 'Produced by', 'Marvel studios'), ('Guardians of the galaxy vol. 3', 'Distributed by', 'Walt disney studios motion pictures'), ('Guardians of the galaxy vol. 3', 'Sequel to', 'Guardians of the galaxy'), ('Guardians of the galaxy vol. 3', 'Sequel to', 'Guardians of the galaxy vol. 2'), ('Guardians of the galaxy vol. 3', 'Is', '32nd film in mcu'), ('James gunn', 'Wrote and directed', 'Guardians of the galaxy vol. 3'), ('Rocket', 'Played by', 'Bradley cooper'), ('High evolutionary', 'Played by', 'Chukwudi iwuji')]
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/completions', 'files': None, 'json_data': {'model': 'qwen2.5', 'prompt': 'Some text is provided below. Given the text, extract up to 10 knowledge triplets in the form of (subject, predicate, object). Avoid stopwords.\n---------------------\nExample:Text: Alice is Bob\'s mother.Triplets:\n(Alice, is mother of, Bob)\nText: Philz is a coffee shop founded in Berkeley in 1982.\nTriplets:\n(Philz, is, coffee shop)\n(Philz, founded in, Berkeley)\n(Philz, founded in, 1982)\n---------------------\nText: His return was publicly revealed in March 2019, and he restarted work on the film after completing his film The Suicide Squad (2021) and the first season of its spin-off series Peacemaker (2022) for DC Films. New cast members, including Iwuji and Poulter, joined by the start of filming, which took place at Trilith Studios in Atlanta, Georgia, from November 2021 to May 2022.\nGuardians of the Galaxy Vol. 3 premiered at Disneyland Paris on April 22, 2023, and was released in the United States on May 5, as part of Phase Five of the MCU. Like its predecessors, it was a critical and commercial success, with many deeming it to be a satisfactory conclusion to the trilogy. It grossed over $845.6 million worldwide, becoming the fourth-highest-grossing film of 2023. At the 96th Academy Awards, the film was nominated for Best Visual Effects.\n\n\n== Plot ==\nAt their new headquarters on Knowhere, the Guardians of the Galaxy are attacked by Adam Warlock, a Sovereign warrior created by High Priestess Ayesha who seeks to destroy them for stealing from her. After critically wounding Rocket, Adam is stabbed by Nebula and flees. The Guardians\' med-packs are ineffective at healing Rocket\'s wounds due to a kill switch embedded in him by the organization Orgocorp. The Guardians travel to Orgocorp\'s headquarters to find the switch\'s override code and save Rocket\'s life.\nAs Rocket lies dying, he recalls his past. He was found and experimented on as a baby raccoon by the High Evolutionary, leader of Orgocorp, who aimed to enhance and anthropomorphize animal lifeforms into "Humanimals" for an ideal society, Counter-Earth. Rocket\'s fellow Batch 89 test subjects included the otter Lylla, walrus Teefs, and rabbit Floor. Impressed by Rocket\'s intelligence, the High Evolutionary used his insights to improve later batches of Humanimals. Angry that one of his creations could solve a problem that he could not, the High Evolutionary planned to harvest Rocket\'s brain and incinerate all of Batch 89. Rocket tried to rescue his friends, but the High Evolutionary killed Lylla and mocked Rocket\'s grief.\nTriplets:\n', 'stream': False, 'temperature': 0.1}}
# DEBUG:openai._base_client:Sending HTTP Request: POST https://llms-inference.innkube.fim.uni-passau.de/completions
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Thu, 24 Apr 2025 14:37:48 GMT'), (b'Content-Type', b'application/json'), (b'Content-Length', b'759'), (b'Connection', b'keep-alive'), (b'x-litellm-call-id', b'd076069d-dafb-4f79-906c-362848148323'), (b'x-litellm-model-id', b'4fc98ad04997d06d243fa1037a8527856cb537a73abc970ce37122958bbea148'), (b'x-litellm-model-api-base', b'http://qwen2-5-ollama:11434'), (b'x-litellm-version', b'1.42.2'), (b'x-litellm-response-cost', b'0.347267'), (b'x-litellm-key-tpm-limit', b'None'), (b'x-litellm-key-rpm-limit', b'100'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains'), (b'Access-Control-Allow-Origin', b'*'), (b'Access-Control-Allow-Credentials', b'true'), (b'Access-Control-Allow-Methods', b'PUT, GET, POST'), (b'Access-Control-Allow-Headers', b'DNT,Keep-Alive,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range,Authorization'), (b'Access-Control-Max-Age', b'1728000')])
# INFO:httpx:HTTP Request: POST https://llms-inference.innkube.fim.uni-passau.de/completions "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:openai._base_client:HTTP Response: POST https://llms-inference.innkube.fim.uni-passau.de/completions "200 OK" Headers({'date': 'Thu, 24 Apr 2025 14:37:48 GMT', 'content-type': 'application/json', 'content-length': '759', 'connection': 'keep-alive', 'x-litellm-call-id': 'd076069d-dafb-4f79-906c-362848148323', 'x-litellm-model-id': '4fc98ad04997d06d243fa1037a8527856cb537a73abc970ce37122958bbea148', 'x-litellm-model-api-base': 'http://qwen2-5-ollama:11434', 'x-litellm-version': '1.42.2', 'x-litellm-response-cost': '0.347267', 'x-litellm-key-tpm-limit': 'None', 'x-litellm-key-rpm-limit': '100', 'strict-transport-security': 'max-age=31536000; includeSubDomains', 'access-control-allow-origin': '*', 'access-control-allow-credentials': 'true', 'access-control-allow-methods': 'PUT, GET, POST', 'access-control-allow-headers': 'DNT,Keep-Alive,User-Agent,X-Requested-With,If-Modified-Since,Cache-Control,Content-Type,Range,Authorization', 'access-control-max-age': '1728000'})
# DEBUG:openai._base_client:request_id: None
# DEBUG:llama_index.core.indices.knowledge_graph.base:> Extracted triplets: [('His return', 'Publicly revealed in', 'March 2019'), ('He', 'Restarted work on', 'Film'), ('Film', 'Completed after', 'The suicide squad'), ('The suicide squad', 'Released in', '2021'), ('Peacemaker', 'First season of', 'Spin-off series'), ('New cast members', 'Joined by', 'Start of filming'), ('Filming', 'Took place at', 'Trilith studios'), ('Trilith studios', 'Located in', 'Atlanta'), ('Atlanta', 'State of', 'Georgia'), ('Guardians of the galaxy vol. 3', 'Premiered at', 'Disneyland paris')]
# DEBUG:openai._base_client:Request options: {'method': 'post', 'url': '/completions', 'files': None, 'json_data': {'model': 'qwen2.5', 'prompt': 'Some text is provided below. Given the text, extract up to 10 knowledge triplets in the form of (subject, predicate, object). Avoid stopwords.\n---------------------\nExample:Text: Alice is Bob\'s mother.Triplets:\n(Alice, is mother of, Bob)\nText: Philz is a coffee shop founded in Berkeley in 1982.\nTriplets:\n(Philz, is, coffee shop)\n(Philz, founded in, Berkeley)\n(Philz, founded in, 1982)\n---------------------\nText: The Guardians travel to Orgocorp\'s headquarters to find the switch\'s override code and save Rocket\'s life.\nAs Rocket lies dying, he recalls his past. He was found and experimented on as a baby raccoon by the High Evolutionary, leader of Orgocorp, who aimed to enhance and anthropomorphize animal lifeforms into "Humanimals" for an ideal society, Counter-Earth. Rocket\'s fellow Batch 89 test subjects included the otter Lylla, walrus Teefs, and rabbit Floor. Impressed by Rocket\'s intelligence, the High Evolutionary used his insights to improve later batches of Humanimals. Angry that one of his creations could solve a problem that he could not, the High Evolutionary planned to harvest Rocket\'s brain and incinerate all of Batch 89. Rocket tried to rescue his friends, but the High Evolutionary killed Lylla and mocked Rocket\'s grief. Enraged, Rocket attacked the High Evolutionary, whose henchmen killed Teefs and Floor during the chaos. Rocket escaped in a spaceship.\nIn the present, an alternate version of Gamora, who has joined the Ravagers, helps the Guardians infiltrate Orgocorp. They retrieve Rocket\'s file but discover that Theel, one of the High Evolutionary\'s advisors, has removed the override code. The Guardians and Gamora travel to Counter-Earth to find him. They are followed by Ayesha and Adam after the High Evolutionary, their race\'s creator, threatened to wipe out the Sovereign if they failed to retrieve Rocket. At Counter-Earth, Drax and Mantis remain with Gamora and Rocket while Peter Quill, Groot, and Nebula go to the High Evolutionary\'s Arête Laboratories complex. Guards force Nebula to wait outside due to her cybernetic enhancements; Quill and Groot enter Arête. Drax tricks Mantis into pursuing Quill\'s group and Gamora saves Rocket from Adam and War Pig, one of the High Evolutionary\'s Hellspawn guards.\nThe High Evolutionary agrees with Quill that Counter-Earth is imperfect and begins bombarding the entire planet, killing the Humanimals and Ayesha. Arête, which is actually a spaceship, departs as Nebula, Drax, and Mantis board it to rescue Quill and Groot.\nTriplets:\n', 'stream': False, 'temperature': 0.1}}
# DEBUG:openai._base_client:Sending HTTP Request: POST https://llms-inference.innkube.fim.uni-passau.de/completions
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_headers.failed exception=KeyboardInterrupt()
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[131], line 1
# ----> 1 kg_index = KnowledgeGraphIndex.from_documents(
#       2     documents,
#       3     storage_context=storage_context,
#       4     max_triplets_per_chunk=10,
#       5     llm = llm_qwen,
#       6     space_name=space_name,
#       7     edge_types=edge_types,
#       8     rel_prop_names=rel_prop_names,
#       9     tags=tags,
#      10     include_embeddings=False,
#      11 )
#
# File ~/envs/llmexp/lib/python3.9/site-packages/llama_index/core/indices/base.py:119, in BaseIndex.from_documents(cls, documents, storage_context, show_progress, callback_manager, transformations, **kwargs)
#     110     docstore.set_document_hash(doc.get_doc_id(), doc.hash)
#     112 nodes = run_transformations(
#     113     documents,  # type: ignore
#     114     transformations,
#     115     show_progress=show_progress,
#     116     **kwargs,
#     117 )
# --> 119 return cls(
#     120     nodes=nodes,
#     121     storage_context=storage_context,
#     122     callback_manager=callback_manager,
#     123     show_progress=show_progress,
#     124     transformations=transformations,
#     125     **kwargs,
#     126 )
#
# File ~/envs/llmexp/lib/python3.9/site-packages/llama_index/core/indices/knowledge_graph/base.py:99, in KnowledgeGraphIndex.__init__(self, nodes, objects, index_struct, llm, embed_model, storage_context, kg_triplet_extract_template, max_triplets_per_chunk, include_embeddings, show_progress, max_object_length, kg_triplet_extract_fn, **kwargs)
#      96 self._llm = llm or Settings.llm
#      97 self._embed_model = embed_model or Settings.embed_model
# ---> 99 super().__init__(
#     100     nodes=nodes,
#     101     index_struct=index_struct,
#     102     storage_context=storage_context,
#     103     show_progress=show_progress,
#     104     objects=objects,
#     105     **kwargs,
#     106 )
#     108 # TODO: legacy conversion - remove in next release
#     109 if (
#     110     len(self.index_struct.table) > 0
#     111     and isinstance(self.graph_store, SimpleGraphStore)
#     112     and len(self.graph_store._data.graph_dict) == 0
#     113 ):
#
# File ~/envs/llmexp/lib/python3.9/site-packages/llama_index/core/indices/base.py:77, in BaseIndex.__init__(self, nodes, objects, index_struct, storage_context, callback_manager, transformations, show_progress, **kwargs)
#      75 if index_struct is None:
#      76     nodes = nodes or []
# ---> 77     index_struct = self.build_index_from_nodes(
#      78         nodes + objects,  # type: ignore
#      79         **kwargs,  # type: ignore
#      80     )
#      81 self._index_struct = index_struct
#      82 self._storage_context.index_store.add_index_struct(self._index_struct)
#
# File ~/envs/llmexp/lib/python3.9/site-packages/llama_index/core/indices/base.py:185, in BaseIndex.build_index_from_nodes(self, nodes, **build_kwargs)
#     183 """Build the index from nodes."""
#     184 self._docstore.add_documents(nodes, allow_update=True)
# --> 185 return self._build_index_from_nodes(nodes, **build_kwargs)
#
# File ~/envs/llmexp/lib/python3.9/site-packages/llama_index/core/indices/knowledge_graph/base.py:212, in KnowledgeGraphIndex._build_index_from_nodes(self, nodes, **build_kwargs)
#     208 nodes_with_progress = get_tqdm_iterable(
#     209     nodes, self._show_progress, "Processing nodes"
#     210 )
#     211 for n in nodes_with_progress:
# --> 212     triplets = self._extract_triplets(
#     213         n.get_content(metadata_mode=MetadataMode.LLM)
#     214     )
#     215     logger.debug(f"> Extracted triplets: {triplets}")
#     216     for triplet in triplets:
#
# File ~/envs/llmexp/lib/python3.9/site-packages/llama_index/core/indices/knowledge_graph/base.py:154, in KnowledgeGraphIndex._extract_triplets(self, text)
#     152     return self._kg_triplet_extract_fn(text)
#     153 else:
# --> 154     return self._llm_extract_triplets(text)
#
# File ~/envs/llmexp/lib/python3.9/site-packages/llama_index/core/indices/knowledge_graph/base.py:158, in KnowledgeGraphIndex._llm_extract_triplets(self, text)
#     156 def _llm_extract_triplets(self, text: str) -> List[Tuple[str, str, str]]:
#     157     """Extract keywords from text."""
# --> 158     response = self._llm.predict(
#     159         self.kg_triplet_extract_template,
#     160         text=text,
#     161     )
#     162     return self._parse_triplet_response(
#     163         response, max_length=self._max_object_length
#     164     )
#
# File ~/envs/llmexp/lib/python3.9/site-packages/llama_index/core/instrumentation/dispatcher.py:322, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     319             _logger.debug(f"Failed to reset active_span_id: {e}")
#     321 try:
# --> 322     result = func(*args, **kwargs)
#     323     if isinstance(result, asyncio.Future):
#     324         # If the result is a Future, wrap it
#     325         new_future = asyncio.ensure_future(result)
#
# File ~/envs/llmexp/lib/python3.9/site-packages/llama_index/core/llms/llm.py:609, in LLM.predict(self, prompt, **prompt_args)
#     607 else:
#     608     formatted_prompt = self._get_prompt(prompt, **prompt_args)
# --> 609     response = self.complete(formatted_prompt, formatted=True)
#     610     output = response.text
#     611 parsed_output = self._parse_output(output)
#
# File ~/envs/llmexp/lib/python3.9/site-packages/llama_index/core/instrumentation/dispatcher.py:322, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     319             _logger.debug(f"Failed to reset active_span_id: {e}")
#     321 try:
# --> 322     result = func(*args, **kwargs)
#     323     if isinstance(result, asyncio.Future):
#     324         # If the result is a Future, wrap it
#     325         new_future = asyncio.ensure_future(result)
#
# File ~/envs/llmexp/lib/python3.9/site-packages/llama_index/llms/openai_like/base.py:136, in OpenAILike.complete(self, prompt, formatted, **kwargs)
#     133 if not formatted:
#     134     prompt = self.completion_to_prompt(prompt)
# --> 136 return super().complete(prompt, **kwargs)
#
# File ~/envs/llmexp/lib/python3.9/site-packages/llama_index/core/instrumentation/dispatcher.py:322, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     319             _logger.debug(f"Failed to reset active_span_id: {e}")
#     321 try:
# --> 322     result = func(*args, **kwargs)
#     323     if isinstance(result, asyncio.Future):
#     324         # If the result is a Future, wrap it
#     325         new_future = asyncio.ensure_future(result)
#
# File ~/envs/llmexp/lib/python3.9/site-packages/llama_index/core/llms/callbacks.py:431, in llm_completion_callback.<locals>.wrap.<locals>.wrapped_llm_predict(_self, *args, **kwargs)
#     422 event_id = callback_manager.on_event_start(
#     423     CBEventType.LLM,
#     424     payload={
#    (...)
#     428     },
#     429 )
#     430 try:
# --> 431     f_return_val = f(_self, *args, **kwargs)
#     432 except BaseException as e:
#     433     callback_manager.on_event_end(
#     434         CBEventType.LLM,
#     435         payload={EventPayload.EXCEPTION: e},
#     436         event_id=event_id,
#     437     )
#
# File ~/envs/llmexp/lib/python3.9/site-packages/llama_index/llms/openai/base.py:405, in OpenAI.complete(self, prompt, formatted, **kwargs)
#     403 else:
#     404     complete_fn = self._complete
# --> 405 return complete_fn(prompt, **kwargs)
#
# File ~/envs/llmexp/lib/python3.9/site-packages/llama_index/llms/openai/base.py:111, in llm_retry_decorator.<locals>.wrapper(self, *args, **kwargs)
#     102     return f(self, *args, **kwargs)
#     104 retry = create_retry_decorator(
#     105     max_retries=max_retries,
#     106     random_exponential=True,
#    (...)
#     109     max_seconds=20,
#     110 )
# --> 111 return retry(f)(self, *args, **kwargs)
#
# File ~/envs/llmexp/lib/python3.9/site-packages/tenacity/__init__.py:336, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     334 copy = self.copy()
#     335 wrapped_f.statistics = copy.statistics  # type: ignore[attr-defined]
# --> 336 return copy(f, *args, **kw)
#
# File ~/envs/llmexp/lib/python3.9/site-packages/tenacity/__init__.py:475, in Retrying.__call__(self, fn, *args, **kwargs)
#     473 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     474 while True:
# --> 475     do = self.iter(retry_state=retry_state)
#     476     if isinstance(do, DoAttempt):
#     477         try:
#
# File ~/envs/llmexp/lib/python3.9/site-packages/tenacity/__init__.py:376, in BaseRetrying.iter(self, retry_state)
#     374 result = None
#     375 for action in self.iter_state.actions:
# --> 376     result = action(retry_state)
#     377 return result
#
# File ~/envs/llmexp/lib/python3.9/site-packages/tenacity/__init__.py:398, in BaseRetrying._post_retry_check_actions.<locals>.<lambda>(rs)
#     396 def _post_retry_check_actions(self, retry_state: "RetryCallState") -> None:
#     397     if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 398         self._add_action_func(lambda rs: rs.outcome.result())
#     399         return
#     401     if self.after is not None:
#
# File ~/envs/llmexp/lib/python3.9/concurrent/futures/_base.py:439, in Future.result(self, timeout)
#     437     raise CancelledError()
#     438 elif self._state == FINISHED:
# --> 439     return self.__get_result()
#     441 self._condition.wait(timeout)
#     443 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~/envs/llmexp/lib/python3.9/concurrent/futures/_base.py:391, in Future.__get_result(self)
#     389 if self._exception:
#     390     try:
# --> 391         raise self._exception
#     392     finally:
#     393         # Break a reference cycle with the exception in self._exception
#     394         self = None
#
# File ~/envs/llmexp/lib/python3.9/site-packages/tenacity/__init__.py:478, in Retrying.__call__(self, fn, *args, **kwargs)
#     476 if isinstance(do, DoAttempt):
#     477     try:
# --> 478         result = fn(*args, **kwargs)
#     479     except BaseException:  # noqa: B902
#     480         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File ~/envs/llmexp/lib/python3.9/site-packages/llama_index/llms/openai/base.py:574, in OpenAI._complete(self, prompt, **kwargs)
#     571 self._update_max_tokens(all_kwargs, prompt)
#     573 if self.reuse_client:
# --> 574     response = client.completions.create(
#     575         prompt=prompt,
#     576         stream=False,
#     577         **all_kwargs,
#     578     )
#     579 else:
#     580     with client:
#
# File ~/envs/llmexp/lib/python3.9/site-packages/openai/_utils/_utils.py:279, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     277             msg = f"Missing required argument: {quote(missing[0])}"
#     278     raise TypeError(msg)
# --> 279 return func(*args, **kwargs)
#
# File ~/envs/llmexp/lib/python3.9/site-packages/openai/resources/completions.py:545, in Completions.create(self, model, prompt, best_of, echo, frequency_penalty, logit_bias, logprobs, max_tokens, n, presence_penalty, seed, stop, stream, stream_options, suffix, temperature, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     516 @required_args(["model", "prompt"], ["model", "prompt", "stream"])
#     517 def create(
#     518     self,
#    (...)
#     543     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     544 ) -> Completion | Stream[Completion]:
# --> 545     return self._post(
#     546         "/completions",
#     547         body=maybe_transform(
#     548             {
#     549                 "model": model,
#     550                 "prompt": prompt,
#     551                 "best_of": best_of,
#     552                 "echo": echo,
#     553                 "frequency_penalty": frequency_penalty,
#     554                 "logit_bias": logit_bias,
#     555                 "logprobs": logprobs,
#     556                 "max_tokens": max_tokens,
#     557                 "n": n,
#     558                 "presence_penalty": presence_penalty,
#     559                 "seed": seed,
#     560                 "stop": stop,
#     561                 "stream": stream,
#     562                 "stream_options": stream_options,
#     563                 "suffix": suffix,
#     564                 "temperature": temperature,
#     565                 "top_p": top_p,
#     566                 "user": user,
#     567             },
#     568             completion_create_params.CompletionCreateParamsStreaming
#     569             if stream
#     570             else completion_create_params.CompletionCreateParamsNonStreaming,
#     571         ),
#     572         options=make_request_options(
#     573             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     574         ),
#     575         cast_to=Completion,
#     576         stream=stream or False,
#     577         stream_cls=Stream[Completion],
#     578     )
#
# File ~/envs/llmexp/lib/python3.9/site-packages/openai/_base_client.py:1276, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1262 def post(
#    1263     self,
#    1264     path: str,
#    (...)
#    1271     stream_cls: type[_StreamT] | None = None,
#    1272 ) -> ResponseT | _StreamT:
#    1273     opts = FinalRequestOptions.construct(
#    1274         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1275     )
# -> 1276     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/envs/llmexp/lib/python3.9/site-packages/openai/_base_client.py:949, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     946 else:
#     947     retries_taken = 0
# --> 949 return self._request(
#     950     cast_to=cast_to,
#     951     options=options,
#     952     stream=stream,
#     953     stream_cls=stream_cls,
#     954     retries_taken=retries_taken,
#     955 )
#
# File ~/envs/llmexp/lib/python3.9/site-packages/openai/_base_client.py:989, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#     986 log.debug("Sending HTTP Request: %s %s", request.method, request.url)
#     988 try:
# --> 989     response = self._client.send(
#     990         request,
#     991         stream=stream or self._should_stream_response_body(request=request),
#     992         **kwargs,
#     993     )
#     994 except httpx.TimeoutException as err:
#     995     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File ~/envs/llmexp/lib/python3.9/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~/envs/llmexp/lib/python3.9/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~/envs/llmexp/lib/python3.9/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~/envs/llmexp/lib/python3.9/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File ~/envs/llmexp/lib/python3.9/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)
#     247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File ~/envs/llmexp/lib/python3.9/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File ~/envs/llmexp/lib/python3.9/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File ~/envs/llmexp/lib/python3.9/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File ~/envs/llmexp/lib/python3.9/site-packages/httpcore/_sync/http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File ~/envs/llmexp/lib/python3.9/site-packages/httpcore/_sync/http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File ~/envs/llmexp/lib/python3.9/site-packages/httpcore/_sync/http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File ~/envs/llmexp/lib/python3.9/site-packages/httpcore/_sync/http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/envs/llmexp/lib/python3.9/site-packages/httpcore/_backends/sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# File ~/envs/llmexp/lib/python3.9/ssl.py:1260, in SSLSocket.recv(self, buflen, flags)
#    1256     if flags != 0:
#    1257         raise ValueError(
#    1258             "non-zero flags not allowed in calls to recv() on %s" %
#    1259             self.__class__)
# -> 1260     return self.read(buflen)
#    1261 else:
#    1262     return super().recv(buflen, flags)
#
# File ~/envs/llmexp/lib/python3.9/ssl.py:1135, in SSLSocket.read(self, len, buffer)
#    1133         return self._sslobj.read(len, buffer)
#    1134     else:
# -> 1135         return self._sslobj.read(len)
#    1136 except SSLError as x:
#    1137     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %%
print(type(kg_index))
# Out:
# <class 'llama_index.core.indices.knowledge_graph.base.KnowledgeGraphIndex'>

# %%
print(dir(kg_index))
# Out:
# ['__abstractmethods__', '__annotations__', '__class__', '__class_getitem__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__orig_bases__', '__parameters__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_build_index_from_nodes', '_callback_manager', '_delete_node', '_docstore', '_embed_model', '_extract_triplets', '_graph_store', '_index_struct', '_insert', '_is_protocol', '_kg_triplet_extract_fn', '_llm', '_llm_extract_triplets', '_max_object_length', '_object_map', '_parse_triplet_response', '_show_progress', '_storage_context', '_transformations', '_vector_store', 'add_node', 'as_chat_engine', 'as_query_engine', 'as_retriever', 'build_index_from_nodes', 'delete', 'delete_nodes', 'delete_ref_doc', 'docstore', 'from_documents', 'get_networkx_graph', 'graph_store', 'include_embeddings', 'index_id', 'index_struct', 'index_struct_cls', 'insert', 'insert_nodes', 'kg_triplet_extract_template', 'max_triplets_per_chunk', 'query_context', 'ref_doc_info', 'refresh', 'refresh_ref_docs', 'set_index_id', 'storage_context', 'summary', 'update', 'update_ref_doc', 'upsert_triplet', 'upsert_triplet_and_node']

# %%
graph = kg_index.get_networkx_graph()
# print(graph.nodes())  # List all nodes in the graph
# print(graph.edges())  # List all edges in the graph
print(graph.nodes(data=True))  # List all nodes with their attributes
print(graph.edges(data=True))  # List all edges with their attributes
# Out:
# [('Guardians of the galaxy vol. 3', {}), ('American superhero film', {}), ('Marvel comics superhero team guardians of the galaxy', {}), ('Marvel studios', {}), ('Walt disney studios motion pictures', {}), ('Guardians of the galaxy', {}), ('Guardians of the galaxy vol. 2', {}), ('32nd film in mcu', {}), ('Avengers: infinity war', {}), ('Avengers: endgame', {}), ('This iteration of the guardians of the galaxy', {}), ('Dongdaemun design plaza', {}), ('Disneyland paris', {}), ('Dolby theatre', {}), ('Mcu', {}), ('3d', {}), ('Imax', {}), ('1.85:1', {}), ('Walt disney studios home entertainment', {}), ('Digital download', {}), ('Ultra hd blu-ray', {}), ('Dvd', {}), ('Disney+', {}), ("Rocket raccoon's story", {}), ('Marvel.com', {}), ('Imdb', {}), ('Disney a to z', {}), ('Disney.com', {}), ('Disney', {}), ('Vol. 3', {}), ('Character', {}), ('James gunn', {}), ('Post-credits scene', {}), ('Lambshank', {}), ('Stan lee', {}), ('Disney and marvel', {}), ('Different than before', {}), ('The suicide squad (2021', {}), ('Rocket', {}), ('Bradley cooper', {}), ('Past', {}), ('Batch 89', {}), ('War pig', {}), ('Imprisoned animals', {}), ('High evolutionary', {}), ('Guardians', {}), ('Avenger', {}), ('Genetically engineered raccoon-based bounty hunter', {}), ('Weapons and military tactics', {}), ('Gunn', {}), ('The same" by gunn', {}), ('Chukwudi iwuji', {}), ('Orgocorp', {}), ('Animal lifeforms', {}), ('Humanimals', {}), ('Sovereign', {}), ('Creating hybrid creatures', {}), ('All living beings', {}), ('Animen', {}), ('Hell spawn', {}), ('Xeronians', {}), ('Star children', {}), ('Doctor moreau', {}), ('Cruelest mcu villain', {}), ('Rocket and his fellow subject friends', {}), ('His return', {}), ('March 2019', {}), ('He', {}), ('Film', {}), ('The suicide squad', {}), ('Late 2021', {}), ('Creep acoustic version', {}), ("Marvel studios' panel", {}), ('2022 san diego comic-con', {}), ("Rocket's arc story", {}), ('2021', {}), ('Peacemaker', {}), ('2022', {}), ('New cast members', {}), ('Start of filming', {}), ('Filming', {}), ('Trilith studios', {}), ('November 2021 to may 2022', {}), ('November 2021', {}), ('April 2022', {})]
# [('Guardians of the galaxy vol. 3', 'American superhero film', {'label': 'Is', 'title': 'Is'}), ('Guardians of the galaxy vol. 3', 'Marvel comics superhero team guardians of the galaxy', {'label': 'Based on', 'title': 'Based on'}), ('Guardians of the galaxy vol. 3', 'Marvel studios', {'label': 'Produced by', 'title': 'Produced by'}), ('Guardians of the galaxy vol. 3', 'Walt disney studios motion pictures', {'label': 'Distributed by', 'title': 'Distributed by'}), ('Guardians of the galaxy vol. 3', 'Guardians of the galaxy', {'label': 'Sequel to', 'title': 'Sequel to'}), ('Guardians of the galaxy vol. 3', 'Guardians of the galaxy vol. 2', {'label': 'Sequel to', 'title': 'Sequel to'}), ('Guardians of the galaxy vol. 3', '32nd film in mcu', {'label': 'Is', 'title': 'Is'}), ('Guardians of the galaxy vol. 3', 'Avengers: infinity war', {'label': 'Set after', 'title': 'Set after'}), ('Guardians of the galaxy vol. 3', 'Avengers: endgame', {'label': 'Set after', 'title': 'Set after'}), ('Guardians of the galaxy vol. 3', 'This iteration of the guardians of the galaxy', {'label': 'Conclude story of', 'title': 'Conclude story of'}), ('Guardians of the galaxy vol. 3', 'Dongdaemun design plaza', {'label': 'Had early screening at', 'title': 'Had early screening at'}), ('Guardians of the galaxy vol. 3', 'Disneyland paris', {'label': 'Premiered at', 'title': 'Premiered at'}), ('Guardians of the galaxy vol. 3', 'Dolby theatre', {'label': 'North american premiere held at', 'title': 'North american premiere held at'}), ('Guardians of the galaxy vol. 3', 'Mcu', {'label': 'Part of phase five of', 'title': 'Part of phase five of'}), ('Guardians of the galaxy vol. 3', '3d', {'label': 'Released in formats including', 'title': 'Released in formats including'}), ('Guardians of the galaxy vol. 3', 'Imax', {'label': 'Released in formats including', 'title': 'Released in formats including'}), ('Guardians of the galaxy vol. 3', '1.85:1', {'label': 'Forty-five minutes presented in aspect ratio', 'title': 'Forty-five minutes presented in aspect ratio'}), ('Guardians of the galaxy vol. 3', 'Walt disney studios home entertainment', {'label': 'Released by', 'title': 'Released by'}), ('Guardians of the galaxy vol. 3', 'Digital download', {'label': 'Released on', 'title': 'Released on'}), ('Guardians of the galaxy vol. 3', 'Ultra hd blu-ray', {'label': 'Released on', 'title': 'Released on'}), ('Guardians of the galaxy vol. 3', 'Dvd', {'label': 'Released on', 'title': 'Released on'}), ('Guardians of the galaxy vol. 3', 'Disney+', {'label': 'Released on', 'title': 'Released on'}), ('Guardians of the galaxy vol. 3', "Rocket raccoon's story", {'label': 'Tells', 'title': 'Tells'}), ('Guardians of the galaxy vol. 3', 'Marvel.com', {'label': 'Has official website at', 'title': 'Has official website at'}), ('Guardians of the galaxy vol. 3', 'Imdb', {'label': 'Listed on', 'title': 'Listed on'}), ('Guardians of the galaxy vol. 3', 'Disney a to z', {'label': 'Referenced in', 'title': 'Referenced in'}), ('Guardians of the galaxy vol. 3', 'Disney.com', {'label': 'Featured on', 'title': 'Featured on'}), ('Guardians of the galaxy vol. 3', 'James gunn', {'label': 'Directed', 'title': 'Directed'}), ('Marvel studios', 'Disney', {'label': 'Began conversations with', 'title': 'Began conversations with'}), ('Marvel studios', 'Vol. 3', {'label': 'Reiterated would make', 'title': 'Reiterated would make'}), ('Marvel studios', 'Character', {'label': 'Has future plans for', 'title': 'Has future plans for'}), ('Disney', 'James gunn', {'label': 'Completed exit settlement with', 'title': 'Completed exit settlement with'}), ('James gunn', 'Post-credits scene', {'label': 'Opted not to include drax in', 'title': 'Opted not to include drax in'}), ('James gunn', 'Lambshank', {'label': 'Voices', 'title': 'Voices'}), ('James gunn', 'Stan lee', {'label': 'Wrote role for', 'title': 'Wrote role for'}), ('James gunn', 'Disney and marvel', {'label': 'Severed ties with', 'title': 'Severed ties with'}), ('J ...

# %%
# from llama_index.llms.openai_like import OpenAILike
# from llama_index.core.llms import ChatMessage

# llm = OpenAILike(
#   api_base="https://llms-inference.innkube.fim.uni-passau.de",
#   api_key="sk-Fr2TEolkvrxjjs235KJqkg",
#   model="qwen2.5")

# messages = [
#     ChatMessage(
#         role="system", content="You are a pirate with a colorful personality"
#     ),
#     ChatMessage(role="user", content="What is your name"),
# ]
# resp = llm.chat(messages)
